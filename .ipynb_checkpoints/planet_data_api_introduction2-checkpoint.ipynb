# %% [markdown]
# # Planet Data API Introduction using Python
#
# ---

# %% [markdown]
# ## Introduction
#
# ---
#
# This tutorial is an introduction to [Planet](https://www.planet.com)'s Data API. It provides code samples on how to write simple Python code to access data.
#
# [`https://api.planet.com/data/v1`](https://api.planet.com/data/v1)
#
# The focus of this tutorial will be the search portion of the Planet Data API. We will find and download imagery data using complex searches and save them for later use, as well as learn how to get stats on search results. After completing this tutorial, you should feel comfortable interacting with the Data API, and have a good foundation for leveraging the Planet Data API for your own applications.

# %% [markdown]
# ## Table of Contents
#
# ---
#
# * **Introduction**
#     * Requirements
#        * Software & Modules
#        * Planet API Key
#     * Useful Links
#
#
# * **Overview**
#      * The Basic Workflow
#       * Data API Endpoints
#       * Planet Explorer
#
#
# * **Basic Setup**
#     * Authentication
#     * Helper Modules and Functions
#     * Our First Request
#
#
# * **Search Mechanics & Filters**
#     * Statistics
#     * Using a Search Filter
#     * Filter types
#         * Field Filters
#         * Logical Filters
#         * (Field) Filter Type examples
#     * Complex Queries using Logical Filters
#
#
# * **Searching for Items**
#     * Quick Search
#         * Mapping Footprints Example
#
#
# * **Assets & Permissions**
#     * Activating Assets
#     * Downloading Assets
#     * Rate Limits
#
#
# * **Saved Searches**
#
#
# * **Conclusion**

# %% [markdown]
# ### Requirements
#
# ---
#
# #### Software & Modules
#
# This tutorial assumes familiarity with the [Python](https://python.org) programming language throughout. Familiarity with basic REST API concepts and usage is also assumed.
#
# We'll be using a **"Jupyter Notebook"** (aka Python Notebook) to run through the examples.
# To learn more about and get started with using Jupyter, visit: [Jupyter](https://jupyter.org/) and [IPython](https://ipython.org/).
#
# For the best experience, download this notebook and run it on your system, and make sure to install the modules listed below first. You can also copy the examples' code to a separate Python files an run them directly with Python on your system if you prefer.
#
#
# Python modules used in this tutorial are:
# * [requests](http://docs.python-requests.org/)
# * [geojsonio](https://pypi.python.org/pypi/geojsonio)
#
#
# #### Planet API Key
#
# You should have an account on the Planet Platform to access the Data API. You may retrieve your API key from your [account page](https://www.planet.com/account/), or from the "API Tab" in [Planet Explorer](https://www.planet.com/explorer).

# %% [markdown]
# ### Useful links
#
# ---
#
# * [Planet Data API Reference & Documentation](https://www.planet.com/docs/reference/data-api/)
# * [Planet Explorer](https://www.planet.com/explorer)
#
# * Planet Data API explorer - Coming Soon!

# %% [markdown]
# ## Overview
#
# ---
#
# ### The Basic Workflow:
#
# 1. Search item types based on filters
# 1. Activate assets
# 1. Download assets

# %% [markdown]
# ### API Endpoints
#
# This tutorial will cover the following API ***endpoints***:
#
# * [`/item-types`](https://api.planet.com/data/v1/item-types/)
# * [`/asset-types`](https://api.planet.com/data/v1/asset-types/)
# * `/quick-search`
# * `/searches`
# * `/stats`
#
# There is an additional [`/spec`](https://api.planet.com/data/v1/spec) endpoint that publishes a [Swagger](http://swagger.io/) specification for the Data API.
#
# ### Exploring Endpoints
#
# We can start by exploring two endpoints using our browser.
#
# ##### What item types are available?
#
# https://api.planet.com/data/v1/item-types/
#
# ##### What assets are available?
#
# https://api.planet.com/data/v1/asset-types/

# %% [markdown]
# ***Note:*** *You may choose to install a helpful browser plugin called **JSONView** that formats JSON and makes it easier to read:*
#
# * [Chrome Extension](https://chrome.google.com/webstore/detail/jsonview/chklaanhfefbnpoihckbnefhakgolnmc)
# * [Firefox Plugin](https://addons.mozilla.org/en-us/firefox/addon/jsonview/)

# %% [markdown]
# ### Planet Explorer
# We can also use Planet Explorer to expose relevant API information for search results.
#
# In Planet Explorer, while in *Daily Imagery Mode* click on the *"Api"* button in the bottom left corner of the results panel.
#
# ![Planet Explorer Screenshot](images/planet-explorer.png)
#
# Here, you may access your API Key, selected item id's, and `cURL` request information containing filters and options.

# %% [markdown]
# ## Basic Setup
#
# ---
#
# Before interacting with the Planet Data API using Python, we will set up our environment with some useful modules and helper functions.
#
# * We'll configure *authentication* to the Planet Data API
# * We'll use the `requests` Python module to make HTTP communication easier.
# * We'll use the `json` Python module to help us work with JSON responses from the API.
# * We'll create a function called `p` that will print Python dictionaries nicely.
#
# Then we'll be ready to make our first call to the Planet API by hitting the base endpoint at `https://api.planet.com/data/v1`.
#
# Let's start by configuring authentication:

# %% [markdown]
# ### Authentication
#
# Authentication with the Planet Data API be achieved using a valid Planet **API key**.

# %% [markdown]
# You can *export* your API Key as an environment variable on your system:
#
# `export PL_API_KEY="YOUR API KEY HERE"`
#
# Or add the variable to your path, etc. If you are using our Docker environement, it will already be set.
#
# To start our Python code, we'll setup an API Key variable from an environment variable to use with our requests:

# %%
# Import the os module in order to access environment variables
import os

# If you're following along with this notebook, you can enter your API Key on the following line, and uncomment it:
os.environ['PL_API_KEY']='e2bbb6fc3fc94e889cb2d6ee2ff78798'

# Setup the API Key from the `PL_API_KEY` environment variable
PLANET_API_KEY = os.getenv('PL_API_KEY')

# %% [markdown]
# ### Helper Modules and Functions

# %%
# Import helper modules
import json
import requests

# %%
# Helper function to printformatted JSON using the json module
def p(data):
    print(json.dumps(data, indent=2))

# %% [markdown]
# ### Our First Request

# %%
# Setup Planet Data API base URL
URL = "https://api.planet.com/data/v1"

# Setup the session
session = requests.Session()

# Authenticate
session.auth = (PLANET_API_KEY, "")

# %%
# Make a GET request to the Planet Data API
res = session.get(URL)

# %% [markdown]
# Now we should get a response, hopefully it's a `200` code, saying everything is OK!

# %%
# Response status code
res.status_code
# Out:
# 200

# %%
# Response Body
res.text
# Out:
# '{"_links": {"_self": "https://api.planet.com/data/v1/", "asset-types": "https://api.planet.com/data/v1/asset-types/", "item-types": "https://api.planet.com/data/v1/item-types/", "spec": "https://api.planet.com/data/v1/spec"}}'

# %%
# Print formatted JSON response
p(res.json())
# Out:
# {
#   "_links": {
#     "_self": "https://api.planet.com/data/v1/",
#     "asset-types": "https://api.planet.com/data/v1/asset-types/",
#     "item-types": "https://api.planet.com/data/v1/item-types/",
#     "spec": "https://api.planet.com/data/v1/spec"
#   }
# }

# %%
# Print the value of the item-types key from _links
print(res.json()["_links"]["item-types"])
# Out:
# https://api.planet.com/data/v1/item-types/

# %% [markdown]
# **Congratulations!** You just made your first request to the Planet Data API using Python!
#
# Now, let's take a look at how to access all that high cadence satellite imagery!

# %% [markdown]
# ## Search Mechanics & Filters
#
# ---
#
# There's a lot of data available on the Planet Data API and in order to find what we're looking for, we'll have to perform various types of searches.
#
# To construct a search, we use **filters** that let us limit results based on date, geography or other metadata properties.
#
# Using these filters, we are able to **search** for items or get **statistics** for search results.
#
# Let's first make a request to the `/stats` endpoint to understand how the filters work:

# %% [markdown]
# ### Statistics `/stats`
#
# ---
#
# The `/stats` endpoint provides a summary of the available data based on some search criteria.
#
# `https://api.planet.com/data/v1/stats`
#
# We'll need to send a ***`POST`*** request to `/stats`, let's start by setting up the request url:

# %%
# Setup the stats URL
stats_url = "{}/stats".format(URL)

# Print the stats URL
print(stats_url)
# Out:
# https://api.planet.com/data/v1/stats

# %% [markdown]
# ### Using a Search Filter
#
# Search filters should have the following properties:
#
# * **Type** (`type`) - The type of filter being used
# * **Configuration** (`config`) - The configuration for this filter
# * **Field Name** (`field_name`) - The field on which to filter
#
# For this example, let's use a filter to get some stats on what data is available for *Planet Scope (3 Band)* and *Rapid Eye (Ortho Tile)* products taken from 2013 until now:

# %%
# Specify the sensors/satellites or "item types" to include in our results
item_types = ["PSScene3Band", "REOrthoTile"]

# %%
# Create filter object for all imagery captured between 2013-01-01 and present.
date_filter = {
    "type": "DateRangeFilter", # Type of filter -> Date Range
    "field_name": "acquired", # The field to filter on: "acquired" -> Date on which the "image was taken"
    "config": {
        "gte": "2013-01-01T00:00:00.000Z", # "gte" -> Greater than or equal to
    }
}

# %% [markdown]
# Depending on the filter type, some requests may need an `interval` field:
#
# The following intervals are possible:
# * `year`
# * `month`
# * `week`
# * `day`
# * `hour`
#
# An `interval` must be provided with the request so that the number of matching items can be aggregated. We'll use an interval with our date filter.

# %% [markdown]
# Now let's perform our request using the `date_filter` filter we created above:

# %%
# Construct the request.
request = {
    "item_types" : item_types,
    "interval" : "year",
    "filter" : date_filter
}

# Send the POST request to the API stats endpoint
res = session.post(stats_url, json=request)

# Print response
p(res.json())
# Out:
# {
#   "utc_offset": "+0h",
#   "interval": "year",
#   "buckets": [
#     {
#       "count": 3113947,
#       "start_time": "2013-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 3648445,
#       "start_time": "2014-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 8699136,
#       "start_time": "2015-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 37014246,
#       "start_time": "2016-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 174380708,
#       "start_time": "2017-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 11963190,
#       "start_time": "2018-01-01T00:00:00.000000Z"
#     }
#   ]
# }

# %% [markdown]
# ***Good Job!*** You've received a response from the API that contains some statistics like item counts for the search criteria!

# %% [markdown]
# <div class="alert alert-info">
#
# **Exercise:** Create a new date filter to find data from before 2013.
#
# </div>

# %%
        # Fill in this filter to complete the exercise! 
date_filter2 = { "type": "DateRangeFilter", # Type of filter -> Date Range
    "field_name": "acquired", # The field to filter on: "acquired" -> Date on which the "image was taken"
    "config": {
        "lte": "2018-01-01T00:00:00.000Z",
        "gte": "2017-12-01T00:00:00.000Z"# "lte" -> minor than or equal to
}
               }
request = {
    "item_types" : item_types,
    "interval" : "week",
    "filter" : date_filter2
}

res = session.post(stats_url, json=request)
p(res.json())
# Out:
# {
#   "utc_offset": "+0h",
#   "interval": "week",
#   "buckets": [
#     {
#       "count": 1909011,
#       "start_time": "2017-11-27T00:00:00.000000Z"
#     },
#     {
#       "count": 4887082,
#       "start_time": "2017-12-04T00:00:00.000000Z"
#     },
#     {
#       "count": 4103446,
#       "start_time": "2017-12-11T00:00:00.000000Z"
#     },
#     {
#       "count": 4324695,
#       "start_time": "2017-12-18T00:00:00.000000Z"
#     },
#     {
#       "count": 4414248,
#       "start_time": "2017-12-25T00:00:00.000000Z"
#     },
#     {
#       "count": 4,
#       "start_time": "2018-01-01T00:00:00.000000Z"
#     }
#   ]
# }

# %% [markdown]
# ---
#
# Next, let's take a closer look at some of the available filters:

# %% [markdown]
# ### Filter types
#
# The Planet Data API supports several filter types. The most common are the following:
#
# ### Field Filters
#
# * `DateRangeFilter`
# * `RangeFilter`
# * `StringInFilter`
# * `PermissionFilter`
# * `GeometryFilter`
#
# ### Logical Filters
#
# * `NotFilter`
# * `AndFilter`
# * `OrFilter`
#
# More information and examples on filter types can be found at the [API Docs](https://www.planet.com/docs/reference/data-api/search-api/).
#
# ---
#
# ### (Field) Filter Type examples:

# %% [markdown]
# #### `DateRangeFilter`
#
# Find imagery that was `acquired` or `published` before, after or between certain dates.
#
# ```
# {
#   "type": "DateRangeFilter",
#   "field_name": "acquired",
#   "config": {
#     "gt": "2016-01-01T00:00:00Z",
#     "lte": "2016-03-01T00:00:00Z"
#   }
# }
# ```
#
# The upper or lower bound may be omitted.

# %% [markdown]
# #### `RangeFilter`
#
# Find imagery that has a metadata that matches a number within a range of numbers.
#
# ```
# {
#   "type": "RangeFilter",
#   "field_name": "cloud_cover",
#   "config": {
#     "lt": 0.2,
#     "gt": 0.1
#   }
# }
# ```

# %% [markdown]
# The following **operators** are supported by the Data API's `DateRangeFilter` and `RangeFilter`:
# * `gt`: Greater Than
# * `gte`: Greater Than or Equal To
# * `lt`: Less Than
# * `lte`: Less Than or Equal To

# %% [markdown]
# #### `StringInFilter`
#
# Find imagery that has a metadata that matches a string within the array of provided strings.
#
#
# ```
# {
#   "type": "StringInFilter",
#   "field_name": "instrument",
#   "config": ["PS2"]
# }
# ```

# %% [markdown]
# #### `PermissionFilter`
#
# Find data which has assets that are accessible by the user.
#
# ```
# {
#   "type": "PermissionFilter",
#   "config": ["assets.analytic:download"]
# }
# ```
#
# ***Note:*** `assets:download` means *any* downloadable asset.

# %% [markdown]
# #### `GeometryFilter`
#
# Find data contained within a given geometry. The filter's config value may be any valid GeoJSON object.
#
# ```
# {
#   "type": "GeometryFilter",
#   "field_name": "geometry",
#   "config": {
#     "type": "Polygon",
#     "coordinates": [
#       [
#         [
#           -120.27282714843749,
#           38.348118547988065
#         ],
#         [
#           -120.27282714843749,
#           38.74337300148126
#         ],
#         [
#           -119.761962890625,
#           38.74337300148126
#         ],
#         [
#           -119.761962890625,
#           38.348118547988065
#         ],
#         [
#           -120.27282714843749,
#           38.348118547988065
#         ]
#       ]
#     ]
#   }
# }
# ```
#
# A few quick ways to get a GeoJSON geometry to use in your search:
#
# * Draw an Area of Interst (AOI) in [Planet Explorer](http://planet.com/explorer), and use the API button to see the geometry filter config.
# * Use your favorite GIS tools like [Quantum GIS (QGIS)](http://www.qgis.org) and export GeoJSON.
# * Draw a polygon in [GeoJSON.io](http://geojson.io).
#
# Make sure the `config` property in the geometry filter is in the right format, which should be similar to a `feature` property in a GeoJSON object.

# %% [markdown]
# ---
#
# Let's try a few more requests and get some more stats, this time using different filters:

# %%
# Search for imagery only from PlanetScope satellites that have a PS2 telescope

# Setup item types
item_types = ["PSScene3Band"]

# Setup a filter for instrument type
instrument_filter = {
    "type": "StringInFilter",
    "field_name": "instrument",
    "config": ["PS2"]
}
print(instrument_filter)
# Out:
# {'type': 'StringInFilter', 'field_name': 'instrument', 'config': ['PS2']}

# %%
# Setup the request
request = {
    "item_types" : item_types,
    "interval" : "year",
    "filter" : instrument_filter
}

# Send the POST request to the API stats endpoint
res = session.post(stats_url, json=request)

# Print response
p(res.json())
# Out:
# {
#   "utc_offset": "+0h",
#   "interval": "year",
#   "buckets": [
#     {
#       "count": 1524094,
#       "start_time": "2015-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 29356498,
#       "start_time": "2016-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 170227294,
#       "start_time": "2017-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 11822794,
#       "start_time": "2018-01-01T00:00:00.000000Z"
#     }
#   ]
# }

# %% [markdown]
# <div class="alert alert-info">
#
# **Exercise:** Create a new filter that finds all data from PS0 or PS1 telescopes.
#
# </div>

# %%
# Fill in this filter to complete the exercise! 

instrument_filter2 = {
    "type": "StringInFilter",
    "field_name": "instrument",
    "config": ["PS0"]
}
instrument_filter3 = {
    "type": "StringInFilter",
    "field_name": "instrument",
    "config": ["PS1"]
}
or_filter = {
    "type": "OrFilter",
    "config": [instrument_filter2, instrument_filter3]
}
request = {
    "item_types" : item_types,
    "interval" : "year",
    "filter" : or_filter
}
print(or_filter)
# Send the POST request to the API stats endpoint
res=session.post(stats_url, json=request)

# Print response
p(res.json())
# Out:
# {'type': 'OrFilter', 'config': [{'type': 'StringInFilter', 'field_name': 'instrument', 'config': ['PS0']}, {'type': 'StringInFilter', 'field_name': 'instrument', 'config': ['PS1']}]}
# {
#   "utc_offset": "+0h",
#   "interval": "year",
#   "buckets": [
#     {
#       "count": 463568,
#       "start_time": "2014-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 3534243,
#       "start_time": "2015-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 3693939,
#       "start_time": "2016-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 768,
#       "start_time": "2017-01-01T00:00:00.000000Z"
#     }
#   ]
# }

# %% [markdown]
# Find a GeoJSON geometry from http://geojson.io and copy one `feature`.

# %%
# Search for imagery that only intersects with 40N, 90W

# Setup GeoJSON 
geom = {
        "type": "Polygon",
        "coordinates": [
          [
            [
              -56.76155090332031,
              -34.23564771187117
            ],
            [
              -56.62010192871094,
              -34.23564771187117
            ],
            [
              -56.62010192871094,
              -34.1476127606448
            ],
            [
              -56.76155090332031,
              -34.1476127606448
            ],
            [
              -56.76155090332031,
              -34.23564771187117
            ]
          ]
        ]
      }
    
# Setup Geometry Filter
geometry_filter = {
    "type": "GeometryFilter",
    "field_name": "geometry",
    "config":geom
}

# %%
# Setup the request
request = {
    "item_types" : item_types,
    "interval" : "month",
    "filter" : geometry_filter
}

# Send the POST request to the API stats endpoint
res=session.post(stats_url, json=request)

# Print response
p(res.json())
# Out:
# {
#   "utc_offset": "+0h",
#   "interval": "month",
#   "buckets": [
#     {
#       "count": 4,
#       "start_time": "2014-12-01T00:00:00.000000Z"
#     },
#     {
#       "count": 9,
#       "start_time": "2015-04-01T00:00:00.000000Z"
#     },
#     {
#       "count": 1,
#       "start_time": "2015-05-01T00:00:00.000000Z"
#     },
#     {
#       "count": 4,
#       "start_time": "2015-06-01T00:00:00.000000Z"
#     },
#     {
#       "count": 13,
#       "start_time": "2015-11-01T00:00:00.000000Z"
#     },
#     {
#       "count": 19,
#       "start_time": "2015-12-01T00:00:00.000000Z"
#     },
#     {
#       "count": 31,
#       "start_time": "2016-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 9,
#       "start_time": "2016-02-01T00:00:00.000000Z"
#     },
#     {
#       "count": 13,
#       "start_time": "2016-03-01T00:00:00.000000Z"
#     },
#     {
#       "count": 4,
#       "start_time": "2016-05-01T00:00:00.000000Z"
#     },
#     {
#       "count": 6,
#       "start_time": "2016-07-01T00:00:00.000000Z"
#     },
#     {
#       "count": 14,
#       "start_time": "2016-08-01T00:00:00.000000Z"
#     },
#     {
#       "count": 34,
#       "start_time": "2016-09-01T00:00:00.000000Z"
#     },
#     {
#       "count": 5,
#       "start_time": "2016-10-01T00:00:00.000000Z"
#     },
#     {
#       "count": 73,
#       "start_time": "2016-11-01T00:00:00.000000Z"
#     },
#     {
#       "count": 22,
#       "start_time": "2016-12-01T00:00:00.000000Z"
#     },
#     {
#       "count": 76,
#       "start_time": "2017-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 6,
#       "start_time": "2017-02-01T00:00:00.000000Z"
#     },
#     {
#       "count": 61,
#       "start_time": "2017-03-01T00:00:00.000000Z"
#     },
#     {
#       "count": 30,
#       "start_time": "2017-04-01T00:00:00.000000Z"
#     },
#     {
#       "count": 60,
#       "start_time": "2017-05-01T00:00:00.000000Z"
#     },
#     {
#       "count": 70,
#       "start_time": "2017-06-01T00:00:00.000000Z"
#     },
#     {
#       "count": 81,
#       "start_time": "2017-07-01T00:00:00.000000Z"
#     },
#     {
#       "count": 79,
#       "start_time": "2017-08-01T00:00:00.000000Z"
#     },
#     {
#       "count": 78,
#       "start_time": "2017-09-01T00:00:00.000000Z"
#     },
#     {
#       "count": 72,
#       "start_time": "2017-10-01T00:00:00.000000Z"
#     },
#     {
#       "count": 147,
#       "start_time": "2017-11-01T00:00:00.000000Z"
#     },
#     {
#       "count": 98,
#       "start_time": "2017-12-01T00:00:00.000000Z"
#     },
#     {
#       "count": 114,
#       "start_time": "2018-01-01T00:00:00.000000Z"
#     }
#   ]
# }

# %% [markdown]
# ### Complex Queries using Logical Filters
#
# Complex queries may require combining field filters using **logical filters** (see Filter Types above).
#
# Let's try a complex stats search:

# %%
# PS2 imagery; over 40N, 90W; captured between 2013 and present

# Setup an "AND" logical filter
and_filter = {
    "type": "AndFilter",
    "config": [instrument_filter, geometry_filter, date_filter]
}

# Print the logical filter
p(and_filter)
# Out:
# {
#   "type": "AndFilter",
#   "config": [
#     {
#       "type": "StringInFilter",
#       "field_name": "instrument",
#       "config": [
#         "PS2"
#       ]
#     },
#     {
#       "type": "GeometryFilter",
#       "field_name": "geometry",
#       "config": "POINT(-90 40)"
#     },
#     {
#       "type": "DateRangeFilter",
#       "field_name": "acquired",
#       "config": {
#         "gte": "2013-01-01T00:00:00.000Z"
#       }
#     }
#   ]
# }

# %%
# Setup the request
request = {
    "item_types" : item_types,
    "interval" : "year",
    "filter" : and_filter
}

# Send the POST request to the API stats endpoint
res=session.post(stats_url, json=request)

# Print response
p(res.json())
# Out:
# {
#   "field": {
#     "filter.config.1.config": [
#       {
#         "message": "u'POINT(-90 40)' is not of type 'object'"
#       }
#     ]
#   },
#   "general": []
# }

# %% [markdown]
# Here's another complex search query example using a "Not" logical filter and "string in" field filter. Can you tell what it's requesting?

# %%
# Setup Item Types
item_types = ["PSScene4Band"]

# Setup Instrument Filter
instrument_filter = {
    "type": "StringInFilter",
    "field_name": "instrument",
    "config": ["PS2"]
}

# Setup "not" Logical Filter
not_filter = {
    "type": "NotFilter",
    "config": instrument_filter
}

# Setup the request
request = {
    "item_types" : item_types,
    "interval" : "year",
    "filter" : not_filter
}

# Send the POST request to the API stats endpoint
res=session.post(stats_url, json=request)

# Print response
p(res.json())
# Out:
# {
#   "utc_offset": "+0h",
#   "interval": "year",
#   "buckets": []
# }

# %% [markdown]
# Now that you're comfortable working with **filters**, let's take a look at how to perform searches!

# %% [markdown]
# ## Searching for Items
#
# ---
#
# There are two types of searches:
# * **"Quick Search"** `/quick-search`
# * **"Saved Searches"** `/searches`
#
# Saved searches are retained on the Planet Platform and may be performed again at any time in the future. You can use these to setup efficient workflows for repetitive tasks, for example, querying an area that is of interest to you, or getting data for specific sensors.
#
# Quick searches are meant to be more fleeting, and are not guaranteed to be available on the API after they are executed.
#
# Searches use the same request format as the `/stats` endpoint except without the `interval` field.

# %% [markdown]
# ### Quick Search
#
# Let's dive right in and create our first `quick search`:

# %%
# Setup the quick search endpoint url
quick_url = "{}/quick-search".format(URL)

# %%
# Setup Item Types
item_types = ["PSScene4Band"]

# Setup GeoJSON for only imagery that intersects with 40N, 90W
geom = {
        "type": "Polygon",
        "coordinates": [
          [
            [
              -56.76155090332031,
              -34.23564771187117
            ],
            [
              -56.62010192871094,
              -34.23564771187117
            ],
            [
              -56.62010192871094,
              -34.1476127606448
            ],
            [
              -56.76155090332031,
              -34.1476127606448
            ],
            [
              -56.76155090332031,
              -34.23564771187117
            ]
          ]
        ]
      }

# Setup a geometry filter
geometry_filter = {
    "type": "GeometryFilter",
    "field_name": "geometry",
    "config": geom
}

# Setup the request
request = {
    "item_types" : item_types,
    "filter" : geometry_filter
}

# %%
# Send the POST request to the API quick search endpoint
res = session.post(quick_url, json=request)

# Assign the response to a variable
geojson = res.json()

# Print the response

p(geojson)
# Out:
# {
#   "_links": {
#     "_first": "https://api.planet.com/data/v1/searches/5285ebc4144b4b53b5cc93b7b08ff892/results?_page=eyJxdWVyeV9wYXJhbXMiOiB7fSwgInNvcnRfcHJldiI6IGZhbHNlLCAicGFnZV9zaXplIjogMjUwLCAic29ydF9ieSI6ICJwdWJsaXNoZWQiLCAic29ydF9zdGFydCI6IG51bGwsICJzb3J0X2xhc3RfaWQiOiBudWxsLCAic29ydF9kZXNjIjogdHJ1ZX0%3D",
#     "_next": "https://api.planet.com/data/v1/searches/5285ebc4144b4b53b5cc93b7b08ff892/results?_page=eyJxdWVyeV9wYXJhbXMiOiB7fSwgInNvcnRfcHJldiI6IGZhbHNlLCAicGFnZV9zaXplIjogMjUwLCAic29ydF9ieSI6ICJwdWJsaXNoZWQiLCAic29ydF9zdGFydCI6ICIyMDE3LTExLTIyVDE5OjIzOjM2LjAwMDAwMFoiLCAic29ydF9sYXN0X2lkIjogIjIwMTcxMTIxXzE4MDgyOF8wYzYyIiwgInNvcnRfZGVzYyI6IHRydWV9",
#     "_self": "https://api.planet.com/data/v1/searches/5285ebc4144b4b53b5cc93b7b08ff892/results?_page=eyJxdWVyeV9wYXJhbXMiOiB7fSwgInNvcnRfcHJldiI6IGZhbHNlLCAicGFnZV9zaXplIjogMjUwLCAic29ydF9ieSI6ICJwdWJsaXNoZWQiLCAic29ydF9zdGFydCI6IG51bGwsICJzb3J0X2xhc3RfaWQiOiBudWxsLCAic29ydF9kZXNjIjogdHJ1ZX0%3D"
#   },
#   "features": [
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180201_131116_1010",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180201_131116_1010/assets/",
#         "thumbnail": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180201_131116_1010/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_rpc_nitf:download",
#         "assets.analytic_xml:download",
#         "assets.basic_analytic_dn:download",
#         "assets.basic_analytic_dn_xml_nitf:download",
#         "assets.basic_analytic_dn_nitf:download",
#         "assets.basic_analytic_xml:download",
#         "assets.basic_analytic_nitf:download",
#         "assets.basic_analytic_rpc:download",
#         "assets.analytic_dn:download",
#         "assets.basic_udm:download",
#         "assets.basic_analytic_dn_rpc_nitf:download",
#         "assets.analytic:download",
#         "assets.analytic_dn_xml:download",
#         "assets.analytic_sr:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.basic_analytic_xml_nitf:download",
#         "assets.basic_analytic:download",
#         "assets.udm:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -56.615625386424966,
#               -34.183806918622516
#             ],
#             [
#               -56.33786723317663,
#               -34.233250552337985
#             ],
#             [
#               -56.356755423310865,
#               -34.308057988818035
#             ],
#             [
#               -56.63522323078925,
#               -34.25845888206757
#             ],
#             [
#               -56.61959014193289,
#               -34.197594356665185
#             ],
#             [
#               -56.61918587635708,
#               -34.19766639962155
#             ],
#             [
#               -56.615625386424966,
#               -34.183806918622516
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20180201_131116_1010",
#       "properties": {
#         "acquired": "2018-02-01T13:11:16.692604Z",
#         "anomalous_pixels": 0,
#         "cloud_cover": 0,
#         "columns": 9133,
#         "epsg_code": 32721,
#         "ground_control": true,
#         "gsd": 4,
#         "instrument": "PS2",
#         "item_type": "PSScene4Band",
#         "origin_x": 533583,
#         "origin_y": 6217398,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2018-02-01T20:27:07Z",
#         "quality_category": "standard",
#         "rows": 4633,
#         "satellite_id": "1010",
#         "strip_id": "1131676",
#         "sun_azimuth": 76.2,
#         "sun_elevation": 48.7,
#         "updated": "2018-02-02T06:01:01Z",
#         "usable_data": 0,
#         "view_angle": 0.9
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180201_131115_1010",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180201_131115_1010/assets/",
#         "thumbnail": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180201_131115_1010/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_rpc_nitf:download",
#         "assets.analytic_xml:download",
#         "assets.basic_analytic_dn:download",
#         "assets.basic_analytic_dn_xml_nitf:download",
#         "assets.basic_analytic_dn_nitf:download",
#         "assets.basic_analytic_xml:download",
#         "assets.basic_analytic_nitf:download",
#         "assets.basic_analytic_rpc:download",
#         "assets.analytic_dn:download",
#         "assets.basic_udm:download",
#         "assets.basic_analytic_dn_rpc_nitf:download",
#         "assets.analytic:download",
#         "assets.analytic_dn_xml:download",
#         "assets.analytic_sr:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.basic_analytic_xml_nitf:download",
#         "assets.basic_analytic:download",
#         "assets.udm:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -56.60284558273284,
#               -34.13406054949363
#             ],
#             [
#               -56.60230445691234,
#               -34.13200950459736
#             ],
#             [
#               -56.60185946568261,
#               -34.132088856721985
#             ],
#             [
#               -56.59840020732965,
#               -34.11860049144714
#             ],
#             [
#               -56.320778792313284,
#               -34.168056514690875
#             ],
#             [
#               -56.33958508972384,
#               -34.242536440143844
#             ],
#             [
#               -56.33966830007299,
#               -34.24285658410206
#             ],
#             [
#               -56.618050476671854,
#               -34.19324676899103
#             ],
#             [
#               -56.60284558273284,
#               -34.13406054949363
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20180201_131115_1010",
#       "properties": {
#         "acquired": "2018-02-01T13:11:15.649461Z",
#         "anomalous_pixels": 0,
#         "cloud_cover": 0.01,
#         "columns": 9137,
#         "epsg_code": 32721,
#         "ground_control": true,
#         "gsd": 4,
#         "instrument": "PS2",
#         "item_type": "PSScene4Band",
#         "origin_x": 535191,
#         "origin_y": 6224622,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2018-02-01T20:27:07Z",
#         "quality_category": "standard",
#         "rows": 4635,
#         "satellite_id": "1010",
#         "strip_id": "1131676",
#         "sun_azimuth": 76.3,
#         "sun_elevation": 48.8,
#         "updated": "2018-02-02T06:01:34Z",
#         "usable_data": 0,
#         "view_angle": 0.9
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180201_131231_1009",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180201_131231_1009/assets/",
#         "thumbnail": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180201_131231_1009/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_rpc_nitf:download",
#         "assets.analytic_xml:download",
#         "assets.basic_analytic_dn:download",
#         "assets.basic_analytic_dn_xml_nitf:download",
#         "assets.basic_analytic_dn_nitf:download",
#         "assets.basic_analytic_xml:download",
#         "assets.basic_analytic_nitf:download",
#         "assets.basic_analytic_rpc:download",
#         "assets.analytic_dn:download",
#         "assets.basic_udm:download",
#         "assets.basic_analytic_dn_rpc_nitf:download",
#         "assets.analytic:download",
#         "assets.analytic_dn_xml:download",
#         "assets.analytic_sr:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.basic_analytic_xml_nitf:download",
#         "assets.basic_analytic:download",
#         "assets.udm:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -56.66398638425575,
#               -34.31312379967587
#             ],
#             [
#               -56.9455091732384,
#               -34.26292565003318
#             ],
#             [
#               -56.92554135024568,
#               -34.18743195740864
#             ],
#             [
#               -56.64465039926028,
#               -34.237454305940446
#             ],
#             [
#               -56.648427100531315,
#               -34.25199447871847
#             ],
#             [
#               -56.648092033329945,
#               -34.252054233277455
#             ],
#             [
#               -56.66398638425575,
#               -34.31312379967587
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20180201_131231_1009",
#       "properties": {
#         "acquired": "2018-02-01T13:12:31.920018Z",
#         "anomalous_pixels": 0,
#         "cloud_cover": 0,
#         "columns": 9237,
#         "epsg_code": 32721,
#         "ground_control": true,
#         "gsd": 4,
#         "instrument": "PS2",
#         "item_type": "PSScene4Band",
#         "origin_x": 505014,
#         "origin_y": 6217062,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2018-02-01T20:14:07Z",
#         "quality_category": "standard",
#         "rows": 4663,
#         "satellite_id": "1009",
#         "strip_id": "1131669",
#         "sun_azimuth": 76.2,
#         "sun_elevation": 48.7,
#         "updated": "2018-02-02T05:51:23Z",
#         "usable_data": 0,
#         "view_angle": 0.9
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180201_131230_1009",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180201_131230_1009/assets/",
#         "thumbnail": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180201_131230_1009/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_rpc_nitf:download",
#         "assets.analytic_xml:download",
#         "assets.basic_analytic_dn:download",
#         "assets.basic_analytic_dn_xml_nitf:download",
#         "assets.basic_analytic_dn_nitf:download",
#         "assets.basic_analytic_xml:download",
#         "assets.basic_analytic_nitf:download",
#         "assets.basic_analytic_rpc:download",
#         "assets.analytic_dn:download",
#         "assets.basic_udm:download",
#         "assets.basic_analytic_dn_rpc_nitf:download",
#         "assets.analytic:download",
#         "assets.analytic_dn_xml:download",
#         "assets.analytic_sr:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.basic_analytic_xml_nitf:download",
#         "assets.basic_analytic:download",
#         "assets.udm:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -56.925334775383526,
#               -34.18367806787532
#             ],
#             [
#               -56.91285457753154,
#               -34.13636906196142
#             ],
#             [
#               -56.91257902881331,
#               -34.13641818140561
#             ],
#             [
#               -56.90883936947936,
#               -34.121797019956674
#             ],
#             [
#               -56.62782600944315,
#               -34.171853104359165
#             ],
#             [
#               -56.63527626137336,
#               -34.20136419058874
#             ],
#             [
#               -56.64726482826627,
#               -34.24751976961759
#             ],
#             [
#               -56.92882542042391,
#               -34.19730942876647
#             ],
#             [
#               -56.925334775383526,
#               -34.18367806787532
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20180201_131230_1009",
#       "properties": {
#         "acquired": "2018-02-01T13:12:30.876804Z",
#         "anomalous_pixels": 0,
#         "cloud_cover": 0,
#         "columns": 9249,
#         "epsg_code": 32721,
#         "ground_control": true,
#         "gsd": 4,
#         "instrument": "PS2",
#         "item_type": "PSScene4Band",
#         "origin_x": 506556,
#         "origin_y": 6224337,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2018-02-01T20:14:07Z",
#         "quality_category": "standard",
#         "rows": 4665,
#         "satellite_id": "1009",
#         "strip_id": "1131669",
#         "sun_azimuth": 76.3,
#         "sun_elevation": 48.8,
#         "updated": "2018-02-02T05:53:07Z",
#         "usable_data": 0,
#         "view_angle": 0.8
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180201_131229_1009",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180201_131229_1009/assets/",
#         "thumbnail": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180201_131229_1009/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_rpc_nitf:download",
#         "assets.analytic_xml:download",
#         "assets.basic_analytic_dn:download",
#         "assets.basic_analytic_dn_xml_nitf:download",
#         "assets.basic_analytic_dn_nitf:download",
#         "assets.basic_analytic_xml:download",
#         "assets.basic_analytic_nitf:download",
#         "assets.basic_analytic_rpc:download",
#         "assets.analytic_dn:download",
#         "assets.basic_udm:download",
#         "assets.basic_analytic_dn_rpc_nitf:download",
#         "assets.analytic:download",
#         "assets.analytic_dn_xml:download",
#         "assets.analytic_sr:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.basic_analytic_xml_nitf:download",
#         "assets.basic_analytic:download",
#         "assets.udm:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -56.89164712968119,
#               -34.05641280103749
#             ],
#             [
#               -56.61120313535137,
#               -34.10634338452111
#             ],
#             [
#               -56.63027753646029,
#               -34.18206131268084
#             ],
#             [
#               -56.91143534934812,
#               -34.13194667194094
#             ],
#             [
#               -56.89581900052496,
#               -34.07089053366828
#             ],
#             [
#               -56.89536986895092,
#               -34.070970580331796
#             ],
#             [
#               -56.89164712968119,
#               -34.05641280103749
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20180201_131229_1009",
#       "properties": {
#         "acquired": "2018-02-01T13:12:29.83359Z",
#         "anomalous_pixels": 0,
#         "cloud_cover": 0,
#         "columns": 9232,
#         "epsg_code": 32721,
#         "ground_control": true,
#         "gsd": 4,
#         "instrument": "PS2",
#         "item_type": "PSScene4Band",
#         "origin_x": 508164,
#         "origin_y": 6231585,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2018-02-01T20:14:07Z",
#         "quality_category": "standard",
#         "rows": 4664,
#         "satellite_id": "1009",
#         "strip_id": "1131669",
#         "sun_azimuth": 76.3,
#         "sun_elevation": 48.8,
#         "updated": "2018-02-02T05:52:48Z",
#         "usable_data": 0,
#         "view_angle": 0.9
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180131_131223_0f31",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180131_131223_0f31/assets/",
#         "thumbnail": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180131_131223_0f31/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_rpc_nitf:download",
#         "assets.analytic_xml:download",
#         "assets.basic_analytic_dn:download",
#         "assets.basic_analytic_dn_xml_nitf:download",
#         "assets.basic_analytic_dn_nitf:download",
#         "assets.basic_analytic_xml:download",
#         "assets.basic_analytic_nitf:download",
#         "assets.basic_analytic_rpc:download",
#         "assets.analytic_dn:download",
#         "assets.basic_udm:download",
#         "assets.basic_analytic_dn_rpc_nitf:download",
#         "assets.analytic:download",
#         "assets.analytic_dn_xml:download",
#         "assets.analytic_sr:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.basic_analytic_xml_nitf:download",
#         "assets.basic_analytic:download",
#         "assets.udm:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -56.7947377204834,
#               -34.21513524133518
#             ],
#             [
#               -56.78339012548609,
#               -34.17224068048865
#             ],
#             [
#               -56.50389985109966,
#               -34.222148158643
#             ],
#             [
#               -56.507568169705294,
#               -34.23623396603748
#             ],
#             [
#               -56.50726128706243,
#               -34.236288786339266
#             ],
#             [
#               -56.51383369056951,
#               -34.262227784781494
#             ],
#             [
#               -56.52301457402581,
#               -34.29736305297373
#             ],
#             [
#               -56.80300337224703,
#               -34.247334677170905
#             ],
#             [
#               -56.7947377204834,
#               -34.21513524133518
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20180131_131223_0f31",
#       "properties": {
#         "acquired": "2018-01-31T13:12:23.790854Z",
#         "anomalous_pixels": 0,
#         "cloud_cover": 0.01,
#         "columns": 9186,
#         "epsg_code": 32721,
#         "ground_control": true,
#         "gsd": 4,
#         "instrument": "PS2",
#         "item_type": "PSScene4Band",
#         "origin_x": 518139,
#         "origin_y": 6218727,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2018-01-31T16:20:18Z",
#         "quality_category": "standard",
#         "rows": 4653,
#         "satellite_id": "0f31",
#         "strip_id": "1128219",
#         "sun_azimuth": 76.5,
#         "sun_elevation": 49,
#         "updated": "2018-02-01T05:02:06Z",
#         "usable_data": 0,
#         "view_angle": 0.8
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180131_131222_0f31",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180131_131222_0f31/assets/",
#         "thumbnail": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180131_131222_0f31/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_rpc_nitf:download",
#         "assets.analytic_xml:download",
#         "assets.basic_analytic_dn:download",
#         "assets.basic_analytic_dn_xml_nitf:download",
#         "assets.basic_analytic_dn_nitf:download",
#         "assets.basic_analytic_xml:download",
#         "assets.basic_analytic_nitf:download",
#         "assets.basic_analytic_rpc:download",
#         "assets.analytic_dn:download",
#         "assets.basic_udm:download",
#         "assets.basic_analytic_dn_rpc_nitf:download",
#         "assets.analytic:download",
#         "assets.analytic_dn_xml:download",
#         "assets.analytic_sr:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.basic_analytic_xml_nitf:download",
#         "assets.basic_analytic:download",
#         "assets.udm:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -56.50641049684766,
#               -34.2317886714348
#             ],
#             [
#               -56.78617100001118,
#               -34.18181545366873
#             ],
#             [
#               -56.76637991774405,
#               -34.106738571438875
#             ],
#             [
#               -56.48788126757913,
#               -34.1564600148661
#             ],
#             [
#               -56.491605002593495,
#               -34.17076433984277
#             ],
#             [
#               -56.490566448668254,
#               -34.17094984171557
#             ],
#             [
#               -56.50641049684766,
#               -34.2317886714348
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20180131_131222_0f31",
#       "properties": {
#         "acquired": "2018-01-31T13:12:22.747435Z",
#         "anomalous_pixels": 0,
#         "cloud_cover": 0.06,
#         "columns": 9169,
#         "epsg_code": 32721,
#         "ground_control": true,
#         "gsd": 4,
#         "instrument": "PS2",
#         "item_type": "PSScene4Band",
#         "origin_x": 519702,
#         "origin_y": 6225987,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2018-01-31T16:20:18Z",
#         "quality_category": "standard",
#         "rows": 4652,
#         "satellite_id": "0f31",
#         "strip_id": "1128219",
#         "sun_azimuth": 76.5,
#         "sun_elevation": 49,
#         "updated": "2018-02-01T05:02:22Z",
#         "usable_data": 0,
#         "view_angle": 0.9
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180130_131148_1004",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180130_131148_1004/assets/",
#         "thumbnail": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180130_131148_1004/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_rpc_nitf:download",
#         "assets.analytic_xml:download",
#         "assets.basic_analytic_dn:download",
#         "assets.basic_analytic_dn_xml_nitf:download",
#         "assets.basic_analytic_dn_nitf:download",
#         "assets.basic_analytic_xml:download",
#         "assets.basic_analytic_nitf:download",
#         "assets.basic_analytic_rpc:download",
#         "assets.analytic_dn:download",
#         "assets.basic_udm:download",
#         "assets.basic_analytic_dn_rpc_nitf:download",
#         "assets.analytic:download",
#         "assets.analytic_dn_xml:download",
#         "assets.analytic_sr:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.basic_analytic_xml_nitf:download",
#         "assets.basic_analytic:download",
#         "assets.udm:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -56.666912787043046,
#               -34.203332486625655
#             ],
#             [
#               -56.38716315056227,
#               -34.25266018520562
#             ],
#             [
#               -56.40599677616552,
#               -34.327860578723296
#             ],
#             [
#               -56.686049809970164,
#               -34.27844177960515
#             ],
#             [
#               -56.67105507637081,
#               -34.21961013865297
#             ],
#             [
#               -56.666912787043046,
#               -34.203332486625655
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20180130_131148_1004",
#       "properties": {
#         "acquired": "2018-01-30T13:11:48.140067Z",
#         "anomalous_pixels": 0,
#         "cloud_cover": 0,
#         "columns": 9177,
#         "epsg_code": 32721,
#         "ground_control": true,
#         "gsd": 4,
#         "instrument": "PS2",
#         "item_type": "PSScene4Band",
#         "origin_x": 528897,
#         "origin_y": 6215250,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2018-01-30T22:23:20Z",
#         "quality_category": "standard",
#         "rows": 4640,
#         "satellite_id": "1004",
#         "strip_id": "1125593",
#         "sun_azimuth": 76.8,
#         "sun_elevation": 49.1,
#         "updated": "2018-01-31T05:37:17Z",
#         "usable_data": 0,
#         "view_angle": 0.9
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180130_131147_1004",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180130_131147_1004/assets/",
#         "thumbnail": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180130_131147_1004/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_rpc_nitf:download",
#         "assets.analytic_xml:download",
#         "assets.basic_analytic_dn:download",
#         "assets.basic_analytic_dn_xml_nitf:download",
#         "assets.basic_analytic_dn_nitf:download",
#         "assets.basic_analytic_xml:download",
#         "assets.basic_analytic_nitf:download",
#         "assets.basic_analytic_rpc:download",
#         "assets.analytic_dn:download",
#         "assets.basic_udm:download",
#         "assets.basic_analytic_dn_rpc_nitf:download",
#         "assets.analytic:download",
#         "assets.analytic_dn_xml:download",
#         "assets.analytic_sr:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.basic_analytic_xml_nitf:download",
#         "assets.basic_analytic:download",
#         "assets.udm:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -56.38943261463752,
#               -34.262083871112985
#             ],
#             [
#               -56.66927829316187,
#               -34.21270116864747
#             ],
#             [
#               -56.649647435801356,
#               -34.13768450042133
#             ],
#             [
#               -56.37102472361005,
#               -34.18682851851244
#             ],
#             [
#               -56.37455288222498,
#               -34.20052173126513
#             ],
#             [
#               -56.37359901053233,
#               -34.200690214086556
#             ],
#             [
#               -56.38943261463752,
#               -34.262083871112985
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20180130_131147_1004",
#       "properties": {
#         "acquired": "2018-01-30T13:11:47.096174Z",
#         "anomalous_pixels": 0,
#         "cloud_cover": 0,
#         "columns": 9165,
#         "epsg_code": 32721,
#         "ground_control": true,
#         "gsd": 4,
#         "instrument": "PS2",
#         "item_type": "PSScene4Band",
#         "origin_x": 530463,
#         "origin_y": 6222525,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2018-01-30T22:23:20Z",
#         "quality_category": "standard",
#         "rows": 4637,
#         "satellite_id": "1004",
#         "strip_id": "1125593",
#         "sun_azimuth": 76.9,
#         "sun_elevation": 49.2,
#         "updated": "2018-01-31T05:37:21Z",
#         "usable_data": 0,
#         "view_angle": 0.9
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180130_131146_1004",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180130_131146_1004/assets/",
#         "thumbnail": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180130_131146_1004/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_rpc_nitf:download",
#         "assets.analytic_xml:download",
#         "assets.basic_analytic_dn:download",
#         "assets.basic_analytic_dn_xml_nitf:download",
#         "assets.basic_analytic_dn_nitf:download",
#         "assets.basic_analytic_xml:download",
#         "assets.basic_analytic_nitf:download",
#         "assets.basic_analytic_rpc:download",
#         "assets.analytic_dn:download",
#         "assets.basic_udm:download",
#         "assets.basic_analytic_dn_rpc_nitf:download",
#         "assets.analytic:download",
#         "assets.analytic_dn_xml:download",
#         "assets.analytic_sr:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.basic_analytic_xml_nitf:download",
#         "assets.basic_analytic:download",
#         "assets.udm:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -56.373408368954216,
#               -34.196079736041746
#             ],
#             [
#               -56.65250757258475,
#               -34.146782328566076
#             ],
#             [
#               -56.632906486000955,
#               -34.071760109645986
#             ],
#             [
#               -56.35447550692305,
#               -34.12093383161428
#             ],
#             [
#               -56.35801811490903,
#               -34.13470670717376
#             ],
#             [
#               -56.35761358026134,
#               -34.13477823983357
#             ],
#             [
#               -56.373408368954216,
#               -34.196079736041746
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20180130_131146_1004",
#       "properties": {
#         "acquired": "2018-01-30T13:11:46.052281Z",
#         "anomalous_pixels": 0,
#         "cloud_cover": 0,
#         "columns": 9166,
#         "epsg_code": 32721,
#         "ground_control": true,
#         "gsd": 4,
#         "instrument": "PS2",
#         "item_type": "PSScene4Band",
#         "origin_x": 532032,
#         "origin_y": 6229827,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2018-01-30T22:23:20Z",
#         "quality_category": "standard",
#         "rows": 4634,
#         "satellite_id": "1004",
#         "strip_id": "1125593",
#         "sun_azimuth": 77,
#         "sun_elevation": 49.2,
#         "updated": "2018-01-31T05:37:04Z",
#         "usable_data": 0,
#         "view_angle": 0.9
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180129_131220_1015",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180129_131220_1015/assets/",
#         "thumbnail": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180129_131220_1015/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_rpc_nitf:download",
#         "assets.analytic_xml:download",
#         "assets.basic_analytic_dn:download",
#         "assets.basic_analytic_dn_xml_nitf:download",
#         "assets.basic_analytic_dn_nitf:download",
#         "assets.basic_analytic_xml:download",
#         "assets.basic_analytic_nitf:download",
#         "assets.basic_analytic_rpc:download",
#         "assets.analytic_dn:download",
#         "assets.basic_udm:download",
#         "assets.basic_analytic_dn_rpc_nitf:download",
#         "assets.analytic:download",
#         "assets.analytic_dn_xml:download",
#         "assets.analytic_sr:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.basic_analytic_xml_nitf:download",
#         "assets.basic_analytic:download",
#         "assets.udm:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -56.9961442121776,
#               -34.16896562183249
#             ],
#             [
#               -56.9939974545664,
#               -34.16089125214214
#             ],
#             [
#               -56.71670277299292,
#               -34.21055233676148
#             ],
#             [
#               -56.72176032039084,
#               -34.23052884348403
#             ],
#             [
#               -56.722112130091126,
#               -34.231878576739696
#             ],
#             [
#               -56.7221709923682,
#               -34.231868076922595
#             ],
#             [
#               -56.73603859866528,
#               -34.28502270981482
#             ],
#             [
#               -57.01381107902075,
#               -34.23541411765601
#             ],
#             [
#               -56.99756763601655,
#               -34.17431939360525
#             ],
#             [
#               -56.997523103663454,
#               -34.17432735120425
#             ],
#             [
#               -56.9961442121776,
#               -34.16896562183249
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20180129_131220_1015",
#       "properties": {
#         "acquired": "2018-01-29T13:12:20.374287Z",
#         "anomalous_pixels": 0,
#         "cloud_cover": 0,
#         "columns": 9124,
#         "epsg_code": 32721,
#         "ground_control": true,
#         "gsd": 4,
#         "instrument": "PS2",
#         "item_type": "PSScene4Band",
#         "origin_x": 498726,
#         "origin_y": 6220005,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2018-01-29T18:07:46Z",
#         "quality_category": "standard",
#         "rows": 4599,
#         "satellite_id": "1015",
#         "strip_id": "1121931",
#         "sun_azimuth": 77.2,
#         "sun_elevation": 49.3,
#         "updated": "2018-01-30T06:53:10Z",
#         "usable_data": 0,
#         "view_angle": 2
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180129_131219_1015",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180129_131219_1015/assets/",
#         "thumbnail": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180129_131219_1015/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_rpc_nitf:download",
#         "assets.analytic_xml:download",
#         "assets.basic_analytic_dn:download",
#         "assets.basic_analytic_dn_xml_nitf:download",
#         "assets.basic_analytic_dn_nitf:download",
#         "assets.basic_analytic_xml:download",
#         "assets.basic_analytic_nitf:download",
#         "assets.basic_analytic_rpc:download",
#         "assets.analytic_dn:download",
#         "assets.basic_udm:download",
#         "assets.basic_analytic_dn_rpc_nitf:download",
#         "assets.analytic:download",
#         "assets.analytic_dn_xml:download",
#         "assets.analytic_sr:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.basic_analytic_xml_nitf:download",
#         "assets.basic_analytic:download",
#         "assets.udm:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -56.97658131620768,
#               -34.095392111004344
#             ],
#             [
#               -56.700088985146316,
#               -34.14494998426129
#             ],
#             [
#               -56.71896024399647,
#               -34.21949498832577
#             ],
#             [
#               -56.99638754822246,
#               -34.16991181813027
#             ],
#             [
#               -56.98061666344574,
#               -34.10858776399468
#             ],
#             [
#               -56.97999043337911,
#               -34.10869978226466
#             ],
#             [
#               -56.97658131620768,
#               -34.095392111004344
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20180129_131219_1015",
#       "properties": {
#         "acquired": "2018-01-29T13:12:19.330087Z",
#         "anomalous_pixels": 0.01,
#         "cloud_cover": 0,
#         "columns": 9107,
#         "epsg_code": 32721,
#         "ground_control": true,
#         "gsd": 4,
#         "instrument": "PS2",
#         "item_type": "PSScene4Band",
#         "origin_x": 500331,
#         "origin_y": 6227268,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2018-01-29T18:07:46Z",
#         "quality_category": "standard",
#         "rows": 4600,
#         "satellite_id": "1015",
#         "strip_id": "1121931",
#         "sun_azimuth": 77.2,
#         "sun_elevation": 49.4,
#         "updated": "2018-01-30T06:53:57Z",
#         "usable_data": 0,
#         "view_angle": 1.9
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180129_131218_1015",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180129_131218_1015/assets/",
#         "thumbnail": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180129_131218_1015/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_rpc_nitf:download",
#         "assets.analytic_xml:download",
#         "assets.basic_analytic_dn:download",
#         "assets.basic_analytic_dn_xml_nitf:download",
#         "assets.basic_analytic_dn_nitf:download",
#         "assets.basic_analytic_xml:download",
#         "assets.basic_analytic_nitf:download",
#         "assets.basic_analytic_rpc:download",
#         "assets.analytic_dn:download",
#         "assets.basic_udm:download",
#         "assets.basic_analytic_dn_rpc_nitf:download",
#         "assets.analytic:download",
#         "assets.analytic_dn_xml:download",
#         "assets.analytic_sr:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.basic_analytic_xml_nitf:download",
#         "assets.basic_analytic:download",
#         "assets.udm:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -56.959443337592795,
#               -34.02972052010821
#             ],
#             [
#               -56.68291038554012,
#               -34.07929789262386
#             ],
#             [
#               -56.70178935899277,
#               -34.15385334577892
#             ],
#             [
#               -56.978860977596206,
#               -34.10429089119223
#             ],
#             [
#               -56.96306636164588,
#               -34.04263576284655
#             ],
#             [
#               -56.96276207482631,
#               -34.04269020092455
#             ],
#             [
#               -56.959443337592795,
#               -34.02972052010821
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20180129_131218_1015",
#       "properties": {
#         "acquired": "2018-01-29T13:12:18.285887Z",
#         "anomalous_pixels": 0.01,
#         "cloud_cover": 0,
#         "columns": 9103,
#         "epsg_code": 32721,
#         "ground_control": true,
#         "gsd": 4,
#         "instrument": "PS2",
#         "item_type": "PSScene4Band",
#         "origin_x": 501948,
#         "origin_y": 6234549,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2018-01-29T18:07:46Z",
#         "quality_category": "standard",
#         "rows": 4602,
#         "satellite_id": "1015",
#         "strip_id": "1121931",
#         "sun_azimuth": 77.3,
#         "sun_elevation": 49.4,
#         "updated": "2018-01-30T06:56:13Z",
#         "usable_data": 0,
#         "view_angle": 2
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180128_131305_1018",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180128_131305_1018/assets/",
#         "thumbnail": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180128_131305_1018/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_rpc_nitf:download",
#         "assets.analytic_xml:download",
#         "assets.basic_analytic_dn:download",
#         "assets.basic_analytic_dn_xml_nitf:download",
#         "assets.basic_analytic_dn_nitf:download",
#         "assets.basic_analytic_xml:download",
#         "assets.basic_analytic_nitf:download",
#         "assets.basic_analytic_rpc:download",
#         "assets.analytic_dn:download",
#         "assets.basic_udm:download",
#         "assets.basic_analytic_dn_rpc_nitf:download",
#         "assets.analytic:download",
#         "assets.analytic_dn_xml:download",
#         "assets.analytic_sr:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.basic_analytic_xml_nitf:download",
#         "assets.basic_analytic:download",
#         "assets.udm:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -56.92668955459149,
#               -34.08394300200841
#             ],
#             [
#               -56.9189435292859,
#               -34.05439262093109
#             ],
#             [
#               -56.91871099798073,
#               -34.054433886471216
#             ],
#             [
#               -56.915678612927806,
#               -34.04254013107091
#             ],
#             [
#               -56.639038966568876,
#               -34.09181253745107
#             ],
#             [
#               -56.653369355691325,
#               -34.14895740266164
#             ],
#             [
#               -56.65764446000078,
#               -34.165494444500204
#             ],
#             [
#               -56.93489274823967,
#               -34.11603748081309
#             ],
#             [
#               -56.92668955459149,
#               -34.08394300200841
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20180128_131305_1018",
#       "properties": {
#         "acquired": "2018-01-28T13:13:05.295724Z",
#         "anomalous_pixels": 0,
#         "cloud_cover": 0.61,
#         "columns": 9099,
#         "epsg_code": 32721,
#         "ground_control": true,
#         "gsd": 4,
#         "instrument": "PS2",
#         "item_type": "PSScene4Band",
#         "origin_x": 506004,
#         "origin_y": 6233127,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2018-01-29T02:11:55Z",
#         "quality_category": "standard",
#         "rows": 4562,
#         "satellite_id": "1018",
#         "strip_id": "1118676",
#         "sun_azimuth": 77.6,
#         "sun_elevation": 49.6,
#         "updated": "2018-01-29T06:23:03Z",
#         "usable_data": 0,
#         "view_angle": 0.9
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180128_131115_1003",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180128_131115_1003/assets/",
#         "thumbnail": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180128_131115_1003/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_rpc_nitf:download",
#         "assets.analytic_xml:download",
#         "assets.basic_analytic_dn:download",
#         "assets.basic_analytic_dn_xml_nitf:download",
#         "assets.basic_analytic_dn_nitf:download",
#         "assets.basic_analytic_xml:download",
#         "assets.basic_analytic_nitf:download",
#         "assets.basic_analytic_rpc:download",
#         "assets.analytic_dn:download",
#         "assets.basic_udm:download",
#         "assets.basic_analytic_dn_rpc_nitf:download",
#         "assets.analytic:download",
#         "assets.analytic_dn_xml:download",
#         "assets.analytic_sr:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.basic_analytic_xml_nitf:download",
#         "assets.basic_analytic:download",
#         "assets.udm:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -56.686007019655136,
#               -34.20748502261133
#             ],
#             [
#               -56.4091413345371,
#               -34.25658233626045
#             ],
#             [
#               -56.42770227755829,
#               -34.331068538005724
#             ],
#             [
#               -56.706123366483325,
#               -34.281599936348606
#             ],
#             [
#               -56.69050088735879,
#               -34.22041706968858
#             ],
#             [
#               -56.68936574927178,
#               -34.220618316661934
#             ],
#             [
#               -56.686007019655136,
#               -34.20748502261133
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20180128_131115_1003",
#       "properties": {
#         "acquired": "2018-01-28T13:11:15.080472Z",
#         "anomalous_pixels": 0,
#         "cloud_cover": 0.59,
#         "columns": 9118,
#         "epsg_code": 32721,
#         "ground_control": true,
#         "gsd": 4,
#         "instrument": "PS2",
#         "item_type": "PSScene4Band",
#         "origin_x": 527049,
#         "origin_y": 6214794,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2018-01-29T00:27:44Z",
#         "quality_category": "standard",
#         "rows": 4603,
#         "satellite_id": "1003",
#         "strip_id": "1118674",
#         "sun_azimuth": 77.6,
#         "sun_elevation": 49.4,
#         "updated": "2018-01-29T05:41:44Z",
#         "usable_data": 0,
#         "view_angle": 0.9
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180128_131114_1003",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180128_131114_1003/assets/",
#         "thumbnail": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180128_131114_1003/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_rpc_nitf:download",
#         "assets.analytic_xml:download",
#         "assets.basic_analytic_dn:download",
#         "assets.basic_analytic_dn_xml_nitf:download",
#         "assets.basic_analytic_dn_nitf:download",
#         "assets.basic_analytic_xml:download",
#         "assets.basic_analytic_nitf:download",
#         "assets.basic_analytic_rpc:download",
#         "assets.analytic_dn:download",
#         "assets.basic_udm:download",
#         "assets.basic_analytic_dn_rpc_nitf:download",
#         "assets.analytic:download",
#         "assets.analytic_dn_xml:download",
#         "assets.analytic_sr:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.basic_analytic_xml_nitf:download",
#         "assets.basic_analytic:download",
#         "assets.udm:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -56.668510854825,
#               -34.141766134129355
#             ],
#             [
#               -56.39167673173806,
#               -34.19078086450598
#             ],
#             [
#               -56.41041875930485,
#               -34.265450131136035
#             ],
#             [
#               -56.688237113713384,
#               -34.216205129428616
#             ],
#             [
#               -56.67250882975506,
#               -34.15470444264741
#             ],
#             [
#               -56.67184599984407,
#               -34.15482205836772
#             ],
#             [
#               -56.668510854825,
#               -34.141766134129355
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20180128_131114_1003",
#       "properties": {
#         "acquired": "2018-01-28T13:11:14.036825Z",
#         "anomalous_pixels": 0,
#         "cloud_cover": 0.66,
#         "columns": 9112,
#         "epsg_code": 32721,
#         "ground_control": true,
#         "gsd": 4,
#         "instrument": "PS2",
#         "item_type": "PSScene4Band",
#         "origin_x": 528717,
#         "origin_y": 6222078,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2018-01-29T00:27:44Z",
#         "quality_category": "standard",
#         "rows": 4609,
#         "satellite_id": "1003",
#         "strip_id": "1118674",
#         "sun_azimuth": 77.6,
#         "sun_elevation": 49.4,
#         "updated": "2018-01-29T05:41:54Z",
#         "usable_data": 0,
#         "view_angle": 0.9
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180128_131112_1003",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180128_131112_1003/assets/",
# ...
#         "assets.basic_analytic_dn_rpc_nitf:download",
#         "assets.analytic:download",
#         "assets.analytic_dn_xml:download",
#         "assets.analytic_sr:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.basic_analytic_xml_nitf:download",
#         "assets.basic_analytic:download",
#         "assets.udm:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -56.71068302078693,
#               -34.242377959078816
#             ],
#             [
#               -56.97666963603816,
#               -34.28806800096801
#             ],
#             [
#               -56.994105303760755,
#               -34.216637070760214
#             ],
#             [
#               -56.72906643971789,
#               -34.17083439721644
#             ],
#             [
#               -56.72517678824632,
#               -34.186505505262716
#             ],
#             [
#               -56.72456965056175,
#               -34.18640126714726
#             ],
#             [
#               -56.71068302078693,
#               -34.242377959078816
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20171119_151550_101c",
#       "properties": {
#         "acquired": "2017-11-19T15:15:50.232599Z",
#         "anomalous_pixels": 0,
#         "cloud_cover": 0.01,
#         "columns": 8701,
#         "epsg_code": 32721,
#         "ground_control": true,
#         "gsd": 3.8,
#         "instrument": "PS2",
#         "item_type": "PSScene4Band",
#         "origin_x": 500541,
#         "origin_y": 6218871,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2017-11-22T21:55:00Z",
#         "quality_category": "standard",
#         "rows": 4323,
#         "satellite_id": "101c",
#         "strip_id": "926997",
#         "sun_azimuth": 16.8,
#         "sun_elevation": 74.7,
#         "updated": "2017-11-22T21:55:00Z",
#         "usable_data": 0,
#         "view_angle": 4
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20171119_151549_101c",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20171119_151549_101c/assets/",
#         "thumbnail": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20171119_151549_101c/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_rpc_nitf:download",
#         "assets.analytic_xml:download",
#         "assets.basic_analytic_dn:download",
#         "assets.basic_analytic_dn_xml_nitf:download",
#         "assets.basic_analytic_dn_nitf:download",
#         "assets.basic_analytic_xml:download",
#         "assets.basic_analytic_nitf:download",
#         "assets.basic_analytic_rpc:download",
#         "assets.analytic_dn:download",
#         "assets.basic_udm:download",
#         "assets.basic_analytic_dn_rpc_nitf:download",
#         "assets.analytic:download",
#         "assets.analytic_dn_xml:download",
#         "assets.analytic_sr:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.basic_analytic_xml_nitf:download",
#         "assets.basic_analytic:download",
#         "assets.udm:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -56.694978869608995,
#               -34.30285970119888
#             ],
#             [
#               -56.96127858035081,
#               -34.348567828262105
#             ],
#             [
#               -56.97868920355098,
#               -34.27712969700954
#             ],
#             [
#               -56.7134231568484,
#               -34.231332532315776
#             ],
#             [
#               -56.70950218956422,
#               -34.247137863148346
#             ],
#             [
#               -56.708855785244204,
#               -34.247026873336566
#             ],
#             [
#               -56.694978869608995,
#               -34.30285970119888
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20171119_151549_101c",
#       "properties": {
#         "acquired": "2017-11-19T15:15:49.269256Z",
#         "anomalous_pixels": 0,
#         "cloud_cover": 0,
#         "columns": 8703,
#         "epsg_code": 32721,
#         "ground_control": true,
#         "gsd": 3.8,
#         "instrument": "PS2",
#         "item_type": "PSScene4Band",
#         "origin_x": 501960,
#         "origin_y": 6212157,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2017-11-22T21:55:00Z",
#         "quality_category": "standard",
#         "rows": 4322,
#         "satellite_id": "101c",
#         "strip_id": "926997",
#         "sun_azimuth": 16.7,
#         "sun_elevation": 74.7,
#         "updated": "2017-11-22T21:55:00Z",
#         "usable_data": 0,
#         "view_angle": 4
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20171119_094435_1_0c81",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20171119_094435_1_0c81/assets/",
#         "thumbnail": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20171119_094435_1_0c81/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_rpc_nitf:download",
#         "assets.analytic_xml:download",
#         "assets.basic_analytic_dn:download",
#         "assets.basic_analytic_dn_xml_nitf:download",
#         "assets.basic_analytic_dn_nitf:download",
#         "assets.basic_analytic_xml:download",
#         "assets.basic_analytic_nitf:download",
#         "assets.basic_analytic_rpc:download",
#         "assets.analytic_dn:download",
#         "assets.basic_udm:download",
#         "assets.basic_analytic_dn_rpc_nitf:download",
#         "assets.analytic:download",
#         "assets.analytic_dn_xml:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.basic_analytic_xml_nitf:download",
#         "assets.basic_analytic:download",
#         "assets.udm:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -56.655260722448524,
#               -34.20233787844224
#             ],
#             [
#               -56.52725294096364,
#               -34.087418894473785
#             ],
#             [
#               -56.484776466279,
#               -34.119624597592946
#             ],
#             [
#               -56.613440443243014,
#               -34.235292079658315
#             ],
#             [
#               -56.64264914752344,
#               -34.21324246526813
#             ],
#             [
#               -56.64181117973048,
#               -34.2124895334983
#             ],
#             [
#               -56.655260722448524,
#               -34.20233787844224
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20171119_094435_1_0c81",
#       "properties": {
#         "acquired": "2017-11-19T09:44:35.320893Z",
#         "anomalous_pixels": 0,
#         "cloud_cover": 0.42,
#         "columns": 5252,
#         "epsg_code": 32721,
#         "ground_control": false,
#         "gsd": 2.7,
#         "instrument": "PS2",
#         "item_type": "PSScene4Band",
#         "origin_x": 531759,
#         "origin_y": 6228051,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2017-11-22T20:42:54Z",
#         "quality_category": "test",
#         "rows": 5455,
#         "satellite_id": "0c81",
#         "strip_id": "926364",
#         "sun_azimuth": 104.7,
#         "sun_elevation": 13.5,
#         "updated": "2017-11-22T20:42:54Z",
#         "usable_data": 0,
#         "view_angle": 0.4
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20171119_094434_1_0c81",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20171119_094434_1_0c81/assets/",
#         "thumbnail": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20171119_094434_1_0c81/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_rpc_nitf:download",
#         "assets.analytic_xml:download",
#         "assets.basic_analytic_dn:download",
#         "assets.basic_analytic_dn_xml_nitf:download",
#         "assets.basic_analytic_dn_nitf:download",
#         "assets.basic_analytic_xml:download",
#         "assets.basic_analytic_nitf:download",
#         "assets.basic_analytic_rpc:download",
#         "assets.analytic_dn:download",
#         "assets.basic_udm:download",
#         "assets.basic_analytic_dn_rpc_nitf:download",
#         "assets.analytic:download",
#         "assets.analytic_dn_xml:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.basic_analytic_xml_nitf:download",
#         "assets.basic_analytic:download",
#         "assets.udm:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -56.58550000519401,
#               -34.04062208795465
#             ],
#             [
#               -56.556263041560754,
#               -34.062822594405354
#             ],
#             [
#               -56.68475528869436,
#               -34.17815867545453
#             ],
#             [
#               -56.71413419300169,
#               -34.15601076865934
#             ],
#             [
#               -56.58550000519401,
#               -34.04062208795465
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20171119_094434_1_0c81",
#       "properties": {
#         "acquired": "2017-11-19T09:44:34.036115Z",
#         "anomalous_pixels": 0,
#         "cloud_cover": 0.24,
#         "columns": 4867,
#         "epsg_code": 32721,
#         "ground_control": false,
#         "gsd": 2.7,
#         "instrument": "PS2",
#         "item_type": "PSScene4Band",
#         "origin_x": 526350,
#         "origin_y": 6233265,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2017-11-22T20:42:53Z",
#         "quality_category": "test",
#         "rows": 5074,
#         "satellite_id": "0c81",
#         "strip_id": "926364",
#         "sun_azimuth": 104.8,
#         "sun_elevation": 13.4,
#         "updated": "2017-11-22T20:42:53Z",
#         "usable_data": 0,
#         "view_angle": 0.5
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20171119_094434_0c81",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20171119_094434_0c81/assets/",
#         "thumbnail": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20171119_094434_0c81/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_rpc_nitf:download",
#         "assets.analytic_xml:download",
#         "assets.basic_analytic_dn:download",
#         "assets.basic_analytic_dn_xml_nitf:download",
#         "assets.basic_analytic_dn_nitf:download",
#         "assets.basic_analytic_xml:download",
#         "assets.basic_analytic_nitf:download",
#         "assets.basic_analytic_rpc:download",
#         "assets.analytic_dn:download",
#         "assets.basic_udm:download",
#         "assets.basic_analytic_dn_rpc_nitf:download",
#         "assets.analytic:download",
#         "assets.analytic_dn_xml:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.basic_analytic_xml_nitf:download",
#         "assets.basic_analytic:download",
#         "assets.udm:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -56.69078043614159,
#               -34.17361649094375
#             ],
#             [
#               -56.56304846916051,
#               -34.05903652903579
#             ],
#             [
#               -56.52051817471874,
#               -34.09132210334219
#             ],
#             [
#               -56.649198973067364,
#               -34.20691325992873
#             ],
#             [
#               -56.6785144629948,
#               -34.184786058448225
#             ],
#             [
#               -56.677350451268836,
#               -34.18374096836166
#             ],
#             [
#               -56.69078043614159,
#               -34.17361649094375
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20171119_094434_0c81",
#       "properties": {
#         "acquired": "2017-11-19T09:44:34.678504Z",
#         "anomalous_pixels": 0,
#         "cloud_cover": 0.3,
#         "columns": 5246,
#         "epsg_code": 32721,
#         "ground_control": false,
#         "gsd": 2.7,
#         "instrument": "PS2",
#         "item_type": "PSScene4Band",
#         "origin_x": 528495,
#         "origin_y": 6231213,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2017-11-22T20:42:53Z",
#         "quality_category": "test",
#         "rows": 5456,
#         "satellite_id": "0c81",
#         "strip_id": "926364",
#         "sun_azimuth": 104.7,
#         "sun_elevation": 13.4,
#         "updated": "2017-11-22T20:42:53Z",
#         "usable_data": 0,
#         "view_angle": 0.4
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20171121_180828_0c62",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20171121_180828_0c62/assets/",
#         "thumbnail": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20171121_180828_0c62/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_rpc_nitf:download",
#         "assets.analytic_xml:download",
#         "assets.basic_analytic_dn:download",
#         "assets.basic_analytic_dn_xml_nitf:download",
#         "assets.basic_analytic_dn_nitf:download",
#         "assets.basic_analytic_xml:download",
#         "assets.basic_analytic_nitf:download",
#         "assets.basic_analytic_rpc:download",
#         "assets.analytic_dn:download",
#         "assets.basic_udm:download",
#         "assets.basic_analytic_dn_rpc_nitf:download",
#         "assets.analytic:download",
#         "assets.analytic_dn_xml:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.basic_analytic_xml_nitf:download",
#         "assets.basic_analytic:download",
#         "assets.udm:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -56.6270125550861,
#               -34.073258194153546
#             ],
#             [
#               -56.48639721915001,
#               -34.20124876397634
#             ],
#             [
#               -56.533744146089965,
#               -34.23693520315994
#             ],
#             [
#               -56.673168201814875,
#               -34.10991721805924
#             ],
#             [
#               -56.66008002781583,
#               -34.10005500245659
#             ],
#             [
#               -56.66119168468309,
#               -34.099042653639714
#             ],
#             [
#               -56.6270125550861,
#               -34.073258194153546
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20171121_180828_0c62",
#       "properties": {
#         "acquired": "2017-11-21T18:08:28.124472Z",
#         "anomalous_pixels": 0,
#         "cloud_cover": 0,
#         "columns": 5726,
#         "epsg_code": 32721,
#         "ground_control": true,
#         "gsd": 2.9,
#         "instrument": "PS2",
#         "item_type": "PSScene4Band",
#         "origin_x": 530142,
#         "origin_y": 6229659,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2017-11-22T19:23:36Z",
#         "quality_category": "standard",
#         "rows": 6062,
#         "satellite_id": "0c62",
#         "strip_id": "932636",
#         "sun_azimuth": 282.2,
#         "sun_elevation": 52.9,
#         "updated": "2017-11-24T10:47:23Z",
#         "usable_data": 0,
#         "view_angle": 2.4
#       },
#       "type": "Feature"
#     }
#   ],
#   "type": "FeatureCollection"
# }

# %% [markdown]
# Nice! The response gives us search results for Planet Scope (4 Band) for a specific area.
#
# Let's do another search, this time using the "not" filter we setup earlier:

# %%
# Setup Item Types
item_types = ["PSScene3Band"]

# Setup the request
request = {
    "item_types" : item_types,
    "filter" : not_filter
}

# Send the POST request to the API quick search endpoint
res = session.post(quick_url, json=request)

# Assign the response to a variable
geojson = res.json()

# Print the response
p(geojson)
# Out:
# {
#   "_links": {
#     "_first": "https://api.planet.com/data/v1/searches/e6d83a54ebf44412bc666d9688fe7bcd/results?_page=eyJxdWVyeV9wYXJhbXMiOiB7fSwgInNvcnRfcHJldiI6IGZhbHNlLCAicGFnZV9zaXplIjogMjUwLCAic29ydF9ieSI6ICJwdWJsaXNoZWQiLCAic29ydF9zdGFydCI6IG51bGwsICJzb3J0X2xhc3RfaWQiOiBudWxsLCAic29ydF9kZXNjIjogdHJ1ZX0%3D",
#     "_next": "https://api.planet.com/data/v1/searches/e6d83a54ebf44412bc666d9688fe7bcd/results?_page=eyJxdWVyeV9wYXJhbXMiOiB7fSwgInNvcnRfcHJldiI6IGZhbHNlLCAicGFnZV9zaXplIjogMjUwLCAic29ydF9ieSI6ICJwdWJsaXNoZWQiLCAic29ydF9zdGFydCI6ICIyMDE3LTEwLTI0VDA0OjM4OjA3LjAwMDAwMFoiLCAic29ydF9sYXN0X2lkIjogIjIwMTYwMzMwXzA5MDg0MV8wYjA3IiwgInNvcnRfZGVzYyI6IHRydWV9",
#     "_self": "https://api.planet.com/data/v1/searches/e6d83a54ebf44412bc666d9688fe7bcd/results?_page=eyJxdWVyeV9wYXJhbXMiOiB7fSwgInNvcnRfcHJldiI6IGZhbHNlLCAicGFnZV9zaXplIjogMjUwLCAic29ydF9ieSI6ICJwdWJsaXNoZWQiLCAic29ydF9zdGFydCI6IG51bGwsICJzb3J0X2xhc3RfaWQiOiBudWxsLCAic29ydF9kZXNjIjogdHJ1ZX0%3D"
#   },
#   "features": [
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160926_034414_0906",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160926_034414_0906/assets/",
#         "thumbnail": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160926_034414_0906/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.analytic_dn:download",
#         "assets.basic_udm:download",
#         "assets.visual:download",
#         "assets.analytic_dn_xml:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_dn:download",
#         "assets.visual_xml:download",
#         "assets.udm:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               116.78651205147732,
#               38.95910810588407
#             ],
#             [
#               116.48582643713424,
#               38.95799224360764
#             ],
#             [
#               116.22482734145359,
#               38.634134715592324
#             ],
#             [
#               116.50853319395833,
#               38.62956689642292
#             ],
#             [
#               116.78651205147732,
#               38.95910810588407
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20160926_034414_0906",
#       "properties": {
#         "acquired": "2016-09-26T03:44:14.174921Z",
#         "anomalous_pixels": 0.02,
#         "cloud_cover": 0.17,
#         "columns": 16325,
#         "epsg_code": 32650,
#         "ground_control": false,
#         "gsd": 10.9,
#         "instrument": "PS0",
#         "item_type": "PSScene3Band",
#         "origin_x": 432531,
#         "origin_y": 4312263,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2017-10-24T08:27:22Z",
#         "quality_category": "test",
#         "rows": 12160,
#         "satellite_id": "0906",
#         "strip_id": "666205",
#         "sun_azimuth": 159.6,
#         "sun_elevation": 52.1,
#         "updated": "2017-10-24T08:27:22Z",
#         "usable_data": 0,
#         "view_angle": 52.3
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160514_013208_0b0d",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160514_013208_0b0d/assets/",
#         "thumbnail": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160514_013208_0b0d/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.analytic_dn:download",
#         "assets.basic_udm:download",
#         "assets.visual:download",
#         "assets.analytic_dn_xml:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_dn:download",
#         "assets.visual_xml:download",
#         "assets.udm:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               110.37910991206076,
#               12.775556280122105
#             ],
#             [
#               110.40893976893645,
#               12.734376102932556
#             ],
#             [
#               110.47238915770404,
#               12.778578086029677
#             ],
#             [
#               110.44256520784639,
#               12.819766800208976
#             ],
#             [
#               110.37910991206076,
#               12.775556280122105
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20160514_013208_0b0d",
#       "properties": {
#         "acquired": "2016-05-14T01:32:08.381344Z",
#         "anomalous_pixels": 0,
#         "cloud_cover": 0.01,
#         "columns": 3377,
#         "epsg_code": 32649,
#         "ground_control": false,
#         "gsd": 2.1,
#         "instrument": "PS1",
#         "item_type": "PSScene3Band",
#         "origin_x": 432606,
#         "origin_y": 1417272,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2017-10-24T04:52:40Z",
#         "quality_category": "test",
#         "rows": 3146,
#         "satellite_id": "0b0d",
#         "strip_id": "182740",
#         "sun_azimuth": 76.2,
#         "sun_elevation": 45.9,
#         "updated": "2017-10-24T04:52:40Z",
#         "usable_data": 0,
#         "view_angle": 0.1
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160514_013205_0b0d",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160514_013205_0b0d/assets/",
#         "thumbnail": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160514_013205_0b0d/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.analytic_dn:download",
#         "assets.basic_udm:download",
#         "assets.visual:download",
#         "assets.analytic_dn_xml:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_dn:download",
#         "assets.visual_xml:download",
#         "assets.udm:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               110.25125357148934,
#               12.939390458981396
#             ],
#             [
#               110.28115390878003,
#               12.898246376898774
#             ],
#             [
#               110.34458886598465,
#               12.942524346999551
#             ],
#             [
#               110.31469357727727,
#               12.983674857044647
#             ],
#             [
#               110.25125357148934,
#               12.939390458981396
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20160514_013205_0b0d",
#       "properties": {
#         "acquired": "2016-05-14T01:32:05.117317Z",
#         "anomalous_pixels": 0,
#         "cloud_cover": 0,
#         "columns": 3376,
#         "epsg_code": 32649,
#         "ground_control": false,
#         "gsd": 2.1,
#         "instrument": "PS1",
#         "item_type": "PSScene3Band",
#         "origin_x": 418782,
#         "origin_y": 1435431,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2017-10-24T04:52:40Z",
#         "quality_category": "test",
#         "rows": 3147,
#         "satellite_id": "0b0d",
#         "strip_id": "182740",
#         "sun_azimuth": 76.4,
#         "sun_elevation": 45.8,
#         "updated": "2017-10-24T04:52:40Z",
#         "usable_data": 0,
#         "view_angle": 0
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160514_013201_0b0d",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160514_013201_0b0d/assets/",
#         "thumbnail": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160514_013201_0b0d/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.analytic_dn:download",
#         "assets.basic_udm:download",
#         "assets.visual:download",
#         "assets.analytic_dn_xml:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_dn:download",
#         "assets.visual_xml:download",
#         "assets.udm:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               110.09029077972178,
#               13.158440172458286
#             ],
#             [
#               110.12017284005853,
#               13.117264879454165
#             ],
#             [
#               110.1837170998908,
#               13.16147162380001
#             ],
#             [
#               110.1538401455747,
#               13.202658636015364
#             ],
#             [
#               110.09029077972178,
#               13.158440172458286
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20160514_013201_0b0d",
#       "properties": {
#         "acquired": "2016-05-14T01:32:01.037284Z",
#         "anomalous_pixels": 0,
#         "cloud_cover": 0,
#         "columns": 3376,
#         "epsg_code": 32649,
#         "ground_control": false,
#         "gsd": 2.1,
#         "instrument": "PS1",
#         "item_type": "PSScene3Band",
#         "origin_x": 401409,
#         "origin_y": 1459704,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2017-10-24T04:52:40Z",
#         "quality_category": "test",
#         "rows": 3145,
#         "satellite_id": "0b0d",
#         "strip_id": "182740",
#         "sun_azimuth": 76.6,
#         "sun_elevation": 45.7,
#         "updated": "2017-10-24T04:52:40Z",
#         "usable_data": 0,
#         "view_angle": 0.2
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160514_013157_0b0d",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160514_013157_0b0d/assets/",
#         "thumbnail": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160514_013157_0b0d/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.analytic_dn:download",
#         "assets.basic_udm:download",
#         "assets.visual:download",
#         "assets.analytic_dn_xml:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_dn:download",
#         "assets.visual_xml:download",
#         "assets.udm:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               109.96075321686405,
#               13.32139408664316
#             ],
#             [
#               109.9907169293351,
#               13.280261706493933
#             ],
#             [
#               110.0542350631164,
#               13.324558963439152
#             ],
#             [
#               110.02427784293886,
#               13.365699485648555
#             ],
#             [
#               109.96075321686405,
#               13.32139408664316
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20160514_013157_0b0d",
#       "properties": {
#         "acquired": "2016-05-14T01:31:57.773258Z",
#         "anomalous_pixels": 0,
#         "cloud_cover": 0.05,
#         "columns": 3377,
#         "epsg_code": 32649,
#         "ground_control": false,
#         "gsd": 2.1,
#         "instrument": "PS1",
#         "item_type": "PSScene3Band",
#         "origin_x": 387441,
#         "origin_y": 1477788,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2017-10-24T04:52:40Z",
#         "quality_category": "test",
#         "rows": 3146,
#         "satellite_id": "0b0d",
#         "strip_id": "182740",
#         "sun_azimuth": 76.7,
#         "sun_elevation": 45.6,
#         "updated": "2017-10-24T04:52:40Z",
#         "usable_data": 0,
#         "view_angle": 0.1
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090851_0b07",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090851_0b07/assets/",
#         "thumbnail": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090851_0b07/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.analytic_dn:download",
#         "assets.basic_udm:download",
#         "assets.visual:download",
#         "assets.analytic_dn_xml:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_dn:download",
#         "assets.visual_xml:download",
#         "assets.udm:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               107.62944184538148,
#               2.1054006643090126
#             ],
#             [
#               107.6624189646118,
#               2.151016408818824
#             ],
#             [
#               107.59368279029755,
#               2.20104143460078
#             ],
#             [
#               107.56070836906291,
#               2.1554208299942212
#             ],
#             [
#               107.62944184538148,
#               2.1054006643090126
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20160330_090851_0b07",
#       "properties": {
#         "acquired": "2016-03-30T09:08:51.791097Z",
#         "anomalous_pixels": 0,
#         "cloud_cover": 0,
#         "columns": 3775,
#         "epsg_code": 32648,
#         "ground_control": false,
#         "gsd": 2.3,
#         "instrument": "PS1",
#         "item_type": "PSScene3Band",
#         "origin_x": 784836,
#         "origin_y": 243534,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2017-10-24T04:52:05Z",
#         "quality_category": "test",
#         "rows": 3526,
#         "satellite_id": "0b07",
#         "strip_id": "168204",
#         "sun_azimuth": 273.4,
#         "sun_elevation": 26.4,
#         "updated": "2017-10-24T04:52:05Z",
#         "usable_data": 0,
#         "view_angle": 0.1
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090846_1_0b07",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090846_1_0b07/assets/",
#         "thumbnail": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090846_1_0b07/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.analytic_dn:download",
#         "assets.basic_udm:download",
#         "assets.visual:download",
#         "assets.analytic_dn_xml:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_dn:download",
#         "assets.visual_xml:download",
#         "assets.udm:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               107.41911883462107,
#               1.8010279799727786
#             ],
#             [
#               107.45199931230961,
#               1.846722063424921
#             ],
#             [
#               107.38317081084112,
#               1.8966199131223653
#             ],
#             [
#               107.35029078993647,
#               1.8509264069785032
#             ],
#             [
#               107.41911883462107,
#               1.8010279799727786
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20160330_090846_1_0b07",
#       "properties": {
#         "acquired": "2016-03-30T09:08:46.079055Z",
#         "anomalous_pixels": 0,
#         "cloud_cover": 0,
#         "columns": 3775,
#         "epsg_code": 32648,
#         "ground_control": false,
#         "gsd": 2.3,
#         "instrument": "PS1",
#         "item_type": "PSScene3Band",
#         "origin_x": 761466,
#         "origin_y": 209817,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2017-10-24T04:52:05Z",
#         "quality_category": "test",
#         "rows": 3524,
#         "satellite_id": "0b07",
#         "strip_id": "168204",
#         "sun_azimuth": 273.6,
#         "sun_elevation": 26.6,
#         "updated": "2017-10-24T04:52:05Z",
#         "usable_data": 0,
#         "view_angle": 0.1
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090824_1_0b07",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090824_1_0b07/assets/",
#         "thumbnail": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090824_1_0b07/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.analytic_dn:download",
#         "assets.basic_udm:download",
#         "assets.visual:download",
#         "assets.analytic_dn_xml:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_dn:download",
#         "assets.visual_xml:download",
#         "assets.udm:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               106.60679302262389,
#               0.6576551974170693
#             ],
#             [
#               106.63968511490981,
#               0.7033755752025365
#             ],
#             [
#               106.57087647230766,
#               0.7533613658800293
#             ],
#             [
#               106.53798441919389,
#               0.707639552280841
#             ],
#             [
#               106.60679302262389,
#               0.6576551974170693
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20160330_090824_1_0b07",
#       "properties": {
#         "acquired": "2016-03-30T09:08:24.046897Z",
#         "anomalous_pixels": 0,
#         "cloud_cover": 0.87,
#         "columns": 3775,
#         "epsg_code": 32648,
#         "ground_control": false,
#         "gsd": 2.3,
#         "instrument": "PS1",
#         "item_type": "PSScene3Band",
#         "origin_x": 671145,
#         "origin_y": 83301,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2017-10-24T04:52:05Z",
#         "quality_category": "test",
#         "rows": 3528,
#         "satellite_id": "0b07",
#         "strip_id": "168204",
#         "sun_azimuth": 274.1,
#         "sun_elevation": 27.4,
#         "updated": "2017-10-24T04:52:05Z",
#         "usable_data": 0,
#         "view_angle": 0
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090816_0b07",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090816_0b07/assets/",
#         "thumbnail": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090816_0b07/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.analytic_dn:download",
#         "assets.basic_udm:download",
#         "assets.visual:download",
#         "assets.analytic_dn_xml:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_dn:download",
#         "assets.visual_xml:download",
#         "assets.udm:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               106.33586663763558,
#               0.2713489336964869
#             ],
#             [
#               106.36874844377928,
#               0.3170918068538271
#             ],
#             [
#               106.29992215574546,
#               0.3670802543064762
#             ],
#             [
#               106.26703937209236,
#               0.32133789241551636
#             ],
#             [
#               106.33586663763558,
#               0.2713489336964869
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20160330_090816_0b07",
#       "properties": {
#         "acquired": "2016-03-30T09:08:16.702845Z",
#         "anomalous_pixels": 0,
#         "cloud_cover": 0.24,
#         "columns": 3774,
#         "epsg_code": 32648,
#         "ground_control": false,
#         "gsd": 2.3,
#         "instrument": "PS1",
#         "item_type": "PSScene3Band",
#         "origin_x": 640998,
#         "origin_y": 40584,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2017-10-24T04:52:05Z",
#         "quality_category": "test",
#         "rows": 3528,
#         "satellite_id": "0b07",
#         "strip_id": "168204",
#         "sun_azimuth": 274.4,
#         "sun_elevation": 27.7,
#         "updated": "2017-10-24T04:52:05Z",
#         "usable_data": 0,
#         "view_angle": 0
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090843_0b07",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090843_0b07/assets/",
#         "thumbnail": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090843_0b07/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.analytic_dn:download",
#         "assets.basic_udm:download",
#         "assets.visual:download",
#         "assets.analytic_dn_xml:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_dn:download",
#         "assets.visual_xml:download",
#         "assets.udm:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               107.32205382678711,
#               1.6710571513650982
#             ],
#             [
#               107.35495739942587,
#               1.7167401163153584
#             ],
#             [
#               107.28615246946381,
#               1.7666832978635707
#             ],
#             [
#               107.2532488146493,
#               1.720998803215815
#             ],
#             [
#               107.32205382678711,
#               1.6710571513650982
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20160330_090843_0b07",
#       "properties": {
#         "acquired": "2016-03-30T09:08:43.631037Z",
#         "anomalous_pixels": 0,
#         "cloud_cover": 0,
#         "columns": 3775,
#         "epsg_code": 32648,
#         "ground_control": false,
#         "gsd": 2.3,
#         "instrument": "PS1",
#         "item_type": "PSScene3Band",
#         "origin_x": 750681,
#         "origin_y": 195429,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2017-10-24T04:52:04Z",
#         "quality_category": "test",
#         "rows": 3525,
#         "satellite_id": "0b07",
#         "strip_id": "168204",
#         "sun_azimuth": 273.6,
#         "sun_elevation": 26.7,
#         "updated": "2017-10-24T04:52:04Z",
#         "usable_data": 0,
#         "view_angle": 0
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090904_0b07",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090904_0b07/assets/",
#         "thumbnail": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090904_0b07/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.analytic_dn:download",
#         "assets.basic_udm:download",
#         "assets.visual:download",
#         "assets.analytic_dn_xml:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_dn:download",
#         "assets.visual_xml:download",
#         "assets.udm:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               108.10491120164073,
#               2.7778093508554442
#             ],
#             [
#               108.13786585525537,
#               2.8234298229279577
#             ],
#             [
#               108.06907014277778,
#               2.8733685203326798
#             ],
#             [
#               108.03611714512355,
#               2.8277431208726855
#             ],
#             [
#               108.10491120164073,
#               2.7778093508554442
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20160330_090904_0b07",
#       "properties": {
#         "acquired": "2016-03-30T09:09:04.847195Z",
#         "anomalous_pixels": 0,
#         "cloud_cover": 0.71,
#         "columns": 3775,
#         "epsg_code": 32649,
#         "ground_control": false,
#         "gsd": 2.3,
#         "instrument": "PS1",
#         "item_type": "PSScene3Band",
#         "origin_x": 170445,
#         "origin_y": 318015,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2017-10-24T04:42:39Z",
#         "quality_category": "test",
#         "rows": 3529,
#         "satellite_id": "0b07",
#         "strip_id": "168204",
#         "sun_azimuth": 273.1,
#         "sun_elevation": 25.9,
#         "updated": "2017-10-24T04:42:39Z",
#         "usable_data": 0,
#         "view_angle": 0
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090903_0b07",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090903_0b07/assets/",
#         "thumbnail": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090903_0b07/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.analytic_dn:download",
#         "assets.basic_udm:download",
#         "assets.visual:download",
#         "assets.analytic_dn_xml:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_dn:download",
#         "assets.visual_xml:download",
#         "assets.udm:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               108.04933719337288,
#               2.697102022237935
#             ],
#             [
#               108.08228182388744,
#               2.742729173615761
#             ],
#             [
#               108.01348588908726,
#               2.7926589640692967
#             ],
#             [
#               107.98054171072253,
#               2.7470298279861134
#             ],
#             [
#               108.04933719337288,
#               2.697102022237935
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20160330_090903_0b07",
#       "properties": {
#         "acquired": "2016-03-30T09:09:03.215183Z",
#         "anomalous_pixels": 0,
#         "cloud_cover": 0.16,
#         "columns": 3775,
#         "epsg_code": 32649,
#         "ground_control": false,
#         "gsd": 2.3,
#         "instrument": "PS1",
#         "item_type": "PSScene3Band",
#         "origin_x": 164235,
#         "origin_y": 309099,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2017-10-24T04:42:39Z",
#         "quality_category": "test",
#         "rows": 3530,
#         "satellite_id": "0b07",
#         "strip_id": "168204",
#         "sun_azimuth": 273.1,
#         "sun_elevation": 25.9,
#         "updated": "2017-10-24T04:42:39Z",
#         "usable_data": 0,
#         "view_angle": 0
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090946_0b07",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090946_0b07/assets/",
#         "thumbnail": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090946_0b07/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.analytic_dn:download",
#         "assets.basic_udm:download",
#         "assets.visual:download",
#         "assets.analytic_dn_xml:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_dn:download",
#         "assets.visual_xml:download",
#         "assets.udm:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               109.64437495113722,
#               4.941548751977338
#             ],
#             [
#               109.67758145013565,
#               4.9869724529478345
#             ],
#             [
#               109.60885186509731,
#               5.037079757003216
#             ],
#             [
#               109.57564698054087,
#               4.9916530613172325
#             ],
#             [
#               109.64437495113722,
#               4.941548751977338
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20160330_090946_0b07",
#       "properties": {
#         "acquired": "2016-03-30T09:09:46.463525Z",
#         "anomalous_pixels": 0,
#         "cloud_cover": 0,
#         "columns": 3769,
#         "epsg_code": 32649,
#         "ground_control": false,
#         "gsd": 2.3,
#         "instrument": "PS1",
#         "item_type": "PSScene3Band",
#         "origin_x": 342084,
#         "origin_y": 556929,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2017-10-24T04:42:38Z",
#         "quality_category": "test",
#         "rows": 3525,
#         "satellite_id": "0b07",
#         "strip_id": "168204",
#         "sun_azimuth": 272.2,
#         "sun_elevation": 24.3,
#         "updated": "2017-10-24T04:42:38Z",
#         "usable_data": 0,
#         "view_angle": 0
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090944_1_0b07",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090944_1_0b07/assets/",
#         "thumbnail": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090944_1_0b07/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.analytic_dn:download",
#         "assets.basic_udm:download",
#         "assets.visual:download",
#         "assets.analytic_dn_xml:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_dn:download",
#         "assets.visual_xml:download",
#         "assets.udm:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               109.5557378034488,
#               4.814681527841784
#             ],
#             [
#               109.58894658146761,
#               4.8601040907011726
#             ],
#             [
#               109.52023481854914,
#               4.910228599287142
#             ],
#             [
#               109.48702861212978,
#               4.864803305822242
#             ],
#             [
#               109.5557378034488,
#               4.814681527841784
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20160330_090944_1_0b07",
#       "properties": {
#         "acquired": "2016-03-30T09:09:44.015505Z",
#         "anomalous_pixels": 0,
#         "cloud_cover": 0,
#         "columns": 3769,
#         "epsg_code": 32649,
#         "ground_control": false,
#         "gsd": 2.3,
#         "instrument": "PS1",
#         "item_type": "PSScene3Band",
#         "origin_x": 332226,
#         "origin_y": 542925,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2017-10-24T04:42:38Z",
#         "quality_category": "test",
#         "rows": 3526,
#         "satellite_id": "0b07",
#         "strip_id": "168204",
#         "sun_azimuth": 272.2,
#         "sun_elevation": 24.4,
#         "updated": "2017-10-24T04:42:38Z",
#         "usable_data": 0,
#         "view_angle": 0
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090944_0b07",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090944_0b07/assets/",
#         "thumbnail": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090944_0b07/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.analytic_dn:download",
#         "assets.basic_udm:download",
#         "assets.visual:download",
#         "assets.analytic_dn_xml:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_dn:download",
#         "assets.visual_xml:download",
#         "assets.udm:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               109.58556091686181,
#               4.857494250179219
#             ],
#             [
#               109.61874577632146,
#               4.902933685155448
#             ],
#             [
#               109.55000272233023,
#               4.953017207681689
#             ],
#             [
#               109.51682028536761,
#               4.907574594477407
#             ],
#             [
#               109.58556091686181,
#               4.857494250179219
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20160330_090944_0b07",
#       "properties": {
#         "acquired": "2016-03-30T09:09:44.831512Z",
#         "anomalous_pixels": 0,
#         "cloud_cover": 0,
#         "columns": 3768,
#         "epsg_code": 32649,
#         "ground_control": false,
#         "gsd": 2.3,
#         "instrument": "PS1",
#         "item_type": "PSScene3Band",
#         "origin_x": 335541,
#         "origin_y": 547647,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2017-10-24T04:42:38Z",
#         "quality_category": "test",
#         "rows": 3524,
#         "satellite_id": "0b07",
#         "strip_id": "168204",
#         "sun_azimuth": 272.2,
#         "sun_elevation": 24.3,
#         "updated": "2017-10-24T04:42:38Z",
#         "usable_data": 0,
#         "view_angle": 0
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090943_0b07",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090943_0b07/assets/",
#         "thumbnail": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090943_0b07/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.analytic_dn:download",
#         "assets.basic_udm:download",
#         "assets.visual:download",
#         "assets.analytic_dn_xml:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_dn:download",
#         "assets.visual_xml:download",
#         "assets.udm:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               109.52687647654382,
#               4.7746250861406345
#             ],
#             [
#               109.56008604156833,
#               4.8200491258702005
#             ],
#             [
#               109.49137721740148,
#               4.8701796923473095
#             ],
#             [
#               109.45816986268419,
#               4.824752799868769
#             ],
#             [
#               109.52687647654382,
#               4.7746250861406345
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20160330_090943_0b07",
#       "properties": {
#         "acquired": "2016-03-30T09:09:43.199499Z",
#         "anomalous_pixels": 0,
#         "cloud_cover": 0,
#         "columns": 3768,
#         "epsg_code": 32649,
#         "ground_control": false,
#         "gsd": 2.3,
#         "instrument": "PS1",
#         "item_type": "PSScene3Band",
#         "origin_x": 329016,
#         "origin_y": 538503,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2017-10-24T04:42:38Z",
#         "quality_category": "test",
#         "rows": 3526,
#         "satellite_id": "0b07",
#         "strip_id": "168204",
#         "sun_azimuth": 272.2,
#         "sun_elevation": 24.4,
#         "updated": "2017-10-24T04:42:38Z",
#         "usable_data": 0,
#         "view_angle": 0
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090928_0b07",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090928_0b07/assets/",
#         "thumbnail": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090928_0b07/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.analytic_dn:download",
#         "assets.basic_udm:download",
#         "assets.visual:download",
#         "assets.analytic_dn_xml:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_dn:download",
#         "assets.visual_xml:download",
#         "assets.udm:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               108.98558714941588,
#               4.0150321871642936
#             ],
#             [
#               109.01874618356368,
#               4.060489514094876
#             ],
#             [
#               108.95007711065412,
#               4.110624515471389
#             ],
#             [
#               108.9169204108934,
#               4.065164309581307
#             ],
#             [
#               108.98558714941588,
#               4.0150321871642936
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20160330_090928_0b07",
#       "properties": {
#         "acquired": "2016-03-30T09:09:28.51138Z",
#         "anomalous_pixels": 0,
#         "cloud_cover": 0,
#         "columns": 3771,
#         "epsg_code": 32649,
#         "ground_control": false,
#         "gsd": 2.3,
#         "instrument": "PS1",
#         "item_type": "PSScene3Band",
#         "origin_x": 268731,
#         "origin_y": 454650,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2017-10-24T04:42:38Z",
#         "quality_category": "test",
#         "rows": 3529,
#         "satellite_id": "0b07",
#         "strip_id": "168204",
#         "sun_azimuth": 272.5,
#         "sun_elevation": 25,
#         "updated": "2017-10-24T04:42:38Z",
#         "usable_data": 0,
#         "view_angle": 0
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090904_1_0b07",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090904_1_0b07/assets/",
#         "thumbnail": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090904_1_0b07/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.analytic_dn:download",
#         "assets.basic_udm:download",
#         "assets.visual:download",
#         "assets.analytic_dn_xml:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_dn:download",
#         "assets.visual_xml:download",
#         "assets.udm:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               108.079092304241,
#               2.7432279317162336
#             ],
#             [
#               108.11203173819564,
#               2.788856880871918
#             ],
#             [
#               108.04322615069405,
#               2.838776103032485
#             ],
#             [
#               108.01028842534024,
#               2.7931416851678805
#             ],
#             [
#               108.079092304241,
#               2.7432279317162336
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20160330_090904_1_0b07",
#       "properties": {
#         "acquired": "2016-03-30T09:09:04.031189Z",
#         "anomalous_pixels": 0,
#         "cloud_cover": 0.47,
#         "columns": 3775,
#         "epsg_code": 32649,
#         "ground_control": false,
#         "gsd": 2.3,
#         "instrument": "PS1",
#         "item_type": "PSScene3Band",
#         "origin_x": 167559,
#         "origin_y": 314196,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2017-10-24T04:42:38Z",
#         "quality_category": "test",
#         "rows": 3530,
#         "satellite_id": "0b07",
#         "strip_id": "168204",
#         "sun_azimuth": 273.1,
#         "sun_elevation": 25.9,
#         "updated": "2017-10-24T04:42:38Z",
#         "usable_data": 0,
#         "view_angle": 0.1
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090902_0b07",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090902_0b07/assets/",
#         "thumbnail": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090902_0b07/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.analytic_dn:download",
#         "assets.basic_udm:download",
#         "assets.visual:download",
#         "assets.analytic_dn_xml:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_dn:download",
#         "assets.visual_xml:download",
#         "assets.udm:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               108.01414899126641,
#               2.647626050066925
#             ],
#             [
#               108.04711957859456,
#               2.6932387565630074
#             ],
#             [
#               107.97835007141582,
#               2.743211968967204
#             ],
#             [
#               107.9453795710229,
#               2.6975978579623985
#             ],
#             [
#               108.01414899126641,
#               2.647626050066925
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20160330_090902_0b07",
#       "properties": {
#         "acquired": "2016-03-30T09:09:02.399176Z",
#         "anomalous_pixels": 0,
#         "cloud_cover": 0.18,
#         "columns": 3776,
#         "epsg_code": 32648,
#         "ground_control": false,
#         "gsd": 2.3,
#         "instrument": "PS1",
#         "item_type": "PSScene3Band",
#         "origin_x": 827529,
#         "origin_y": 303624,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2017-10-24T04:42:38Z",
#         "quality_category": "test",
#         "rows": 3525,
#         "satellite_id": "0b07",
#         "strip_id": "168204",
#         "sun_azimuth": 273.1,
#         "sun_elevation": 26,
#         "updated": "2017-10-24T04:42:38Z",
#         "usable_data": 0,
#         "view_angle": 0
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090901_0b07",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090901_0b07/assets/",
#         "thumbnail": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090901_0b07/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.analytic_dn:download",
#         "assets.basic_udm:download",
#         "assets.visual:download",
#         "assets.analytic_dn_xml:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_dn:download",
#         "assets.visual_xml:download",
#         "assets.udm:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               107.98790291550307,
#               2.6117552459387103
#             ],
#             [
#               108.02090597832992,
#               2.6573420324477817
#             ],
#             [
#               107.95217792448064,
#               2.707368082034234
#             ],
#             [
#               107.91917496469101,
#               2.661779158882702
#             ],
#             [
#               107.98790291550307,
#               2.6117552459387103
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20160330_090901_0b07",
#       "properties": {
#         "acquired": "2016-03-30T09:09:01.583171Z",
#         "anomalous_pixels": 0,
#         "cloud_cover": 0.12,
#         "columns": 3776,
#         "epsg_code": 32648,
#         "ground_control": false,
#         "gsd": 2.3,
#         "instrument": "PS1",
#         "item_type": "PSScene3Band",
#         "origin_x": 824622,
#         "origin_y": 299649,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2017-10-24T04:42:38Z",
#         "quality_category": "test",
#         "rows": 3525,
#         "satellite_id": "0b07",
#         "strip_id": "168204",
#         "sun_azimuth": 273.2,
#         "sun_elevation": 26,
#         "updated": "2017-10-24T04:42:38Z",
#         "usable_data": 0,
#         "view_angle": 0
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090900_0b07",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090900_0b07/assets/",
#         "thumbnail": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090900_0b07/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.analytic_dn:download",
#         "assets.basic_udm:download",
#         "assets.visual:download",
#         "assets.analytic_dn_xml:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_dn:download",
#         "assets.visual_xml:download",
#         "assets.udm:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               107.96054029043839,
#               2.571164414889842
#             ],
#             [
#               107.99351363987765,
#               2.616773635437032
#             ],
#             [
#               107.92475448732854,
#               2.6667570324668413
#             ],
#             [
#               107.89178256621025,
#               2.621145490048836
#             ],
#             [
#               107.96054029043839,
#               2.571164414889842
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20160330_090900_0b07",
#       "properties": {
#         "acquired": "2016-03-30T09:09:00.767164Z",
#         "anomalous_pixels": 0,
#         "cloud_cover": 0.02,
#         "columns": 3776,
#         "epsg_code": 32648,
#         "ground_control": false,
#         "gsd": 2.3,
#         "instrument": "PS1",
#         "item_type": "PSScene3Band",
#         "origin_x": 821583,
#         "origin_y": 295146,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2017-10-24T04:42:38Z",
#         "quality_category": "test",
#         "rows": 3524,
#         "satellite_id": "0b07",
#         "strip_id": "168204",
#         "sun_azimuth": 273.2,
#         "sun_elevation": 26,
#         "updated": "2017-10-24T04:42:38Z",
#         "usable_data": 0,
#         "view_angle": 0
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090859_0b07",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090859_0b07/assets/",
#         "thumbnail": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090859_0b07/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.analytic_dn:download",
#         "assets.basic_udm:download",
#         "assets.visual:download",
#         "assets.analytic_dn_xml:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_dn:download",
#         "assets.visual_xml:download",
#         "assets.udm:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               107.92993848186248,
#               2.5293781348139683
#             ],
#             [
#               107.96293197696286,
#               2.5749729557770045
#             ],
#             [
#               107.89419533495969,
#               2.624990780233284
#             ],
#             [
#               107.86120434250019,
#               2.5793910552597716
#             ],
#             [
#               107.92993848186248,
#               2.5293781348139683
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20160330_090859_0b07",
#       "properties": {
#         "acquired": "2016-03-30T09:08:59.951158Z",
#         "anomalous_pixels": 0,
# ...
#       "properties": {
#         "acquired": "2016-03-30T09:10:01.151648Z",
#         "anomalous_pixels": 0,
#         "cloud_cover": 0,
#         "columns": 3767,
#         "epsg_code": 32649,
#         "ground_control": false,
#         "gsd": 2.3,
#         "instrument": "PS1",
#         "item_type": "PSScene3Band",
#         "origin_x": 402939,
#         "origin_y": 641100,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2017-10-24T04:38:07Z",
#         "quality_category": "test",
#         "rows": 3525,
#         "satellite_id": "0b07",
#         "strip_id": "168204",
#         "sun_azimuth": 271.9,
#         "sun_elevation": 23.7,
#         "updated": "2017-10-24T04:38:07Z",
#         "usable_data": 0,
#         "view_angle": 0
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090959_0b07",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090959_0b07/assets/",
#         "thumbnail": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090959_0b07/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.analytic_dn:download",
#         "assets.basic_udm:download",
#         "assets.visual:download",
#         "assets.analytic_dn_xml:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_dn:download",
#         "assets.visual_xml:download",
#         "assets.udm:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               110.1358134188282,
#               5.627688099243179
#             ],
#             [
#               110.16908950975026,
#               5.673060651237806
#             ],
#             [
#               110.1003398911481,
#               5.72319221464695
#             ],
#             [
#               110.06706702965096,
#               5.6778130701710365
#             ],
#             [
#               110.1358134188282,
#               5.627688099243179
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20160330_090959_0b07",
#       "properties": {
#         "acquired": "2016-03-30T09:09:59.519634Z",
#         "anomalous_pixels": 0,
#         "cloud_cover": 0.07,
#         "columns": 3767,
#         "epsg_code": 32649,
#         "ground_control": false,
#         "gsd": 2.3,
#         "instrument": "PS1",
#         "item_type": "PSScene3Band",
#         "origin_x": 396687,
#         "origin_y": 632685,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2017-10-24T04:38:07Z",
#         "quality_category": "test",
#         "rows": 3522,
#         "satellite_id": "0b07",
#         "strip_id": "168204",
#         "sun_azimuth": 271.9,
#         "sun_elevation": 23.7,
#         "updated": "2017-10-24T04:38:07Z",
#         "usable_data": 0,
#         "view_angle": 0
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090957_1_0b07",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090957_1_0b07/assets/",
#         "thumbnail": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090957_1_0b07/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.analytic_dn:download",
#         "assets.basic_udm:download",
#         "assets.visual:download",
#         "assets.analytic_dn_xml:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_dn:download",
#         "assets.visual_xml:download",
#         "assets.udm:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               110.07567375820832,
#               5.543919523227931
#             ],
#             [
#               110.10895500699439,
#               5.589287980702038
#             ],
#             [
#               110.04022336556038,
#               5.639437676045841
#             ],
#             [
#               110.00694550136234,
#               5.594062500069902
#             ],
#             [
#               110.07567375820832,
#               5.543919523227931
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20160330_090957_1_0b07",
#       "properties": {
#         "acquired": "2016-03-30T09:09:57.887621Z",
#         "anomalous_pixels": 0,
#         "cloud_cover": 0,
#         "columns": 3767,
#         "epsg_code": 32649,
#         "ground_control": false,
#         "gsd": 2.3,
#         "instrument": "PS1",
#         "item_type": "PSScene3Band",
#         "origin_x": 390015,
#         "origin_y": 623436,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2017-10-24T04:38:07Z",
#         "quality_category": "test",
#         "rows": 3523,
#         "satellite_id": "0b07",
#         "strip_id": "168204",
#         "sun_azimuth": 271.9,
#         "sun_elevation": 23.8,
#         "updated": "2017-10-24T04:38:07Z",
#         "usable_data": 0,
#         "view_angle": 0
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090926_0b07",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090926_0b07/assets/",
#         "thumbnail": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090926_0b07/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.analytic_dn:download",
#         "assets.basic_udm:download",
#         "assets.visual:download",
#         "assets.analytic_dn_xml:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_dn:download",
#         "assets.visual_xml:download",
#         "assets.udm:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               108.92581776717816,
#               3.9315948282251836
#             ],
#             [
#               108.95888829542089,
#               3.9771165820965506
#             ],
#             [
#               108.89012750952,
#               4.027123502825285
#             ],
#             [
#               108.85706311979872,
#               3.9815965870842436
#             ],
#             [
#               108.92581776717816,
#               3.9315948282251836
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20160330_090926_0b07",
#       "properties": {
#         "acquired": "2016-03-30T09:09:26.879367Z",
#         "anomalous_pixels": 0,
#         "cloud_cover": 0.03,
#         "columns": 3771,
#         "epsg_code": 32649,
#         "ground_control": false,
#         "gsd": 2.3,
#         "instrument": "PS1",
#         "item_type": "PSScene3Band",
#         "origin_x": 262059,
#         "origin_y": 445431,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2017-10-24T04:38:07Z",
#         "quality_category": "test",
#         "rows": 3527,
#         "satellite_id": "0b07",
#         "strip_id": "168204",
#         "sun_azimuth": 272.6,
#         "sun_elevation": 25,
#         "updated": "2017-10-24T04:38:07Z",
#         "usable_data": 0,
#         "view_angle": 0
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090909_0b07",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090909_0b07/assets/",
#         "thumbnail": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090909_0b07/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.analytic_dn:download",
#         "assets.basic_udm:download",
#         "assets.visual:download",
#         "assets.analytic_dn_xml:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_dn:download",
#         "assets.visual_xml:download",
#         "assets.udm:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               108.28780166713707,
#               3.030407129800798
#             ],
#             [
#               108.32076319053408,
#               3.076021329654138
#             ],
#             [
#               108.25195624212486,
#               3.1259450419906782
#             ],
#             [
#               108.21899927788613,
#               3.0803297039090936
#             ],
#             [
#               108.28780166713707,
#               3.030407129800798
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20160330_090909_0b07",
#       "properties": {
#         "acquired": "2016-03-30T09:09:09.743233Z",
#         "anomalous_pixels": 0,
#         "cloud_cover": 0.05,
#         "columns": 3774,
#         "epsg_code": 32649,
#         "ground_control": false,
#         "gsd": 2.3,
#         "instrument": "PS1",
#         "item_type": "PSScene3Band",
#         "origin_x": 190866,
#         "origin_y": 345915,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2017-10-24T04:38:07Z",
#         "quality_category": "test",
#         "rows": 3528,
#         "satellite_id": "0b07",
#         "strip_id": "168204",
#         "sun_azimuth": 273,
#         "sun_elevation": 25.7,
#         "updated": "2017-10-24T04:38:07Z",
#         "usable_data": 0,
#         "view_angle": 0
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090848_0b07",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090848_0b07/assets/",
#         "thumbnail": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090848_0b07/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.analytic_dn:download",
#         "assets.basic_udm:download",
#         "assets.visual:download",
#         "assets.analytic_dn_xml:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_dn:download",
#         "assets.visual_xml:download",
#         "assets.udm:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               107.50816949296826,
#               1.9293592386756075
#             ],
#             [
#               107.54111479677192,
#               1.9750032781142908
#             ],
#             [
#               107.47235297739768,
#               2.0249917421504495
#             ],
#             [
#               107.43940772252175,
#               1.9793476548307714
#             ],
#             [
#               107.50816949296826,
#               1.9293592386756075
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20160330_090848_0b07",
#       "properties": {
#         "acquired": "2016-03-30T09:08:48.527073Z",
#         "anomalous_pixels": 0,
#         "cloud_cover": 0.01,
#         "columns": 3775,
#         "epsg_code": 32648,
#         "ground_control": false,
#         "gsd": 2.3,
#         "instrument": "PS1",
#         "item_type": "PSScene3Band",
#         "origin_x": 771366,
#         "origin_y": 224034,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2017-10-24T04:38:07Z",
#         "quality_category": "test",
#         "rows": 3526,
#         "satellite_id": "0b07",
#         "strip_id": "168204",
#         "sun_azimuth": 273.5,
#         "sun_elevation": 26.5,
#         "updated": "2017-10-24T04:38:07Z",
#         "usable_data": 0,
#         "view_angle": 0.1
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090842_0b07",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090842_0b07/assets/",
#         "thumbnail": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090842_0b07/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.analytic_dn:download",
#         "assets.basic_udm:download",
#         "assets.visual:download",
#         "assets.analytic_dn_xml:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_dn:download",
#         "assets.visual_xml:download",
#         "assets.udm:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               107.29883561439362,
#               1.6366980681546246
#             ],
#             [
#               107.3317628859731,
#               1.6823621678358331
#             ],
#             [
#               107.2629876316373,
#               1.7323434476056252
#             ],
#             [
#               107.23006160854055,
#               1.686677199542447
#             ],
#             [
#               107.29883561439362,
#               1.6366980681546246
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20160330_090842_0b07",
#       "properties": {
#         "acquired": "2016-03-30T09:08:42.815031Z",
#         "anomalous_pixels": 0,
#         "cloud_cover": 0.01,
#         "columns": 3775,
#         "epsg_code": 32648,
#         "ground_control": false,
#         "gsd": 2.3,
#         "instrument": "PS1",
#         "item_type": "PSScene3Band",
#         "origin_x": 748104,
#         "origin_y": 191628,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2017-10-24T04:38:07Z",
#         "quality_category": "test",
#         "rows": 3526,
#         "satellite_id": "0b07",
#         "strip_id": "168204",
#         "sun_azimuth": 273.6,
#         "sun_elevation": 26.7,
#         "updated": "2017-10-24T04:38:07Z",
#         "usable_data": 0,
#         "view_angle": 0
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090841_0b07",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090841_0b07/assets/",
#         "thumbnail": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20160330_090841_0b07/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.analytic_dn:download",
#         "assets.basic_udm:download",
#         "assets.visual:download",
#         "assets.analytic_dn_xml:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_dn:download",
#         "assets.visual_xml:download",
#         "assets.udm:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               107.23912083157167,
#               1.5488001315535453
#             ],
#             [
#               107.27192738251976,
#               1.5945534225499283
#             ],
#             [
#               107.20302409165686,
#               1.644355513400082
#             ],
#             [
#               107.17021862847123,
#               1.5986014823127632
#             ],
#             [
#               107.23912083157167,
#               1.5488001315535453
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20160330_090841_0b07",
#       "properties": {
#         "acquired": "2016-03-30T09:08:41.183019Z",
#         "anomalous_pixels": 0,
#         "cloud_cover": 0.02,
#         "columns": 3775,
#         "epsg_code": 32648,
#         "ground_control": false,
#         "gsd": 2.3,
#         "instrument": "PS1",
#         "item_type": "PSScene3Band",
#         "origin_x": 741453,
#         "origin_y": 181887,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2017-10-24T04:38:07Z",
#         "quality_category": "test",
#         "rows": 3523,
#         "satellite_id": "0b07",
#         "strip_id": "168204",
#         "sun_azimuth": 273.7,
#         "sun_elevation": 26.7,
#         "updated": "2017-10-24T04:38:07Z",
#         "usable_data": 0,
#         "view_angle": 0
#       },
#       "type": "Feature"
#     }
#   ],
#   "type": "FeatureCollection"
# }

# %% [markdown]
# Let's take a closer look at our response data:

# %%
# Assign a features variable 
features = geojson["features"]

# Get the number of features present in the response
len(features)
# Out:
# 250

# %%
# Loop over all the features from the response
for f in features:
    # Print the ID for each feature
    p(f["id"])
# Out:
# "20180201_131116_1010"
# "20180201_131115_1010"
# "20180201_131231_1009"
# "20180201_131230_1009"
# "20180201_131229_1009"
# "20180131_131223_0f31"
# "20180131_131222_0f31"
# "20180130_131148_1004"
# "20180130_131147_1004"
# "20180130_131146_1004"
# "20180129_131220_1015"
# "20180129_131219_1015"
# "20180129_131218_1015"
# "20180128_131305_1018"
# "20180128_131115_1003"
# "20180128_131114_1003"
# "20180128_131112_1003"
# "20180128_131307_1018"
# "20180128_131306_1018"
# "20180127_131216_0f12"
# "20180127_131556_0e2f"
# "20180126_150357_0f1a"
# "20180126_150356_0f1a"
# "20180126_150355_0f1a"
# "20180125_131239_1011"
# "20180125_131240_1011"
# "20180125_131238_1011"
# "20180123_131120_1032"
# "20180123_131118_1032"
# "20180123_131119_1032"
# "20180122_131141_0f28"
# "20180122_131140_0f28"
# "20180122_131139_0f28"
# "20180122_131432_0e16"
# "20180122_131431_0e16"
# "20180122_131430_0e16"
# "20180121_131151_1044"
# "20180121_131149_1044"
# "20180121_131313_102e"
# "20180121_131312_102e"
# "20180120_131028_1024"
# "20180120_131027_1024"
# "20180120_131026_1024"
# "20180119_131209_100c"
# "20180119_131208_100c"
# "20180119_131207_100c"
# "20180119_131108_0f18"
# "20180119_131107_0f18"
# "20180118_131145_1033"
# "20180118_131147_1033"
# "20180118_131146_1033"
# "20180118_131314_0e26"
# "20180118_131313_0e26"
# "20180118_131312_0e26"
# "20180117_131125_0f52"
# "20180117_131124_0f52"
# "20180116_131135_101d"
# "20180116_131134_101d"
# "20180116_131243_100a"
# "20180116_131242_100a"
# "20180112_131218_0f4e"
# "20180112_131216_0f4e"
# "20180112_131215_0f4e"
# "20180111_131113_1025"
# "20180111_131112_1025"
# "20180111_131111_1025"
# "20180111_131018_102f"
# "20180110_131332_0e0f"
# "20180110_131333_0e0f"
# "20180110_131331_0e0f"
# "20180109_131144_100b"
# "20180109_131143_100b"
# "20180109_131142_100b"
# "20180108_131047_1040"
# "20180108_131046_1040"
# "20180108_131045_1040"
# "20180108_131136_1006"
# "20180108_131135_1006"
# "20180108_131134_1006"
# "20180107_150713_1020"
# "20180107_150712_1020"
# "20180107_150711_1020"
# "20180107_131134_1039"
# "20180107_131133_1039"
# "20180107_131132_1039"
# "20180107_131221_1036"
# "20180107_131220_1036"
# "20180106_131121_0f35"
# "20180106_131120_0f35"
# "20180106_131119_0f35"
# "20180106_131029_1021"
# "20180106_131028_1021"
# "20180106_131027_1021"
# "20180104_145926_0d05"
# "20180104_145928_0d05"
# "20180104_145927_1_0d05"
# "20180104_145927_0d05"
# "20180104_145925_0d05"
# "20180105_131200_0f15"
# "20180105_131159_0f15"
# "20180105_131158_0f15"
# "20180105_131106_0f42"
# "20180105_131107_0f42"
# "20180104_131158_0f25"
# "20180104_131157_0f25"
# "20180104_131156_0f25"
# "20180103_131204_1012"
# "20180103_131203_1012"
# "20180103_131030_1030"
# "20180103_131028_1030"
# "20180103_131029_1030"
# "20180102_131353_0e20"
# "20180102_131352_0e20"
# "20180102_131005_102c"
# "20180102_131004_102c"
# "20180102_131003_102c"
# "20180101_131042_0f22"
# "20180101_131041_0f22"
# "20180101_131040_0f22"
# "20171230_131046_1034"
# "20171230_131045_1034"
# "20171229_150757_104d"
# "20171229_131137_1024"
# "20171229_131136_1024"
# "20171228_195632_0c54"
# "20171228_195631_0c54"
# "20171228_195630_1_0c54"
# "20171228_195630_0c54"
# "20171228_131014_1010"
# "20171228_131013_1010"
# "20171228_131106_1009"
# "20171228_131105_1009"
# "20171228_131104_1009"
# "20171228_150939_0f36"
# "20171228_150938_0f36"
# "20171228_150937_0f36"
# "20171226_131015_1013"
# "20171226_131013_1013"
# "20171226_131123_1004"
# "20171226_131122_1004"
# "20171226_131014_1013"
# "20171225_194138_1_0c43"
# "20171225_194137_0c43"
# "20171225_194136_1_0c43"
# "20171221_203236_1_0c76"
# "20171221_203236_0c76"
# "20171221_203235_0c76"
# "20171221_203234_1_0c76"
# "20171221_131048_1011"
# "20171221_131047_1011"
# "20171221_131046_1011"
# "20171220_131038_102f"
# "20171220_131037_102f"
# "20171220_131036_102f"
# "20171218_131048_103d"
# "20171218_131046_103d"
# "20171218_130939_0f28"
# "20171218_130937_0f28"
# "20171218_131047_103d"
# "20171218_130938_0f28"
# "20171215_131020_1021"
# "20171215_131019_1021"
# "20171215_131018_1021"
# "20171214_130908_1033"
# "20171214_130907_1033"
# "20171214_130906_1033"
# "20171213_131122_0f34"
# "20171213_131121_0f34"
# "20171213_130942_0f52"
# "20171212_131053_1030"
# "20171212_131052_1030"
# "20171212_131051_1030"
# "20171204_131029_1013"
# "20171204_131028_1013"
# "20171211_130911_102c"
# "20171211_130910_102c"
# "20171211_130909_102c"
# "20171211_131012_1002"
# "20171211_131011_1002"
# "20171211_131010_1002"
# "20171210_131000_0f22"
# "20171210_130959_0f22"
# "20171210_130958_0f22"
# "20171209_131027_0f43"
# "20171209_131026_0f43"
# "20171209_131025_0f43"
# "20171208_131127_1034"
# "20171208_131125_1034"
# "20171207_131023_1024"
# "20171206_130938_1009"
# "20171206_130937_1009"
# "20171206_130936_1009"
# "20171205_130935_0f51"
# "20171205_131017_0f31"
# "20171205_131016_0f31"
# "20171205_131015_0f31"
# "20171205_130934_0f51"
# "20171204_131027_1013"
# "20171201_132624_0c59"
# "20171202_130852_1001"
# "20171202_130851_1001"
# "20171202_130850_1001"
# "20171202_130957_100e"
# "20171202_130956_100e"
# "20171202_130955_100e"
# "20171201_131241_0e2f"
# "20171201_131240_0e2f"
# "20171201_131239_0e2f"
# "20171130_130928_0f25"
# "20171130_130927_0f25"
# "20171130_131043_103a"
# "20171130_131042_103a"
# "20171124_153525_0d05"
# "20171129_131019_1011"
# "20171129_131018_1011"
# "20171124_153524_1_0d05"
# "20171128_130816_1025"
# "20171124_153524_0d05"
# "20171127_130905_1023"
# "20171126_130957_103d"
# "20171126_130956_103d"
# "20171126_130857_0f28"
# "20171126_130858_0f28"
# "20171125_130940_102e"
# "20171125_130939_102e"
# "20171125_130938_102e"
# "20171125_151339_101c"
# "20171125_151338_101c"
# "20171125_151337_101c"
# "20171121_131012_0f34"
# "20171121_131011_0f34"
# "20171121_151431_104b"
# "20171121_151430_104b"
# "20171121_131013_0f34"
# "20171124_130926_1036"
# "20171124_130925_1036"
# "20171124_130924_1036"
# "20171121_180825_1_0c62"
# "20171122_131516_0e2f"
# "20171122_131515_0e2f"
# "20171122_130936_0f15"
# "20171122_130935_0f15"
# "20171122_130934_0f15"
# "20171119_151551_101c"
# "20171119_151550_101c"
# "20171119_151549_101c"
# "20171119_094435_1_0c81"
# "20171119_094434_1_0c81"
# "20171119_094434_0c81"
# "20171121_180828_0c62"

# %%
# Print the first feature
p(features[1])
# Out:
# {
#   "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180127_131216_0f12",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180127_131216_0f12/assets/",
#     "thumbnail": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180127_131216_0f12/thumb"
#   },
#   "_permissions": [
#     "assets.basic_analytic_rpc_nitf:download",
#     "assets.analytic_xml:download",
#     "assets.basic_analytic_dn:download",
#     "assets.basic_analytic_dn_xml_nitf:download",
#     "assets.basic_analytic_dn_nitf:download",
#     "assets.basic_analytic_xml:download",
#     "assets.basic_analytic_nitf:download",
#     "assets.basic_analytic_rpc:download",
#     "assets.analytic_dn:download",
#     "assets.basic_udm:download",
#     "assets.basic_analytic_dn_rpc_nitf:download",
#     "assets.analytic:download",
#     "assets.analytic_dn_xml:download",
#     "assets.analytic_sr:download",
#     "assets.basic_analytic_dn_xml:download",
#     "assets.basic_analytic_dn_rpc:download",
#     "assets.basic_analytic_xml_nitf:download",
#     "assets.basic_analytic:download",
#     "assets.udm:download"
#   ],
#   "geometry": {
#     "coordinates": [
#       [
#         [
#           -56.78081098665031,
#           -34.06896867983799
#         ],
#         [
#           -56.501752850475754,
#           -34.11866187798789
#         ],
#         [
#           -56.52070298423228,
#           -34.19379305468161
#         ],
#         [
#           -56.80016983035798,
#           -34.14403034165962
#         ],
#         [
#           -56.784648343763,
#           -34.083595125217165
#         ],
#         [
#           -56.78455085349419,
#           -34.083612470243494
#         ],
#         [
#           -56.78081098665031,
#           -34.06896867983799
#         ]
#       ]
#     ],
#     "type": "Polygon"
#   },
#   "id": "20180127_131216_0f12",
#   "properties": {
#     "acquired": "2018-01-27T13:12:16.297277Z",
#     "anomalous_pixels": 0,
#     "cloud_cover": 0.81,
#     "columns": 9176,
#     "epsg_code": 32721,
#     "ground_control": true,
#     "gsd": 4,
#     "instrument": "PS2",
#     "item_type": "PSScene4Band",
#     "origin_x": 518421,
#     "origin_y": 6230178,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2018-01-27T20:24:56Z",
#     "quality_category": "standard",
#     "rows": 4642,
#     "satellite_id": "0f12",
#     "strip_id": "1115343",
#     "sun_azimuth": 77.9,
#     "sun_elevation": 49.7,
#     "updated": "2018-01-28T04:43:20Z",
#     "usable_data": 0,
#     "view_angle": 0.9
#   },
#   "type": "Feature"
# }

# %% [markdown]
# What happens when there are A LOT of results?
#
# When the number of matching items exceeds 250, the results are delivered in pages. Let's perform a search query that should return a large number of results:

# %%
# Setup a GeoJSON polygon for our geometry filter
geom = {
        "type": "Polygon",
        "coordinates": [
          [
            [
              -56.76155090332031,
              -34.23564771187117
            ],
            [
              -56.62010192871094,
              -34.23564771187117
            ],
            [
              -56.62010192871094,
              -34.1476127606448
            ],
            [
              -56.76155090332031,
              -34.1476127606448
            ],
            [
              -56.76155090332031,
              -34.23564771187117
            ]
          ]
        ]
      }

# Setup the geometry filter
geometry_filter = {
    "type": "GeometryFilter",
    "field_name": "geometry",
    "config": geom
}

# Setup the request
request = {
    "item_types" : item_types,
    "filter" : geometry_filter
}

# %%
# Send the POST request to the API quick search endpoint
res = session.post(quick_url, json=request)

# Assign the response to a variable
geojson = res.json()

# %%
# Print the response "_links" property
p(geojson["_links"])
# Out:
# {
#   "_first": "https://api.planet.com/data/v1/searches/5ec2c42703664f74937fd1242379d36a/results?_page=eyJxdWVyeV9wYXJhbXMiOiB7fSwgInNvcnRfcHJldiI6IGZhbHNlLCAicGFnZV9zaXplIjogMjUwLCAic29ydF9ieSI6ICJwdWJsaXNoZWQiLCAic29ydF9zdGFydCI6IG51bGwsICJzb3J0X2xhc3RfaWQiOiBudWxsLCAic29ydF9kZXNjIjogdHJ1ZX0%3D",
#   "_next": "https://api.planet.com/data/v1/searches/5ec2c42703664f74937fd1242379d36a/results?_page=eyJxdWVyeV9wYXJhbXMiOiB7fSwgInNvcnRfcHJldiI6IGZhbHNlLCAicGFnZV9zaXplIjogMjUwLCAic29ydF9ieSI6ICJwdWJsaXNoZWQiLCAic29ydF9zdGFydCI6ICIyMDE3LTExLTIyVDE5OjIzOjM2LjAwMDAwMFoiLCAic29ydF9sYXN0X2lkIjogIjIwMTcxMTIxXzE4MDgyOF8wYzYyIiwgInNvcnRfZGVzYyI6IHRydWV9",
#   "_self": "https://api.planet.com/data/v1/searches/5ec2c42703664f74937fd1242379d36a/results?_page=eyJxdWVyeV9wYXJhbXMiOiB7fSwgInNvcnRfcHJldiI6IGZhbHNlLCAicGFnZV9zaXplIjogMjUwLCAic29ydF9ieSI6ICJwdWJsaXNoZWQiLCAic29ydF9zdGFydCI6IG51bGwsICJzb3J0X2xhc3RfaWQiOiBudWxsLCAic29ydF9kZXNjIjogdHJ1ZX0%3D"
# }

# %%
# Assign the "_links" -> "_next" property (link to next page of results) to a variable 
next_url = geojson["_links"]["_next"]

# Print the link to the next page of results
print(next_url)
# Out:
# https://api.planet.com/data/v1/searches/5ec2c42703664f74937fd1242379d36a/results?_page=eyJxdWVyeV9wYXJhbXMiOiB7fSwgInNvcnRfcHJldiI6IGZhbHNlLCAicGFnZV9zaXplIjogMjUwLCAic29ydF9ieSI6ICJwdWJsaXNoZWQiLCAic29ydF9zdGFydCI6ICIyMDE3LTExLTIyVDE5OjIzOjM2LjAwMDAwMFoiLCAic29ydF9sYXN0X2lkIjogIjIwMTcxMTIxXzE4MDgyOF8wYzYyIiwgInNvcnRfZGVzYyI6IHRydWV9

# %% [markdown]
# The page size can be set with a `_page_size` parameter in the request:

# %%
# Send the POST request to the API quick search endpoint with a page size of 9
res = session.post(quick_url, json=request, params={"_page_size" : 9})

# Assign the response to a variable
geojson = res.json()

# Get the number of features present in the response
len(geojson["features"])
# Out:
# 9

# %% [markdown]
# ### Mapping Footprints Example
#
# The [`geojsonio`](https://pypi.python.org/pypi/geojsonio/) module can be used to map GeoJSON files and is therefore compatible with the output from Planet Data API searches.
#
# Make sure you've got the module installed and then let's use it to show our resuls on a map:

# %%
# Import the geojsonio python module
# You may need to install this on your system first
import geojsonio

# Assign the url variable to display the geojsonio map
geojsonio.embed()
url = geojsonio.display(res.text)

# %% [markdown]
# We can now iterate through the pages of results.

# %%
# Assign the next_url variable to the next page of results from the response (Setup the next page of results)
next_url = geojson["_links"]["_next"]

# Get the next page of results
res = session.get(next_url)

# Assign the response to a variable
geojson = res.json()

# Get the url see results on geojson.io
url = geojsonio.to_geojsonio(res.text)

# %%
# Setup the next page of results
next_url = geojson["_links"]["_next"]

# Get the next page of results
res = session.get(next_url)

# Assign the response to a variable
geojson = res.json()

# Get the url see results on geojson.io
url = geojsonio.to_geojsonio(res.text)

# %% [markdown]
# Cool huh? Now that we know how to search and find items we are interested in, let's try activating and downloading some assets.

# %% [markdown]
# ## Assets & Permissions
#
# Assets may be imagery files, image masks, metadata files or some other file type that might be associated with the item.
#
# The `_permissions` element in each feature contains a list of assets that the user has access to.

# %% [markdown]
# Let's pick the first item out of our search result to work with, and then see what the permissions are for that item:

# %%
# Assign a variable to the search result features (items)
features = geojson["features"]

# Get the first result's feature
feature = features[0]

# Print the ID
p(feature["id"])

# Print the permissions
p(feature["_permissions"])
# Out:
# "20180128_131306_1018"
# [
#   "assets.basic_analytic_rpc_nitf:download",
#   "assets.analytic_xml:download",
#   "assets.basic_analytic_dn:download",
#   "assets.basic_analytic_dn_xml_nitf:download",
#   "assets.basic_analytic_dn_nitf:download",
#   "assets.basic_analytic_xml:download",
#   "assets.basic_analytic_nitf:download",
#   "assets.basic_analytic_rpc:download",
#   "assets.analytic_dn:download",
#   "assets.basic_udm:download",
#   "assets.basic_analytic_dn_rpc_nitf:download",
#   "assets.analytic:download",
#   "assets.analytic_dn_xml:download",
#   "assets.analytic_sr:download",
#   "assets.basic_analytic_dn_xml:download",
#   "assets.basic_analytic_dn_rpc:download",
#   "assets.basic_analytic_xml_nitf:download",
#   "assets.basic_analytic:download",
#   "assets.udm:download"
# ]

# %% [markdown]
# Each item has an `assets` endpoint in the API that lists all of its assets. Let's get a list of available assets for our item:

# %%
# Get the assets link for the item
assets_url = feature["_links"]["assets"]

# Print the assets link
print(assets_url)
# Out:
# https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180128_131306_1018/assets/

# %%
# Send a GET request to the assets url for the item (Get the list of available assets for the item)
res = session.get(assets_url)

# Assign a variable to the response
assets = res.json()

# Print the asset types that are available
p(assets)
# Out:
# {
#   "analytic": {
#     "_links": {
#       "_self": "https://api.planet.com/data/v1/assets/eyJpIjogIjIwMTgwMTI4XzEzMTMwNl8xMDE4IiwgImMiOiAiUFNTY2VuZTRCYW5kIiwgInQiOiAiYW5hbHl0aWMiLCAiY3QiOiAiaXRlbS10eXBlIn0",
#       "activate": "https://api.planet.com/data/v1/assets/eyJpIjogIjIwMTgwMTI4XzEzMTMwNl8xMDE4IiwgImMiOiAiUFNTY2VuZTRCYW5kIiwgInQiOiAiYW5hbHl0aWMiLCAiY3QiOiAiaXRlbS10eXBlIn0/activate",
#       "type": "https://api.planet.com/data/v1/asset-types/analytic"
#     },
#     "_permissions": [
#       "download"
#     ],
#     "expires_at": "2018-02-02T17:00:11.027631",
#     "location": "https://api.planet.com/data/v1/download?token=eyJhbGciOiJIUzUxMiIsInR5cCI6IkpXVCJ9..45S67lidkWcYJPQGJgmTYvRbjUWYIawzIRMdHSm2bpgQM9IxkFJFopc8xjqunkgv3EATgQ0FlXiojKnNBz8ImQ",
#     "md5_digest": "2fb8cb4513166875e881f824689b955f",
#     "status": "active",
#     "type": "analytic"
#   },
#   "analytic_dn": {
#     "_links": {
#       "_self": "https://api.planet.com/data/v1/assets/eyJpIjogIjIwMTgwMTI4XzEzMTMwNl8xMDE4IiwgImMiOiAiUFNTY2VuZTRCYW5kIiwgInQiOiAiYW5hbHl0aWNfZG4iLCAiY3QiOiAiaXRlbS10eXBlIn0",
#       "activate": "https://api.planet.com/data/v1/assets/eyJpIjogIjIwMTgwMTI4XzEzMTMwNl8xMDE4IiwgImMiOiAiUFNTY2VuZTRCYW5kIiwgInQiOiAiYW5hbHl0aWNfZG4iLCAiY3QiOiAiaXRlbS10eXBlIn0/activate",
#       "type": "https://api.planet.com/data/v1/asset-types/analytic_dn"
#     },
#     "_permissions": [
#       "download"
#     ],
#     "md5_digest": null,
#     "status": "inactive",
#     "type": "analytic_dn"
#   },
#   "analytic_dn_xml": {
#     "_links": {
#       "_self": "https://api.planet.com/data/v1/assets/eyJpIjogIjIwMTgwMTI4XzEzMTMwNl8xMDE4IiwgImMiOiAiUFNTY2VuZTRCYW5kIiwgInQiOiAiYW5hbHl0aWNfZG5feG1sIiwgImN0IjogIml0ZW0tdHlwZSJ9",
#       "activate": "https://api.planet.com/data/v1/assets/eyJpIjogIjIwMTgwMTI4XzEzMTMwNl8xMDE4IiwgImMiOiAiUFNTY2VuZTRCYW5kIiwgInQiOiAiYW5hbHl0aWNfZG5feG1sIiwgImN0IjogIml0ZW0tdHlwZSJ9/activate",
#       "type": "https://api.planet.com/data/v1/asset-types/analytic_dn_xml"
#     },
#     "_permissions": [
#       "download"
#     ],
#     "md5_digest": null,
#     "status": "inactive",
#     "type": "analytic_dn_xml"
#   },
#   "analytic_sr": {
#     "_links": {
#       "_self": "https://api.planet.com/data/v1/assets/eyJpIjogIjIwMTgwMTI4XzEzMTMwNl8xMDE4IiwgImMiOiAiUFNTY2VuZTRCYW5kIiwgInQiOiAiYW5hbHl0aWNfc3IiLCAiY3QiOiAiaXRlbS10eXBlIn0",
#       "activate": "https://api.planet.com/data/v1/assets/eyJpIjogIjIwMTgwMTI4XzEzMTMwNl8xMDE4IiwgImMiOiAiUFNTY2VuZTRCYW5kIiwgInQiOiAiYW5hbHl0aWNfc3IiLCAiY3QiOiAiaXRlbS10eXBlIn0/activate",
#       "type": "https://api.planet.com/data/v1/asset-types/analytic_sr"
#     },
#     "_permissions": [
#       "download"
#     ],
#     "md5_digest": null,
#     "status": "inactive",
#     "type": "analytic_sr"
#   },
#   "analytic_xml": {
#     "_links": {
#       "_self": "https://api.planet.com/data/v1/assets/eyJpIjogIjIwMTgwMTI4XzEzMTMwNl8xMDE4IiwgImMiOiAiUFNTY2VuZTRCYW5kIiwgInQiOiAiYW5hbHl0aWNfeG1sIiwgImN0IjogIml0ZW0tdHlwZSJ9",
#       "activate": "https://api.planet.com/data/v1/assets/eyJpIjogIjIwMTgwMTI4XzEzMTMwNl8xMDE4IiwgImMiOiAiUFNTY2VuZTRCYW5kIiwgInQiOiAiYW5hbHl0aWNfeG1sIiwgImN0IjogIml0ZW0tdHlwZSJ9/activate",
#       "type": "https://api.planet.com/data/v1/asset-types/analytic_xml"
#     },
#     "_permissions": [
#       "download"
#     ],
#     "expires_at": "2018-02-02T17:00:11.017737",
#     "location": "https://api.planet.com/data/v1/download?token=eyJhbGciOiJIUzUxMiIsInR5cCI6IkpXVCJ9..h3t7vVYUoXfR_QH6xr2Ak0k92vO3WvWjfEUX1JC2XEnhsb7qidHVMujB83WaoezXtw1o-8fLSe2_TcehFcSgeA",
#     "md5_digest": "0ad98afc157e57fa7a0585bb1a15e68b",
#     "status": "active",
#     "type": "analytic_xml"
#   },
#   "basic_analytic": {
#     "_links": {
#       "_self": "https://api.planet.com/data/v1/assets/eyJpIjogIjIwMTgwMTI4XzEzMTMwNl8xMDE4IiwgImMiOiAiUFNTY2VuZTRCYW5kIiwgInQiOiAiYmFzaWNfYW5hbHl0aWMiLCAiY3QiOiAiaXRlbS10eXBlIn0",
#       "activate": "https://api.planet.com/data/v1/assets/eyJpIjogIjIwMTgwMTI4XzEzMTMwNl8xMDE4IiwgImMiOiAiUFNTY2VuZTRCYW5kIiwgInQiOiAiYmFzaWNfYW5hbHl0aWMiLCAiY3QiOiAiaXRlbS10eXBlIn0/activate",
#       "type": "https://api.planet.com/data/v1/asset-types/basic_analytic"
#     },
#     "_permissions": [
#       "download"
#     ],
#     "md5_digest": null,
#     "status": "inactive",
#     "type": "basic_analytic"
#   },
#   "basic_analytic_dn": {
#     "_links": {
#       "_self": "https://api.planet.com/data/v1/assets/eyJpIjogIjIwMTgwMTI4XzEzMTMwNl8xMDE4IiwgImMiOiAiUFNTY2VuZTRCYW5kIiwgInQiOiAiYmFzaWNfYW5hbHl0aWNfZG4iLCAiY3QiOiAiaXRlbS10eXBlIn0",
#       "activate": "https://api.planet.com/data/v1/assets/eyJpIjogIjIwMTgwMTI4XzEzMTMwNl8xMDE4IiwgImMiOiAiUFNTY2VuZTRCYW5kIiwgInQiOiAiYmFzaWNfYW5hbHl0aWNfZG4iLCAiY3QiOiAiaXRlbS10eXBlIn0/activate",
#       "type": "https://api.planet.com/data/v1/asset-types/basic_analytic_dn"
#     },
#     "_permissions": [
#       "download"
#     ],
#     "md5_digest": null,
#     "status": "inactive",
#     "type": "basic_analytic_dn"
#   },
#   "basic_analytic_dn_nitf": {
#     "_links": {
#       "_self": "https://api.planet.com/data/v1/assets/eyJpIjogIjIwMTgwMTI4XzEzMTMwNl8xMDE4IiwgImMiOiAiUFNTY2VuZTRCYW5kIiwgInQiOiAiYmFzaWNfYW5hbHl0aWNfZG5fbml0ZiIsICJjdCI6ICJpdGVtLXR5cGUifQ",
#       "activate": "https://api.planet.com/data/v1/assets/eyJpIjogIjIwMTgwMTI4XzEzMTMwNl8xMDE4IiwgImMiOiAiUFNTY2VuZTRCYW5kIiwgInQiOiAiYmFzaWNfYW5hbHl0aWNfZG5fbml0ZiIsICJjdCI6ICJpdGVtLXR5cGUifQ/activate",
#       "type": "https://api.planet.com/data/v1/asset-types/basic_analytic_dn_nitf"
#     },
#     "_permissions": [
#       "download"
#     ],
#     "md5_digest": null,
#     "status": "inactive",
#     "type": "basic_analytic_dn_nitf"
#   },
#   "basic_analytic_dn_rpc": {
#     "_links": {
#       "_self": "https://api.planet.com/data/v1/assets/eyJpIjogIjIwMTgwMTI4XzEzMTMwNl8xMDE4IiwgImMiOiAiUFNTY2VuZTRCYW5kIiwgInQiOiAiYmFzaWNfYW5hbHl0aWNfZG5fcnBjIiwgImN0IjogIml0ZW0tdHlwZSJ9",
#       "activate": "https://api.planet.com/data/v1/assets/eyJpIjogIjIwMTgwMTI4XzEzMTMwNl8xMDE4IiwgImMiOiAiUFNTY2VuZTRCYW5kIiwgInQiOiAiYmFzaWNfYW5hbHl0aWNfZG5fcnBjIiwgImN0IjogIml0ZW0tdHlwZSJ9/activate",
#       "type": "https://api.planet.com/data/v1/asset-types/basic_analytic_dn_rpc"
#     },
#     "_permissions": [
#       "download"
#     ],
#     "md5_digest": null,
#     "status": "inactive",
#     "type": "basic_analytic_dn_rpc"
#   },
#   "basic_analytic_dn_rpc_nitf": {
#     "_links": {
#       "_self": "https://api.planet.com/data/v1/assets/eyJpIjogIjIwMTgwMTI4XzEzMTMwNl8xMDE4IiwgImMiOiAiUFNTY2VuZTRCYW5kIiwgInQiOiAiYmFzaWNfYW5hbHl0aWNfZG5fcnBjX25pdGYiLCAiY3QiOiAiaXRlbS10eXBlIn0",
#       "activate": "https://api.planet.com/data/v1/assets/eyJpIjogIjIwMTgwMTI4XzEzMTMwNl8xMDE4IiwgImMiOiAiUFNTY2VuZTRCYW5kIiwgInQiOiAiYmFzaWNfYW5hbHl0aWNfZG5fcnBjX25pdGYiLCAiY3QiOiAiaXRlbS10eXBlIn0/activate",
#       "type": "https://api.planet.com/data/v1/asset-types/basic_analytic_dn_rpc_nitf"
#     },
#     "_permissions": [
#       "download"
#     ],
#     "md5_digest": null,
#     "status": "inactive",
#     "type": "basic_analytic_dn_rpc_nitf"
#   },
#   "basic_analytic_dn_xml": {
#     "_links": {
#       "_self": "https://api.planet.com/data/v1/assets/eyJpIjogIjIwMTgwMTI4XzEzMTMwNl8xMDE4IiwgImMiOiAiUFNTY2VuZTRCYW5kIiwgInQiOiAiYmFzaWNfYW5hbHl0aWNfZG5feG1sIiwgImN0IjogIml0ZW0tdHlwZSJ9",
#       "activate": "https://api.planet.com/data/v1/assets/eyJpIjogIjIwMTgwMTI4XzEzMTMwNl8xMDE4IiwgImMiOiAiUFNTY2VuZTRCYW5kIiwgInQiOiAiYmFzaWNfYW5hbHl0aWNfZG5feG1sIiwgImN0IjogIml0ZW0tdHlwZSJ9/activate",
#       "type": "https://api.planet.com/data/v1/asset-types/basic_analytic_dn_xml"
#     },
#     "_permissions": [
#       "download"
#     ],
#     "md5_digest": null,
#     "status": "inactive",
#     "type": "basic_analytic_dn_xml"
#   },
#   "basic_analytic_dn_xml_nitf": {
#     "_links": {
#       "_self": "https://api.planet.com/data/v1/assets/eyJpIjogIjIwMTgwMTI4XzEzMTMwNl8xMDE4IiwgImMiOiAiUFNTY2VuZTRCYW5kIiwgInQiOiAiYmFzaWNfYW5hbHl0aWNfZG5feG1sX25pdGYiLCAiY3QiOiAiaXRlbS10eXBlIn0",
#       "activate": "https://api.planet.com/data/v1/assets/eyJpIjogIjIwMTgwMTI4XzEzMTMwNl8xMDE4IiwgImMiOiAiUFNTY2VuZTRCYW5kIiwgInQiOiAiYmFzaWNfYW5hbHl0aWNfZG5feG1sX25pdGYiLCAiY3QiOiAiaXRlbS10eXBlIn0/activate",
#       "type": "https://api.planet.com/data/v1/asset-types/basic_analytic_dn_xml_nitf"
#     },
#     "_permissions": [
#       "download"
#     ],
#     "md5_digest": null,
#     "status": "inactive",
#     "type": "basic_analytic_dn_xml_nitf"
#   },
#   "basic_analytic_nitf": {
#     "_links": {
#       "_self": "https://api.planet.com/data/v1/assets/eyJpIjogIjIwMTgwMTI4XzEzMTMwNl8xMDE4IiwgImMiOiAiUFNTY2VuZTRCYW5kIiwgInQiOiAiYmFzaWNfYW5hbHl0aWNfbml0ZiIsICJjdCI6ICJpdGVtLXR5cGUifQ",
#       "activate": "https://api.planet.com/data/v1/assets/eyJpIjogIjIwMTgwMTI4XzEzMTMwNl8xMDE4IiwgImMiOiAiUFNTY2VuZTRCYW5kIiwgInQiOiAiYmFzaWNfYW5hbHl0aWNfbml0ZiIsICJjdCI6ICJpdGVtLXR5cGUifQ/activate",
#       "type": "https://api.planet.com/data/v1/asset-types/basic_analytic_nitf"
#     },
#     "_permissions": [
#       "download"
#     ],
#     "md5_digest": null,
#     "status": "inactive",
#     "type": "basic_analytic_nitf"
#   },
#   "basic_analytic_rpc": {
#     "_links": {
#       "_self": "https://api.planet.com/data/v1/assets/eyJpIjogIjIwMTgwMTI4XzEzMTMwNl8xMDE4IiwgImMiOiAiUFNTY2VuZTRCYW5kIiwgInQiOiAiYmFzaWNfYW5hbHl0aWNfcnBjIiwgImN0IjogIml0ZW0tdHlwZSJ9",
#       "activate": "https://api.planet.com/data/v1/assets/eyJpIjogIjIwMTgwMTI4XzEzMTMwNl8xMDE4IiwgImMiOiAiUFNTY2VuZTRCYW5kIiwgInQiOiAiYmFzaWNfYW5hbHl0aWNfcnBjIiwgImN0IjogIml0ZW0tdHlwZSJ9/activate",
#       "type": "https://api.planet.com/data/v1/asset-types/basic_analytic_rpc"
#     },
#     "_permissions": [
#       "download"
#     ],
#     "md5_digest": null,
#     "status": "inactive",
#     "type": "basic_analytic_rpc"
#   },
#   "basic_analytic_rpc_nitf": {
#     "_links": {
#       "_self": "https://api.planet.com/data/v1/assets/eyJpIjogIjIwMTgwMTI4XzEzMTMwNl8xMDE4IiwgImMiOiAiUFNTY2VuZTRCYW5kIiwgInQiOiAiYmFzaWNfYW5hbHl0aWNfcnBjX25pdGYiLCAiY3QiOiAiaXRlbS10eXBlIn0",
#       "activate": "https://api.planet.com/data/v1/assets/eyJpIjogIjIwMTgwMTI4XzEzMTMwNl8xMDE4IiwgImMiOiAiUFNTY2VuZTRCYW5kIiwgInQiOiAiYmFzaWNfYW5hbHl0aWNfcnBjX25pdGYiLCAiY3QiOiAiaXRlbS10eXBlIn0/activate",
#       "type": "https://api.planet.com/data/v1/asset-types/basic_analytic_rpc_nitf"
#     },
#     "_permissions": [
#       "download"
#     ],
#     "md5_digest": null,
#     "status": "inactive",
#     "type": "basic_analytic_rpc_nitf"
#   },
#   "basic_analytic_xml": {
#     "_links": {
#       "_self": "https://api.planet.com/data/v1/assets/eyJpIjogIjIwMTgwMTI4XzEzMTMwNl8xMDE4IiwgImMiOiAiUFNTY2VuZTRCYW5kIiwgInQiOiAiYmFzaWNfYW5hbHl0aWNfeG1sIiwgImN0IjogIml0ZW0tdHlwZSJ9",
#       "activate": "https://api.planet.com/data/v1/assets/eyJpIjogIjIwMTgwMTI4XzEzMTMwNl8xMDE4IiwgImMiOiAiUFNTY2VuZTRCYW5kIiwgInQiOiAiYmFzaWNfYW5hbHl0aWNfeG1sIiwgImN0IjogIml0ZW0tdHlwZSJ9/activate",
#       "type": "https://api.planet.com/data/v1/asset-types/basic_analytic_xml"
#     },
#     "_permissions": [
#       "download"
#     ],
#     "md5_digest": null,
#     "status": "inactive",
#     "type": "basic_analytic_xml"
#   },
#   "basic_analytic_xml_nitf": {
#     "_links": {
#       "_self": "https://api.planet.com/data/v1/assets/eyJpIjogIjIwMTgwMTI4XzEzMTMwNl8xMDE4IiwgImMiOiAiUFNTY2VuZTRCYW5kIiwgInQiOiAiYmFzaWNfYW5hbHl0aWNfeG1sX25pdGYiLCAiY3QiOiAiaXRlbS10eXBlIn0",
#       "activate": "https://api.planet.com/data/v1/assets/eyJpIjogIjIwMTgwMTI4XzEzMTMwNl8xMDE4IiwgImMiOiAiUFNTY2VuZTRCYW5kIiwgInQiOiAiYmFzaWNfYW5hbHl0aWNfeG1sX25pdGYiLCAiY3QiOiAiaXRlbS10eXBlIn0/activate",
#       "type": "https://api.planet.com/data/v1/asset-types/basic_analytic_xml_nitf"
#     },
#     "_permissions": [
#       "download"
#     ],
#     "md5_digest": null,
#     "status": "inactive",
#     "type": "basic_analytic_xml_nitf"
#   },
#   "basic_udm": {
#     "_links": {
#       "_self": "https://api.planet.com/data/v1/assets/eyJpIjogIjIwMTgwMTI4XzEzMTMwNl8xMDE4IiwgImMiOiAiUFNTY2VuZTRCYW5kIiwgInQiOiAiYmFzaWNfdWRtIiwgImN0IjogIml0ZW0tdHlwZSJ9",
#       "activate": "https://api.planet.com/data/v1/assets/eyJpIjogIjIwMTgwMTI4XzEzMTMwNl8xMDE4IiwgImMiOiAiUFNTY2VuZTRCYW5kIiwgInQiOiAiYmFzaWNfdWRtIiwgImN0IjogIml0ZW0tdHlwZSJ9/activate",
#       "type": "https://api.planet.com/data/v1/asset-types/basic_udm"
#     },
#     "_permissions": [
#       "download"
#     ],
#     "md5_digest": null,
#     "status": "inactive",
#     "type": "basic_udm"
#   },
#   "udm": {
#     "_links": {
#       "_self": "https://api.planet.com/data/v1/assets/eyJpIjogIjIwMTgwMTI4XzEzMTMwNl8xMDE4IiwgImMiOiAiUFNTY2VuZTRCYW5kIiwgInQiOiAidWRtIiwgImN0IjogIml0ZW0tdHlwZSJ9",
#       "activate": "https://api.planet.com/data/v1/assets/eyJpIjogIjIwMTgwMTI4XzEzMTMwNl8xMDE4IiwgImMiOiAiUFNTY2VuZTRCYW5kIiwgInQiOiAidWRtIiwgImN0IjogIml0ZW0tdHlwZSJ9/activate",
#       "type": "https://api.planet.com/data/v1/asset-types/udm"
#     },
#     "_permissions": [
#       "download"
#     ],
#     "expires_at": "2018-02-02T17:00:11.036083",
#     "location": "https://api.planet.com/data/v1/download?token=eyJhbGciOiJIUzUxMiIsInR5cCI6IkpXVCJ9..p4u-ZuR-2Rcmpf2pRer2mCC7KP827KR-ZbymiicL7Mm9dNk4vgu7tzAwB6HVvS9LDc32OTxIt0lKxrqwYRRqYA",
#     "md5_digest": "698c0d46f8e7034b1b5229c70532b32c",
#     "status": "active",
#     "type": "udm"
#   }
# }

# %% [markdown]
# We can see that most items have several assets available. Let's check out the "visual" asset for this item:

# %%
# Assign a variable to the visual asset from the item's assets
analytic = assets["analytic"]

# Print the visual asset data
p(analytic)
# Out:
# {
#   "_links": {
#     "_self": "https://api.planet.com/data/v1/assets/eyJpIjogIjIwMTgwMTI4XzEzMTMwNl8xMDE4IiwgImMiOiAiUFNTY2VuZTRCYW5kIiwgInQiOiAiYW5hbHl0aWMiLCAiY3QiOiAiaXRlbS10eXBlIn0",
#     "activate": "https://api.planet.com/data/v1/assets/eyJpIjogIjIwMTgwMTI4XzEzMTMwNl8xMDE4IiwgImMiOiAiUFNTY2VuZTRCYW5kIiwgInQiOiAiYW5hbHl0aWMiLCAiY3QiOiAiaXRlbS10eXBlIn0/activate",
#     "type": "https://api.planet.com/data/v1/asset-types/analytic"
#   },
#   "_permissions": [
#     "download"
#   ],
#   "expires_at": "2018-02-02T17:00:11.027631",
#   "location": "https://api.planet.com/data/v1/download?token=eyJhbGciOiJIUzUxMiIsInR5cCI6IkpXVCJ9..45S67lidkWcYJPQGJgmTYvRbjUWYIawzIRMdHSm2bpgQM9IxkFJFopc8xjqunkgv3EATgQ0FlXiojKnNBz8ImQ",
#   "md5_digest": "2fb8cb4513166875e881f824689b955f",
#   "status": "active",
#   "type": "analytic"
# }

# %% [markdown]
# ### Activating Assets
#
# Before an asset is available for download, it must be **activated**.
#
# You can activate an asset by sending a *POST* or *GET* request to the asset's **"activation link"**.
#
# The activation usually takes a little bit of time, but hey, I'm sure by now you have some ideas on how to automate your workflow. Go robots!

# %%
# Setup the activation url for a particular asset (in this case the visual asset)
activation_url = analytic["_links"]["activate"]

# Send a request to the activation url to activate the item
res = session.get(activation_url)

# Print the response from the activation request
p(res.status_code)
# Out:
# 204

# %% [markdown]
# #### Activation Response Codes
#
# After hitting an activation url, you should get a response code back from the API:
#
# * **`202`** - The request has been accepted and the activation will begin shortly.
# * **`204`** - The asset is already active and no further action is needed.
# * **`401`** - The user does not have permissions to download this file.

# %% [markdown]
# After requesting to actiate an asset, let's do another request to see if the assset's status has changed:

# %%
# Send a request to the item's assets url
res = session.get(assets_url)

# Assign a variable to the item's assets url response
assets = res.json()

# Assign a variable to the visual asset from the response
analytic = assets["analytic"]

# Print the visual asset data
p(analytic)
# Out:
# {
#   "_links": {
#     "_self": "https://api.planet.com/data/v1/assets/eyJpIjogIjIwMTgwMTI4XzEzMTMwNl8xMDE4IiwgImMiOiAiUFNTY2VuZTRCYW5kIiwgInQiOiAiYW5hbHl0aWMiLCAiY3QiOiAiaXRlbS10eXBlIn0",
#     "activate": "https://api.planet.com/data/v1/assets/eyJpIjogIjIwMTgwMTI4XzEzMTMwNl8xMDE4IiwgImMiOiAiUFNTY2VuZTRCYW5kIiwgInQiOiAiYW5hbHl0aWMiLCAiY3QiOiAiaXRlbS10eXBlIn0/activate",
#     "type": "https://api.planet.com/data/v1/asset-types/analytic"
#   },
#   "_permissions": [
#     "download"
#   ],
#   "expires_at": "2018-02-02T17:00:26.378291",
#   "location": "https://api.planet.com/data/v1/download?token=eyJhbGciOiJIUzUxMiIsInR5cCI6IkpXVCJ9..2Gu_BE9OcC6AlNU1diNK6JfY17_k9V_Jjocog6Ugevqqy-CDRclVVJyFqc9wblcq3YwLsahVJEwjdEFkrbnXBw",
#   "md5_digest": "2fb8cb4513166875e881f824689b955f",
#   "status": "active",
#   "type": "analytic"
# }

# %% [markdown]
# #### Activation Status
#
# An asset may have a `status` of `inactive`, `activating` or `active`.
#
# Once an asset is active, the response will contain a `location`. We'll use the `location` to download the asset!

# %% [markdown]
# ### Downloading Assets
#
# The asset's `location` property points asset file for use to download. Are you ready to download the asset? Let's do it!

# %%
# Assign a variable to the visual asset's location endpoint
location_url = analytic["location"]

# Print the location endpoint
print(location_url)
# Out:
# https://api.planet.com/data/v1/download?token=eyJhbGciOiJIUzUxMiIsInR5cCI6IkpXVCJ9..2Gu_BE9OcC6AlNU1diNK6JfY17_k9V_Jjocog6Ugevqqy-CDRclVVJyFqc9wblcq3YwLsahVJEwjdEFkrbnXBw

# %% [markdown]
# There's the location url! You could click on it to open it in a browser and download the file... but why not let your code do it?
#
# Let's write a small helper function to download asset files:

# %%
# Create a function to download asset files
# Parameters: 
# - url (the location url)
# - filename (the filename to save it as. defaults to whatever the file is called originally)

def pl_download(url, filename=None):
    
    # Send a GET request to the provided location url, using your API Key for authentication
    res = requests.get(url, stream=True, auth=(PLANET_API_KEY, ""))
    # If no filename argument is given
    if not filename :
        # Construct a filename from the API response
        if "content-disposition" in res.headers:
            filename = res.headers["content-disposition"].split("filename=")[-1].strip("'\"")
        # Construct a filename from the location url
        else:
            filename = url.split("=")[1][:10]
    # Save the file
    with open('D:\\OneDrive\\teleysig_javierMoreira\\TrabajoFinal\\Tesis\\seguimiento ndvi\\downloads\\PSScene4Band/' + filename, "wb") as f:
        for chunk in res.iter_content(chunk_size=1024):
            if chunk: # filter out keep-alive new chunks
                f.write(chunk)
                f.flush()

    return filename

# %%
# Download the file from an activated asset's location url
pl_download(location_url)
# Out:
# '20180128_131306_1018_3B_AnalyticMS.tif'

# %% [markdown]
# **High Five!** You should now be downloading your very own GeoTIFF! We can't wait to see what you'll do with it!

# %% [markdown]
# ### Rate Limits
#
# ---
#
# Now that you know how to download assets, you should probably keep some of the API **rate limits** in mind:
#
# * For most endpoints, the rate limit is 10 requests per second, per API key.
# * For activation endpoints, the rate limit is 5 requests per second, per API key.
# * For download endpoints, the rate limit is 15 requests per second, per API key.
#
# If you're writing to code to automate accessing the API, you should account for `429` responses and handle retries after a *backoff period*.

# %% [markdown]
# ## Saved Searches
#
# ---
#
# The `/searches` endpoint lets you created saved searches that can be reused.
#
# To view your saved searches, visit the [`searches/?search_type=saved`](https://api.planet.com/data/v1/searches/?search_type=saved) endpoint.
#
# Finally, let's create a saved search:

# %%
# Setup the saved searches endpoint url
searches_url = "{}/searches".format(URL)
print(searches_url)
# Out:
# https://api.planet.com/data/v1/searches

# %%
# Setup the request, specifying a name for the saved search, along with the usual search item_types and filter.
request = {
    "name" : "xprimera",
    "item_types" : item_types,
    "filter" : geometry_filter
}

# Send a POST request to the saved searches endpoint (Create the saved search)
res = session.post(searches_url, json=request)

# Print the response
p(res.json())
# Out:
# {
#   "_links": {
#     "_first": "https://api.planet.com/data/v1/searches/?_page=eyJxdWVyeV9wYXJhbXMiOiB7InNlYXJjaF90eXBlIjogImFueSJ9LCAic29ydF9wcmV2IjogZmFsc2UsICJwYWdlX3NpemUiOiAyNTAsICJzb3J0X2J5IjogImNyZWF0ZWQiLCAic29ydF9zdGFydCI6IG51bGwsICJzb3J0X2xhc3RfaWQiOiBudWxsLCAic29ydF9kZXNjIjogdHJ1ZX0%3D",
#     "_next": "https://api.planet.com/data/v1/searches/?_page=%3D%3D",
#     "_prev": "https://api.planet.com/data/v1/searches/?_page=",
#     "_self": "https://api.planet.com/data/v1/searches/?_page=eyJxdWVyeV9wYXJhbXMiOiB7InNlYXJjaF90eXBlIjogImFueSJ9LCAic29ydF9wcmV2IjogZmFsc2UsICJwYWdlX3NpemUiOiAyNTAsICJzb3J0X2J5IjogImNyZWF0ZWQiLCAic29ydF9zdGFydCI6IG51bGwsICJzb3J0X2xhc3RfaWQiOiBudWxsLCAic29ydF9kZXNjIjogdHJ1ZX0%3D"
#   },
#   "searches": [
#     {
#       "__daily_email_enabled": false,
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/searches/b22f749860b9443a95fd33bf1ea79fc9",
#         "results": "https://api.planet.com/data/v1/searches/b22f749860b9443a95fd33bf1ea79fc9/results"
#       },
#       "created": "2018-02-02T15:03:28.692345Z",
#       "filter": {
#         "config": {
#           "coordinates": [
#             [
#               [
#                 -56.76155090332031,
#                 -34.23564771187117
#               ],
#               [
#                 -56.62010192871094,
#                 -34.23564771187117
#               ],
#               [
#                 -56.62010192871094,
#                 -34.1476127606448
#               ],
#               [
#                 -56.76155090332031,
#                 -34.1476127606448
#               ],
#               [
#                 -56.76155090332031,
#                 -34.23564771187117
#               ]
#             ]
#           ],
#           "type": "Polygon"
#         },
#         "field_name": "geometry",
#         "type": "GeometryFilter"
#       },
#       "id": "b22f749860b9443a95fd33bf1ea79fc9",
#       "item_types": [
#         "PSScene4Band"
#       ],
#       "last_executed": "2018-02-02T15:05:56.646659Z",
#       "name": "b22f749860b9443a95fd33bf1ea79fc9",
#       "search_type": "quick",
#       "updated": "2018-02-02T15:05:56.646883Z"
#     },
#     {
#       "__daily_email_enabled": false,
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/searches/5ec2c42703664f74937fd1242379d36a",
#         "results": "https://api.planet.com/data/v1/searches/5ec2c42703664f74937fd1242379d36a/results"
#       },
#       "created": "2018-02-02T14:59:03.360982Z",
#       "filter": {
#         "config": {
#           "coordinates": [
#             [
#               [
#                 -56.76155090332031,
#                 -34.23564771187117
#               ],
#               [
#                 -56.62010192871094,
#                 -34.23564771187117
#               ],
#               [
#                 -56.62010192871094,
#                 -34.1476127606448
#               ],
#               [
#                 -56.76155090332031,
#                 -34.1476127606448
#               ],
#               [
#                 -56.76155090332031,
#                 -34.23564771187117
#               ]
#             ]
#           ],
#           "type": "Polygon"
#         },
#         "field_name": "geometry",
#         "type": "GeometryFilter"
#       },
#       "id": "5ec2c42703664f74937fd1242379d36a",
#       "item_types": [
#         "PSScene4Band"
#       ],
#       "last_executed": "2018-02-02T14:59:03.369248Z",
#       "name": "5ec2c42703664f74937fd1242379d36a",
#       "search_type": "quick",
#       "updated": "2018-02-02T14:59:03.369406Z"
#     },
#     {
#       "__daily_email_enabled": false,
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/searches/5285ebc4144b4b53b5cc93b7b08ff892",
#         "results": "https://api.planet.com/data/v1/searches/5285ebc4144b4b53b5cc93b7b08ff892/results"
#       },
#       "created": "2018-02-02T14:56:10.729281Z",
#       "filter": {
#         "config": {
#           "coordinates": [
#             [
#               [
#                 -56.76155090332031,
#                 -34.23564771187117
#               ],
#               [
#                 -56.62010192871094,
#                 -34.23564771187117
#               ],
#               [
#                 -56.62010192871094,
#                 -34.1476127606448
#               ],
#               [
#                 -56.76155090332031,
#                 -34.1476127606448
#               ],
#               [
#                 -56.76155090332031,
#                 -34.23564771187117
#               ]
#             ]
#           ],
#           "type": "Polygon"
#         },
#         "field_name": "geometry",
#         "type": "GeometryFilter"
#       },
#       "id": "5285ebc4144b4b53b5cc93b7b08ff892",
#       "item_types": [
#         "PSScene4Band"
#       ],
#       "last_executed": "2018-02-02T14:56:10.758645Z",
#       "name": "5285ebc4144b4b53b5cc93b7b08ff892",
#       "search_type": "quick",
#       "updated": "2018-02-02T14:56:10.758789Z"
#     },
#     {
#       "__daily_email_enabled": false,
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/searches/6e632073709e4df99aa26f984873d2a6",
#         "results": "https://api.planet.com/data/v1/searches/6e632073709e4df99aa26f984873d2a6/results"
#       },
#       "created": "2018-02-01T16:38:48.537957Z",
#       "filter": {
#         "config": [
#           {
#             "config": {
#               "coordinates": [
#                 [
#                   [
#                     -57.30460166931152,
#                     -33.232872481362676
#                   ],
#                   [
#                     -57.25773811340332,
#                     -33.232872481362676
#                   ],
#                   [
#                     -57.25773811340332,
#                     -33.19653763818525
#                   ],
#                   [
#                     -57.30460166931152,
#                     -33.19653763818525
#                   ],
#                   [
#                     -57.30460166931152,
#                     -33.232872481362676
#                   ]
#                 ]
#               ],
#               "type": "Polygon"
#             },
#             "field_name": "geometry",
#             "type": "GeometryFilter"
#           },
#           {
#             "config": {
#               "gte": "2017-12-29T00:00:00Z",
#               "lte": "2018-01-31T00:00:00Z"
#             },
#             "field_name": "acquired",
#             "type": "DateRangeFilter"
#           },
#           {
#             "config": {
#               "lte": 0.1
#             },
#             "field_name": "cloud_cover",
#             "type": "RangeFilter"
#           }
#         ],
#         "type": "AndFilter"
#       },
#       "id": "6e632073709e4df99aa26f984873d2a6",
#       "item_types": [
#         "PSScene4Band"
#       ],
#       "last_executed": "2018-02-01T16:38:48.547294Z",
#       "name": "6e632073709e4df99aa26f984873d2a6",
#       "search_type": "quick",
#       "updated": "2018-02-01T16:38:48.547441Z"
#     },
#     {
#       "__daily_email_enabled": false,
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/searches/37049c23fa944aae819af6f6e8b44234",
#         "results": "https://api.planet.com/data/v1/searches/37049c23fa944aae819af6f6e8b44234/results"
#       },
#       "created": "2018-02-01T16:36:57.446789Z",
#       "filter": {
#         "config": [
#           {
#             "config": {
#               "coordinates": [
#                 [
#                   [
#                     -57.30460166931152,
#                     -33.232872481362676
#                   ],
#                   [
#                     -57.25773811340332,
#                     -33.232872481362676
#                   ],
#                   [
#                     -57.25773811340332,
#                     -33.19653763818525
#                   ],
#                   [
#                     -57.30460166931152,
#                     -33.19653763818525
#                   ],
#                   [
#                     -57.30460166931152,
#                     -33.232872481362676
#                   ]
#                 ]
#               ],
#               "type": "Polygon"
#             },
#             "field_name": "geometry",
#             "type": "GeometryFilter"
#           },
#           {
#             "config": {
#               "gte": "2017-12-29T00:00:00Z",
#               "lte": "2018-01-31T00:00:00Z"
#             },
#             "field_name": "acquired",
#             "type": "DateRangeFilter"
#           },
#           {
#             "config": {
#               "lte": 0.1
#             },
#             "field_name": "cloud_cover",
#             "type": "RangeFilter"
#           }
#         ],
#         "type": "AndFilter"
#       },
#       "id": "37049c23fa944aae819af6f6e8b44234",
#       "item_types": [
#         "PSScene4Band"
#       ],
#       "last_executed": "2018-02-01T16:36:58.245384Z",
#       "name": "37049c23fa944aae819af6f6e8b44234",
#       "search_type": "quick",
#       "updated": "2018-02-01T16:36:58.245587Z"
#     },
#     {
#       "__daily_email_enabled": false,
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/searches/db4102e38b394653b13cae8f62810ca5",
#         "results": "https://api.planet.com/data/v1/searches/db4102e38b394653b13cae8f62810ca5/results"
#       },
#       "created": "2018-02-01T16:32:58.743273Z",
#       "filter": {
#         "config": [
#           {
#             "config": {
#               "coordinates": [
#                 [
#                   [
#                     -57.30460166931152,
#                     -33.232872481362676
#                   ],
#                   [
#                     -57.25773811340332,
#                     -33.232872481362676
#                   ],
#                   [
#                     -57.25773811340332,
#                     -33.19653763818525
#                   ],
#                   [
#                     -57.30460166931152,
#                     -33.19653763818525
#                   ],
#                   [
#                     -57.30460166931152,
#                     -33.232872481362676
#                   ]
#                 ]
#               ],
#               "type": "Polygon"
#             },
#             "field_name": "geometry",
#             "type": "GeometryFilter"
#           },
#           {
#             "config": {
#               "gte": "2017-12-29T00:00:00Z",
#               "lte": "2018-01-31T00:00:00Z"
#             },
#             "field_name": "acquired",
#             "type": "DateRangeFilter"
#           },
#           {
#             "config": {
#               "lte": 0.1
#             },
#             "field_name": "cloud_cover",
#             "type": "RangeFilter"
#           }
#         ],
#         "type": "AndFilter"
#       },
#       "id": "db4102e38b394653b13cae8f62810ca5",
#       "item_types": [
#         "PSScene4Band"
#       ],
#       "last_executed": "2018-02-01T16:33:09.036345Z",
#       "name": "db4102e38b394653b13cae8f62810ca5",
#       "search_type": "quick",
#       "updated": "2018-02-01T16:33:09.036576Z"
#     },
#     {
#       "__daily_email_enabled": false,
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/searches/7e90789004ee449eaf358b302a22c07f",
#         "results": "https://api.planet.com/data/v1/searches/7e90789004ee449eaf358b302a22c07f/results"
#       },
#       "created": "2018-02-01T16:30:52.659959Z",
#       "filter": {
#         "config": [
#           {
#             "config": {
#               "coordinates": [
#                 [
#                   [
#                     -57.30460166931152,
#                     -33.232872481362676
#                   ],
#                   [
#                     -57.25773811340332,
#                     -33.232872481362676
#                   ],
#                   [
#                     -57.25773811340332,
#                     -33.19653763818525
#                   ],
#                   [
#                     -57.30460166931152,
#                     -33.19653763818525
#                   ],
#                   [
#                     -57.30460166931152,
#                     -33.232872481362676
#                   ]
#                 ]
#               ],
#               "type": "Polygon"
#             },
#             "field_name": "geometry",
#             "type": "GeometryFilter"
#           },
#           {
#             "config": {
#               "gte": "2017-12-29T00:00:00Z",
#               "lte": "2018-01-31T00:00:00Z"
#             },
#             "field_name": "acquired",
#             "type": "DateRangeFilter"
#           },
#           {
#             "config": {
#               "lte": 0.1
#             },
#             "field_name": "cloud_cover",
#             "type": "RangeFilter"
#           }
#         ],
#         "type": "AndFilter"
#       },
#       "id": "7e90789004ee449eaf358b302a22c07f",
#       "item_types": [
#         "PSScene4Band"
#       ],
#       "last_executed": "2018-02-01T16:30:56.199564Z",
#       "name": "7e90789004ee449eaf358b302a22c07f",
#       "search_type": "quick",
#       "updated": "2018-02-01T16:30:56.199772Z"
#     },
#     {
#       "__daily_email_enabled": false,
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/searches/a01c4102025f44dda65d535bd1f2fa40",
#         "results": "https://api.planet.com/data/v1/searches/a01c4102025f44dda65d535bd1f2fa40/results"
#       },
#       "created": "2018-02-01T16:29:09.450811Z",
#       "filter": {
#         "config": [
#           {
#             "config": {
#               "coordinates": [
#                 [
#                   [
#                     -57.30460166931152,
#                     -33.232872481362676
#                   ],
#                   [
#                     -57.25773811340332,
#                     -33.232872481362676
#                   ],
#                   [
#                     -57.25773811340332,
#                     -33.19653763818525
#                   ],
#                   [
#                     -57.30460166931152,
#                     -33.19653763818525
#                   ],
#                   [
#                     -57.30460166931152,
#                     -33.232872481362676
#                   ]
#                 ]
#               ],
#               "type": "Polygon"
#             },
#             "field_name": "geometry",
#             "type": "GeometryFilter"
#           },
#           {
#             "config": {
#               "gte": "2017-12-29T00:00:00Z",
#               "lte": "2018-01-31T00:00:00Z"
#             },
#             "field_name": "acquired",
#             "type": "DateRangeFilter"
#           },
#           {
#             "config": {
#               "lte": 0.1
#             },
#             "field_name": "cloud_cover",
#             "type": "RangeFilter"
#           }
#         ],
#         "type": "AndFilter"
#       },
#       "id": "a01c4102025f44dda65d535bd1f2fa40",
#       "item_types": [
#         "PSScene4Band"
#       ],
#       "last_executed": "2018-02-01T16:29:09.468466Z",
#       "name": "a01c4102025f44dda65d535bd1f2fa40",
#       "search_type": "quick",
#       "updated": "2018-02-01T16:29:09.468613Z"
#     },
#     {
#       "__daily_email_enabled": false,
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/searches/c49a5afcbe5940ce863c858416cff018",
#         "results": "https://api.planet.com/data/v1/searches/c49a5afcbe5940ce863c858416cff018/results"
#       },
#       "created": "2018-02-01T16:25:19.967858Z",
#       "filter": {
#         "config": [
#           {
#             "config": {
#               "coordinates": [
#                 [
#                   [
#                     -57.30460166931152,
#                     -33.232872481362676
#                   ],
#                   [
#                     -57.25773811340332,
#                     -33.232872481362676
#                   ],
#                   [
#                     -57.25773811340332,
#                     -33.19653763818525
#                   ],
#                   [
#                     -57.30460166931152,
#                     -33.19653763818525
#                   ],
#                   [
#                     -57.30460166931152,
#                     -33.232872481362676
#                   ]
#                 ]
#               ],
#               "type": "Polygon"
#             },
#             "field_name": "geometry",
#             "type": "GeometryFilter"
#           },
#           {
#             "config": {
#               "gte": "2017-12-29T00:00:00Z",
#               "lte": "2018-01-31T00:00:00Z"
#             },
#             "field_name": "acquired",
#             "type": "DateRangeFilter"
#           },
#           {
#             "config": {
#               "lte": 0.1
#             },
#             "field_name": "cloud_cover",
#             "type": "RangeFilter"
#           }
#         ],
#         "type": "AndFilter"
#       },
#       "id": "c49a5afcbe5940ce863c858416cff018",
#       "item_types": [
#         "PSScene4Band"
#       ],
#       "last_executed": "2018-02-01T16:25:19.992489Z",
#       "name": "c49a5afcbe5940ce863c858416cff018",
#       "search_type": "quick",
#       "updated": "2018-02-01T16:25:19.992643Z"
#     },
#     {
#       "__daily_email_enabled": false,
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/searches/d4ec88dc606b4ff98cd312d18661fa08",
#         "results": "https://api.planet.com/data/v1/searches/d4ec88dc606b4ff98cd312d18661fa08/results"
#       },
#       "created": "2018-02-01T02:44:11.396208Z",
#       "filter": {
#         "config": [
#           {
#             "config": {
#               "coordinates": [
#                 [
#                   [
#                     -56.85842630492038,
#                     -33.69725153110313
#                   ],
#                   [
#                     -56.81070444212742,
#                     -33.69725153110313
#                   ],
#                   [
#                     -56.81070444212742,
#                     -33.65239467733888
#                   ],
#                   [
#                     -56.85842630492038,
#                     -33.65239467733888
#                   ],
#                   [
#                     -56.85842630492038,
#                     -33.69725153110313
#                   ]
#                 ]
#               ],
#               "type": "Polygon"
#             },
#             "field_name": "geometry",
#             "type": "GeometryFilter"
#           },
#           {
#             "config": [
#               {
#                 "config": [
#                   {
#                     "config": [
#                       "Sentinel2L1C"
#                     ],
#                     "field_name": "item_type",
#                     "type": "StringInFilter"
#                   },
#                   {
#                     "config": {
#                       "gte": 0.0,
#                       "lte": 0.83
#                     },
#                     "field_name": "cloud_cover",
#                     "type": "RangeFilter"
#                   },
#                   {
#                     "config": {
#                       "gte": 0.0,
#                       "lte": 90.0
#                     },
#                     "field_name": "sun_elevation",
#                     "type": "RangeFilter"
#                   }
#                 ],
#                 "type": "AndFilter"
#               }
#             ],
#             "type": "OrFilter"
#           },
#           {
#             "config": [
#               {
#                 "config": {
#                   "gte": "2017-12-12T15:00:00Z",
#                   "lte": "2018-01-31T23:59:59Z"
#                 },
#                 "field_name": "acquired",
#                 "type": "DateRangeFilter"
#               }
#             ],
#             "type": "OrFilter"
#           }
#         ],
#         "type": "AndFilter"
#       },
#       "id": "d4ec88dc606b4ff98cd312d18661fa08",
#       "item_types": [
#         "Sentinel2L1C"
#       ],
#       "last_executed": "2018-02-01T02:44:13.942751Z",
#       "name": "d4ec88dc606b4ff98cd312d18661fa08",
#       "search_type": "quick",
#       "updated": "2018-02-01T02:44:13.942950Z"
#     },
#     {
#       "__daily_email_enabled": false,
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/searches/8988898d616441d39db70e46f8b398fe",
#         "results": "https://api.planet.com/data/v1/searches/8988898d616441d39db70e46f8b398fe/results"
#       },
#       "created": "2018-02-01T02:44:07.479260Z",
#       "filter": {
#         "config": [
#           {
#             "config": {
#               "coordinates": [
#                 [
#                   [
#                     -56.85842630492038,
#                     -33.69725153110313
#                   ],
#                   [
#                     -56.81070444212742,
#                     -33.69725153110313
#                   ],
#                   [
#                     -56.81070444212742,
#                     -33.65239467733888
#                   ],
#                   [
#                     -56.85842630492038,
#                     -33.65239467733888
#                   ],
#                   [
#                     -56.85842630492038,
#                     -33.69725153110313
#                   ]
#                 ]
#               ],
#               "type": "Polygon"
#             },
#             "field_name": "geometry",
#             "type": "GeometryFilter"
#           },
#           {
#             "config": [
#               {
#                 "config": [
#                   {
#                     "config": [
#                       "Sentinel2L1C"
#                     ],
#                     "field_name": "item_type",
#                     "type": "StringInFilter"
#                   },
#                   {
#                     "config": {
#                       "gte": 0.0,
#                       "lte": 0.47
#                     },
#                     "field_name": "cloud_cover",
#                     "type": "RangeFilter"
#                   },
#                   {
#                     "config": {
#                       "gte": 0.0,
#                       "lte": 90.0
#                     },
#                     "field_name": "sun_elevation",
#                     "type": "RangeFilter"
#                   }
#                 ],
#                 "type": "AndFilter"
#               }
#             ],
#             "type": "OrFilter"
#           },
#           {
#             "config": [
#               {
#                 "config": {
#                   "gte": "2017-12-12T15:00:00Z",
#                   "lte": "2018-01-31T23:59:59Z"
#                 },
#                 "field_name": "acquired",
#                 "type": "DateRangeFilter"
#               }
#             ],
#             "type": "OrFilter"
#           }
#         ],
#         "type": "AndFilter"
#       },
#       "id": "8988898d616441d39db70e46f8b398fe",
#       "item_types": [
#         "Sentinel2L1C"
#       ],
#       "last_executed": "2018-02-01T02:44:08.828052Z",
#       "name": "8988898d616441d39db70e46f8b398fe",
#       "search_type": "quick",
#       "updated": "2018-02-01T02:44:08.828264Z"
#     },
#     {
#       "__daily_email_enabled": false,
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/searches/cb22442453a14339a2e2dc926ae6d521",
#         "results": "https://api.planet.com/data/v1/searches/cb22442453a14339a2e2dc926ae6d521/results"
#       },
#       "created": "2018-02-01T02:44:03.886289Z",
#       "filter": {
#         "config": [
#           {
#             "config": {
#               "coordinates": [
#                 [
#                   [
#                     -56.85842630492038,
#                     -33.69725153110313
#                   ],
#                   [
#                     -56.81070444212742,
#                     -33.69725153110313
#                   ],
#                   [
#                     -56.81070444212742,
#                     -33.65239467733888
#                   ],
#                   [
#                     -56.85842630492038,
#                     -33.65239467733888
#                   ],
#                   [
#                     -56.85842630492038,
#                     -33.69725153110313
#                   ]
#                 ]
#               ],
#               "type": "Polygon"
#             },
#             "field_name": "geometry",
#             "type": "GeometryFilter"
#           },
#           {
#             "config": [
#               {
#                 "config": [
#                   {
#                     "config": [
#                       "Sentinel2L1C"
#                     ],
#                     "field_name": "item_type",
#                     "type": "StringInFilter"
#                   },
#                   {
#                     "config": {
#                       "gte": 0.0,
#                       "lte": 0.23
#                     },
#                     "field_name": "cloud_cover",
#                     "type": "RangeFilter"
#                   },
#                   {
#                     "config": {
#                       "gte": 0.0,
#                       "lte": 90.0
#                     },
#                     "field_name": "sun_elevation",
#                     "type": "RangeFilter"
#                   }
#                 ],
#                 "type": "AndFilter"
#               }
#             ],
#             "type": "OrFilter"
#           },
#           {
#             "config": [
#               {
#                 "config": {
#                   "gte": "2017-12-12T15:00:00Z",
#                   "lte": "2018-01-31T23:59:59Z"
#                 },
#                 "field_name": "acquired",
#                 "type": "DateRangeFilter"
#               }
#             ],
#             "type": "OrFilter"
#           }
#         ],
#         "type": "AndFilter"
#       },
#       "id": "cb22442453a14339a2e2dc926ae6d521",
#       "item_types": [
#         "Sentinel2L1C"
#       ],
#       "last_executed": "2018-02-01T02:44:05.027566Z",
#       "name": "cb22442453a14339a2e2dc926ae6d521",
#       "search_type": "quick",
#       "updated": "2018-02-01T02:44:05.027776Z"
#     },
#     {
#       "__daily_email_enabled": false,
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/searches/544154c7510248b3aa3cf8c9753c9195",
#         "results": "https://api.planet.com/data/v1/searches/544154c7510248b3aa3cf8c9753c9195/results"
#       },
#       "created": "2018-02-01T02:42:46.018193Z",
#       "filter": {
#         "config": [
#           {
#             "config": {
#               "coordinates": [
#                 [
#                   [
#                     -56.85842630492038,
#                     -33.69725153110313
#                   ],
#                   [
#                     -56.81070444212742,
#                     -33.69725153110313
#                   ],
#                   [
#                     -56.81070444212742,
#                     -33.65239467733888
#                   ],
#                   [
#                     -56.85842630492038,
#                     -33.65239467733888
#                   ],
#                   [
#                     -56.85842630492038,
#                     -33.69725153110313
#                   ]
#                 ]
#               ],
#               "type": "Polygon"
#             },
#             "field_name": "geometry",
#             "type": "GeometryFilter"
#           },
#           {
#             "config": [
#               {
#                 "config": [
#                   {
#                     "config": [
#                       "Sentinel2L1C"
#                     ],
#                     "field_name": "item_type",
#                     "type": "StringInFilter"
#                   },
#                   {
#                     "config": {
#                       "gte": 0.0,
#                       "lte": 0.1
#                     },
#                     "field_name": "cloud_cover",
#                     "type": "RangeFilter"
#                   },
#                   {
#                     "config": {
#                       "gte": 0.0,
#                       "lte": 90.0
#                     },
#                     "field_name": "sun_elevation",
#                     "type": "RangeFilter"
#                   }
#                 ],
#                 "type": "AndFilter"
#               }
#             ],
#             "type": "OrFilter"
#           },
#           {
#             "config": [
#               {
#                 "config": {
#                   "gte": "2017-12-12T15:00:00Z",
#                   "lte": "2018-01-31T23:59:59Z"
#                 },
#                 "field_name": "acquired",
#                 "type": "DateRangeFilter"
#               }
#             ],
#             "type": "OrFilter"
#           }
#         ],
#         "type": "AndFilter"
#       },
#       "id": "544154c7510248b3aa3cf8c9753c9195",
#       "item_types": [
#         "Sentinel2L1C"
#       ],
#       "last_executed": "2018-02-01T02:42:47.304268Z",
#       "name": "544154c7510248b3aa3cf8c9753c9195",
#       "search_type": "quick",
#       "updated": "2018-02-01T02:42:47.304471Z"
#     },
#     {
#       "__daily_email_enabled": false,
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/searches/3c063dcecea24307a1a86deba631dc07",
#         "results": "https://api.planet.com/data/v1/searches/3c063dcecea24307a1a86deba631dc07/results"
#       },
#       "created": "2018-02-01T02:42:15.378815Z",
#       "filter": {
#         "config": [
#           {
#             "config": {
#               "coordinates": [
#                 [
#                   [
#                     -56.85842630492038,
#                     -33.69725153110313
#                   ],
#                   [
#                     -56.81070444212742,
#                     -33.69725153110313
#                   ],
#                   [
#                     -56.81070444212742,
#                     -33.65239467733888
#                   ],
#                   [
#                     -56.85842630492038,
#                     -33.65239467733888
#                   ],
#                   [
#                     -56.85842630492038,
#                     -33.69725153110313
#                   ]
#                 ]
#               ],
#               "type": "Polygon"
#             },
#             "field_name": "geometry",
#             "type": "GeometryFilter"
#           },
#           {
#             "config": [
#               {
#                 "config": [
#                   {
#                     "config": [
#                       "Sentinel2L1C"
#                     ],
#                     "field_name": "item_type",
#                     "type": "StringInFilter"
#                   },
#                   {
#                     "config": {
#                       "gte": 0.0,
#                       "lte": 0.1
#                     },
#                     "field_name": "cloud_cover",
#                     "type": "RangeFilter"
#                   },
#                   {
#                     "config": {
#                       "gte": 0.0,
#                       "lte": 90.0
#                     },
#                     "field_name": "sun_elevation",
#                     "type": "RangeFilter"
#                   }
#                 ],
#                 "type": "AndFilter"
#               }
#             ],
#             "type": "OrFilter"
#           },
#           {
#             "config": [
#               {
#                 "config": {
#                   "gte": "2017-12-21T15:00:00Z",
#                   "lte": "2018-01-31T23:59:59Z"
#                 },
#                 "field_name": "acquired",
#                 "type": "DateRangeFilter"
#               }
#             ],
#             "type": "OrFilter"
#           }
#         ],
#         "type": "AndFilter"
#       },
#       "id": "3c063dcecea24307a1a86deba631dc07",
#       "item_types": [
#         "Sentinel2L1C"
#       ],
#       "last_executed": "2018-02-01T02:42:16.576534Z",
#       "name": "3c063dcecea24307a1a86deba631dc07",
#       "search_type": "quick",
#       "updated": "2018-02-01T02:42:16.576728Z"
#     },
#     {
#       "__daily_email_enabled": false,
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/searches/2410558d45244731a8790d09fb964888",
#         "results": "https://api.planet.com/data/v1/searches/2410558d45244731a8790d09fb964888/results"
#       },
#       "created": "2018-02-01T02:22:17.179843Z",
#       "filter": {
#         "config": [
#           {
#             "config": {
#               "coordinates": [
#                 [
#                   [
#                     -58.32694110278779,
#                     -33.35961961441368
#                   ],
#                   [
#                     -58.274412721440136,
#                     -33.35961961441368
#                   ],
#                   [
#                     -58.274412721440136,
#                     -33.308562189807354
#                   ],
#                   [
#                     -58.32694110278779,
#                     -33.308562189807354
#                   ],
#                   [
#                     -58.32694110278779,
#                     -33.35961961441368
#                   ]
#                 ]
#               ],
#               "type": "Polygon"
#             },
#             "field_name": "geometry",
#             "type": "GeometryFilter"
#           },
#           {
#             "config": [
#               {
#                 "config": [
#                   {
#                     "config": [
#                       "Sentinel2L1C"
#                     ],
#                     "field_name": "item_type",
#                     "type": "StringInFilter"
#                   },
#                   {
#                     "config": {
#                       "gte": 0.0,
#                       "lte": 0.1
#                     },
#                     "field_name": "cloud_cover",
#                     "type": "RangeFilter"
#                   },
#                   {
#                     "config": {
#                       "gte": 0.0,
#                       "lte": 90.0
#                     },
#                     "field_name": "sun_elevation",
#                     "type": "RangeFilter"
#                   }
#                 ],
#                 "type": "AndFilter"
#               }
#             ],
#             "type": "OrFilter"
#           },
#           {
#             "config": [
#               {
#                 "config": {
#                   "gte": "2017-12-21T15:00:00Z",
#                   "lte": "2018-01-31T23:59:59Z"
#                 },
#                 "field_name": "acquired",
#                 "type": "DateRangeFilter"
#               }
#             ],
#             "type": "OrFilter"
#           }
#         ],
#         "type": "AndFilter"
#       },
#       "id": "2410558d45244731a8790d09fb964888",
#       "item_types": [
#         "Sentinel2L1C"
#       ],
#       "last_executed": "2018-02-01T02:22:18.024276Z",
#       "name": "2410558d45244731a8790d09fb964888",
#       "search_type": "quick",
#       "updated": "2018-02-01T02:22:18.024474Z"
#     },
#     {
#       "__daily_email_enabled": false,
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/searches/31318c9734764ee98a48a3a878f2d29a",
#         "results": "https://api.planet.com/data/v1/searches/31318c9734764ee98a48a3a878f2d29a/results"
#       },
#       "created": "2018-02-01T02:21:52.571886Z",
#       "filter": {
#         "config": [
#           {
#             "config": {
#               "coordinates": [
#                 [
#                   [
#                     -58.32694110278779,
#                     -33.35961961441368
#                   ],
#                   [
#                     -58.274412721440136,
#                     -33.35961961441368
#                   ],
#                   [
#                     -58.274412721440136,
#                     -33.308562189807354
#                   ],
#                   [
#                     -58.32694110278779,
#                     -33.308562189807354
#                   ],
#                   [
#                     -58.32694110278779,
#                     -33.35961961441368
#                   ]
#                 ]
#               ],
#               "type": "Polygon"
#             },
#             "field_name": "geometry",
#             "type": "GeometryFilter"
#           },
#           {
#             "config": [
#               {
#                 "config": [
#                   {
#                     "config": [
#                       "Sentinel2L1C"
#                     ],
#                     "field_name": "item_type",
#                     "type": "StringInFilter"
#                   },
#                   {
#                     "config": {
#                       "gte": 0.0,
#                       "lte": 0.1
#                     },
#                     "field_name": "cloud_cover",
#                     "type": "RangeFilter"
#                   },
#                   {
#                     "config": {
#                       "gte": 0.0,
#                       "lte": 90.0
#                     },
#                     "field_name": "sun_elevation",
#                     "type": "RangeFilter"
#                   }
#                 ],
#                 "type": "AndFilter"
#               }
#             ],
#             "type": "OrFilter"
#           },
#           {
#             "config": [
#               {
#                 "config": {
#                   "gte": "2017-10-15T15:00:00Z",
#                   "lte": "2018-01-31T23:59:59Z"
#                 },
#                 "field_name": "acquired",
#                 "type": "DateRangeFilter"
#               }
#             ],
#             "type": "OrFilter"
#           }
#         ],
#         "type": "AndFilter"
#       },
#       "id": "31318c9734764ee98a48a3a878f2d29a",
#       "item_types": [
#         "Sentinel2L1C"
#       ],
#       "last_executed": "2018-02-01T02:21:54.053257Z",
#       "name": "31318c9734764ee98a48a3a878f2d29a",
#       "search_type": "quick",
#       "updated": "2018-02-01T02:21:54.053477Z"
#     },
#     {
#       "__daily_email_enabled": false,
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/searches/b2742f1e48b24c4c9788341602105a38",
#         "results": "https://api.planet.com/data/v1/searches/b2742f1e48b24c4c9788341602105a38/results"
#       },
#       "created": "2018-02-01T02:18:52.978099Z",
#       "filter": {
#         "config": [
#           {
#             "config": {
#               "coordinates": [
#                 [
#                   [
#                     -57.69224292923857,
#                     -32.988193114787016
#                   ],
#                   [
#                     -57.64486438919949,
#                     -32.988193114787016
#                   ],
#                   [
#                     -57.64486438919949,
#                     -32.94556279167575
#                   ],
#                   [
#                     -57.69224292923857,
#                     -32.94556279167575
#                   ],
#                   [
#                     -57.69224292923857,
#                     -32.988193114787016
#                   ]
#                 ]
#               ],
#               "type": "Polygon"
#             },
#             "field_name": "geometry",
#             "type": "GeometryFilter"
#           },
#           {
#             "config": [
#               {
#                 "config": [
#                   {
#                     "config": [
#                       "Sentinel2L1C"
#                     ],
#                     "field_name": "item_type",
#                     "type": "StringInFilter"
#                   },
#                   {
#                     "config": {
#                       "gte": 0.0,
#                       "lte": 0.1
#                     },
#                     "field_name": "cloud_cover",
#                     "type": "RangeFilter"
#                   },
#                   {
#                     "config": {
#                       "gte": 0.0,
#                       "lte": 90.0
#                     },
#                     "field_name": "sun_elevation",
#                     "type": "RangeFilter"
#                   }
#                 ],
#                 "type": "AndFilter"
#               }
#             ],
#             "type": "OrFilter"
#           },
#           {
#             "config": [
#               {
#                 "config": {
#                   "gte": "2017-10-15T15:00:00Z",
#                   "lte": "2018-01-31T23:59:59Z"
#                 },
#                 "field_name": "acquired",
#                 "type": "DateRangeFilter"
#               }
#             ],
#             "type": "OrFilter"
#           }
#         ],
#         "type": "AndFilter"
#       },
#       "id": "b2742f1e48b24c4c9788341602105a38",
#       "item_types": [
#         "Sentinel2L1C"
#       ],
#       "last_executed": "2018-02-01T02:18:54.525282Z",
#       "name": "b2742f1e48b24c4c9788341602105a38",
#       "search_type": "quick",
#       "updated": "2018-02-01T02:18:54.525506Z"
#     },
#     {
#       "__daily_email_enabled": false,
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/searches/b99323c64875468e95ea3f9ae1cc3137",
#         "results": "https://api.planet.com/data/v1/searches/b99323c64875468e95ea3f9ae1cc3137/results"
#       },
#       "created": "2018-02-01T02:12:13.501731Z",
#       "filter": {
#         "config": [
#           {
#             "config": {
#               "coordinates": [
#                 [
#                   [
#                     -57.72689100128677,
#                     -34.356173836629715
#                   ],
#                   [
#                     -57.71251436096695,
#                     -34.356173836629715
#                   ],
#                   [
#                     -57.71251436096695,
#                     -34.34533199456192
#                   ],
#                   [
#                     -57.72689100128677,
#                     -34.34533199456192
#                   ],
#                   [
#                     -57.72689100128677,
#                     -34.356173836629715
#                   ]
#                 ]
#               ],
#               "type": "Polygon"
#             },
#             "field_name": "geometry",
#             "type": "GeometryFilter"
#           },
#           {
#             "config": [
#               {
#                 "config": [
#                   {
#                     "config": [
#                       "Sentinel2L1C"
#                     ],
#                     "field_name": "item_type",
#                     "type": "StringInFilter"
#                   },
#                   {
#                     "config": {
#                       "gte": 0.0,
#                       "lte": 0.1
#                     },
#                     "field_name": "cloud_cover",
#                     "type": "RangeFilter"
#                   },
#                   {
#                     "config": {
#                       "gte": 0.0,
#                       "lte": 90.0
#                     },
#                     "field_name": "sun_elevation",
#                     "type": "RangeFilter"
#                   }
#                 ],
#                 "type": "AndFilter"
#               }
#             ],
#             "type": "OrFilter"
#           },
#           {
#             "config": [
#               {
#                 "config": {
#                   "gte": "2017-10-15T15:00:00Z",
#                   "lte": "2018-01-31T23:59:59Z"
#                 },
#                 "field_name": "acquired",
#                 "type": "DateRangeFilter"
#               }
#             ],
#             "type": "OrFilter"
#           }
#         ],
#         "type": "AndFilter"
#       },
#       "id": "b99323c64875468e95ea3f9ae1cc3137",
#       "item_types": [
#         "Sentinel2L1C"
#       ],
#       "last_executed": "2018-02-01T02:12:14.604881Z",
#       "name": "b99323c64875468e95ea3f9ae1cc3137",
#       "search_type": "quick",
#       "updated": "2018-02-01T02:12:14.605100Z"
#     },
#     {
#       "__daily_email_enabled": false,
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/searches/8c0227f2ee284fd29d88203da2affabd",
#         "results": "https://api.planet.com/data/v1/searches/8c0227f2ee284fd29d88203da2affabd/results"
#       },
#       "created": "2018-02-01T02:01:15.422649Z",
#       "filter": {
#         "config": [
#           {
#             "config": {
#               "coordinates": [
#                 [
#                   [
#                     -57.31387478766532,
#                     -33.24325713373394
#                   ],
#                   [
#                     -57.23525387702079,
#                     -33.24325713373394
#                   ],
#                   [
#                     -57.23525387702079,
#                     -33.19055139518428
#                   ],
#                   [
#                     -57.31387478766532,
#                     -33.19055139518428
#                   ],
#                   [
#                     -57.31387478766532,
#                     -33.24325713373394
#                   ]
#                 ]
#               ],
#               "type": "Polygon"
#             },
#             "field_name": "geometry",
#             "type": "GeometryFilter"
#           },
#           {
#             "config": [
#               {
#                 "config": [
#                   {
#                     "config": [
#                       "Sentinel2L1C"
#                     ],
#                     "field_name": "item_type",
#                     "type": "StringInFilter"
#                   },
#                   {
#                     "config": {
#                       "gte": 0.0,
#                       "lte": 0.1
#                     },
#                     "field_name": "cloud_cover",
#                     "type": "RangeFilter"
#                   },
#                   {
#                     "config": {
#                       "gte": 0.0,
#                       "lte": 90.0
#                     },
#                     "field_name": "sun_elevation",
#                     "type": "RangeFilter"
#                   }
#                 ],
#                 "type": "AndFilter"
#               }
#             ],
#             "type": "OrFilter"
#           },
#           {
#             "config": [
#               {
#                 "config": {
#                   "gte": "2017-10-15T15:00:00Z",
#                   "lte": "2018-01-31T23:59:59Z"
#                 },
#                 "field_name": "acquired",
#                 "type": "DateRangeFilter"
#               }
#             ],
#             "type": "OrFilter"
#           }
#         ],
#         "type": "AndFilter"
#       },
#       "id": "8c0227f2ee284fd29d88203da2affabd",
#       "item_types": [
#         "Sentinel2L1C"
#       ],
#       "last_executed": "2018-02-01T02:01:16.640227Z",
#       "name": "8c0227f2ee284fd29d88203da2affabd",
#       "search_type": "quick",
#       "updated": "2018-02-01T02:01:16.640427Z"
#     },
#     {
#       "__daily_email_enabled": false,
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/searches/d1e51550bbf6407da64344e7e2dc6563",
#         "results": "https://api.planet.com/data/v1/searches/d1e51550bbf6407da64344e7e2dc6563/results"
#       },
#       "created": "2018-02-01T02:01:11.450549Z",
#       "filter": {
#         "config": [
#           {
#             "config": {
#               "coordinates": [
#                 [
#                   [
#                     -57.31387478766532,
#                     -33.24325713373394
#                   ],
#                   [
#                     -57.23525387702079,
#                     -33.24325713373394
#                   ],
#                   [
#                     -57.23525387702079,
#                     -33.19055139518428
#                   ],
#                   [
#                     -57.31387478766532,
#                     -33.19055139518428
#                   ],
#                   [
#                     -57.31387478766532,
#                     -33.24325713373394
#                   ]
#                 ]
#               ],
#               "type": "Polygon"
#             },
#             "field_name": "geometry",
#             "type": "GeometryFilter"
#           },
#           {
#             "config": [
#               {
#                 "config": [
#                   {
#                     "config": [
#                       "REOrthoTile"
#                     ],
#                     "field_name": "item_type",
#                     "type": "StringInFilter"
#                   },
#                   {
#                     "config": {
#                       "gte": 0.0,
#                       "lte": 0.1
#                     },
#                     "field_name": "cloud_cover",
#                     "type": "RangeFilter"
#                   },
#                   {
#                     "config": {
#                       "gte": 0.0,
#                       "lte": 90.0
#                     },
#                     "field_name": "sun_elevation",
#                     "type": "RangeFilter"
#                   }
#                 ],
#                 "type": "AndFilter"
#               },
#               {
#                 "config": [
#                   {
#                     "config": [
#                       "Sentinel2L1C"
#                     ],
#                     "field_name": "item_type",
#                     "type": "StringInFilter"
#                   },
#                   {
#                     "config": {
#                       "gte": 0.0,
#                       "lte": 0.1
#                     },
#                     "field_name": "cloud_cover",
#                     "type": "RangeFilter"
#                   },
#                   {
# ...
#       "name": "31fbe69e75e8439bbfac60981ef13973",
#       "search_type": "quick",
#       "updated": "2017-11-27T18:07:20.500541Z"
#     },
#     {
#       "__daily_email_enabled": false,
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/searches/1de0fc2f52754d7299a7afde42e3f189",
#         "results": "https://api.planet.com/data/v1/searches/1de0fc2f52754d7299a7afde42e3f189/results"
#       },
#       "created": "2017-11-27T18:07:19.372911Z",
#       "filter": {
#         "config": [
#           {
#             "config": {
#               "coordinates": [
#                 [
#                   [
#                     -57.44760721089193,
#                     -33.894133934007115
#                   ],
#                   [
#                     -57.41275995137045,
#                     -33.894133934007115
#                   ],
#                   [
#                     -57.41275995137045,
#                     -33.83854440066395
#                   ],
#                   [
#                     -57.44760721089193,
#                     -33.83854440066395
#                   ],
#                   [
#                     -57.44760721089193,
#                     -33.894133934007115
#                   ]
#                 ]
#               ],
#               "type": "Polygon"
#             },
#             "field_name": "geometry",
#             "type": "GeometryFilter"
#           },
#           {
#             "config": {
#               "gte": 0.0,
#               "lte": 90.0
#             },
#             "field_name": "sun_elevation",
#             "type": "RangeFilter"
#           },
#           {
#             "config": [
#               {
#                 "config": {
#                   "gte": "2017-11-01T15:00:00Z",
#                   "lte": "2017-11-27T23:59:59Z"
#                 },
#                 "field_name": "acquired",
#                 "type": "DateRangeFilter"
#               }
#             ],
#             "type": "OrFilter"
#           }
#         ],
#         "type": "AndFilter"
#       },
#       "id": "1de0fc2f52754d7299a7afde42e3f189",
#       "item_types": [
#         "PSScene4Band"
#       ],
#       "last_executed": "2017-11-27T18:07:19.386778Z",
#       "name": "1de0fc2f52754d7299a7afde42e3f189",
#       "search_type": "quick",
#       "updated": "2017-11-27T18:07:19.386945Z"
#     },
#     {
#       "__daily_email_enabled": false,
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/searches/db6fdca7f87a4583a674f818747a0cb5",
#         "results": "https://api.planet.com/data/v1/searches/db6fdca7f87a4583a674f818747a0cb5/results"
#       },
#       "created": "2017-11-27T18:07:19.296084Z",
#       "filter": {
#         "config": [
#           {
#             "config": {
#               "coordinates": [
#                 [
#                   [
#                     -57.44760721089193,
#                     -33.894133934007115
#                   ],
#                   [
#                     -57.41275995137045,
#                     -33.894133934007115
#                   ],
#                   [
#                     -57.41275995137045,
#                     -33.83854440066395
#                   ],
#                   [
#                     -57.44760721089193,
#                     -33.83854440066395
#                   ],
#                   [
#                     -57.44760721089193,
#                     -33.894133934007115
#                   ]
#                 ]
#               ],
#               "type": "Polygon"
#             },
#             "field_name": "geometry",
#             "type": "GeometryFilter"
#           },
#           {
#             "config": {
#               "gte": 0.0,
#               "lte": 90.0
#             },
#             "field_name": "sun_elevation",
#             "type": "RangeFilter"
#           },
#           {
#             "config": [
#               {
#                 "config": {
#                   "gte": "2017-11-01T15:00:00Z",
#                   "lte": "2017-11-27T23:59:59Z"
#                 },
#                 "field_name": "acquired",
#                 "type": "DateRangeFilter"
#               }
#             ],
#             "type": "OrFilter"
#           }
#         ],
#         "type": "AndFilter"
#       },
#       "id": "db6fdca7f87a4583a674f818747a0cb5",
#       "item_types": [
#         "PSScene4Band"
#       ],
#       "last_executed": "2017-11-27T18:07:19.307304Z",
#       "name": "db6fdca7f87a4583a674f818747a0cb5",
#       "search_type": "quick",
#       "updated": "2017-11-27T18:07:19.307475Z"
#     },
#     {
#       "__daily_email_enabled": false,
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/searches/3271023b176340a8ab72412fbf9c4f94",
#         "results": "https://api.planet.com/data/v1/searches/3271023b176340a8ab72412fbf9c4f94/results"
#       },
#       "created": "2017-11-27T18:07:18.520779Z",
#       "filter": {
#         "config": [
#           {
#             "config": {
#               "coordinates": [
#                 [
#                   [
#                     -57.44760721089193,
#                     -33.894133934007115
#                   ],
#                   [
#                     -57.41275995137045,
#                     -33.894133934007115
#                   ],
#                   [
#                     -57.41275995137045,
#                     -33.83854440066395
#                   ],
#                   [
#                     -57.44760721089193,
#                     -33.83854440066395
#                   ],
#                   [
#                     -57.44760721089193,
#                     -33.894133934007115
#                   ]
#                 ]
#               ],
#               "type": "Polygon"
#             },
#             "field_name": "geometry",
#             "type": "GeometryFilter"
#           },
#           {
#             "config": {
#               "gte": 0.0,
#               "lte": 90.0
#             },
#             "field_name": "sun_elevation",
#             "type": "RangeFilter"
#           },
#           {
#             "config": [
#               {
#                 "config": {
#                   "gte": "2017-11-01T15:00:00Z",
#                   "lte": "2017-11-27T23:59:59Z"
#                 },
#                 "field_name": "acquired",
#                 "type": "DateRangeFilter"
#               }
#             ],
#             "type": "OrFilter"
#           }
#         ],
#         "type": "AndFilter"
#       },
#       "id": "3271023b176340a8ab72412fbf9c4f94",
#       "item_types": [
#         "PSScene4Band",
#         "REOrthoTile"
#       ],
#       "last_executed": "2017-11-27T18:07:18.529526Z",
#       "name": "3271023b176340a8ab72412fbf9c4f94",
#       "search_type": "quick",
#       "updated": "2017-11-27T18:07:18.529679Z"
#     },
#     {
#       "__daily_email_enabled": false,
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/searches/aa38033c78cd4bb890bb3964637ad278",
#         "results": "https://api.planet.com/data/v1/searches/aa38033c78cd4bb890bb3964637ad278/results"
#       },
#       "created": "2017-11-27T18:07:18.386880Z",
#       "filter": {
#         "config": [
#           {
#             "config": {
#               "coordinates": [
#                 [
#                   [
#                     -57.44760721089193,
#                     -33.894133934007115
#                   ],
#                   [
#                     -57.41275995137045,
#                     -33.894133934007115
#                   ],
#                   [
#                     -57.41275995137045,
#                     -33.83854440066395
#                   ],
#                   [
#                     -57.44760721089193,
#                     -33.83854440066395
#                   ],
#                   [
#                     -57.44760721089193,
#                     -33.894133934007115
#                   ]
#                 ]
#               ],
#               "type": "Polygon"
#             },
#             "field_name": "geometry",
#             "type": "GeometryFilter"
#           },
#           {
#             "config": {
#               "gte": 0.0,
#               "lte": 90.0
#             },
#             "field_name": "sun_elevation",
#             "type": "RangeFilter"
#           },
#           {
#             "config": [
#               {
#                 "config": {
#                   "gte": "2017-11-01T15:00:00Z",
#                   "lte": "2017-11-27T23:59:59Z"
#                 },
#                 "field_name": "acquired",
#                 "type": "DateRangeFilter"
#               }
#             ],
#             "type": "OrFilter"
#           }
#         ],
#         "type": "AndFilter"
#       },
#       "id": "aa38033c78cd4bb890bb3964637ad278",
#       "item_types": [
#         "PSScene4Band",
#         "REOrthoTile"
#       ],
#       "last_executed": "2017-11-27T18:07:18.394752Z",
#       "name": "aa38033c78cd4bb890bb3964637ad278",
#       "search_type": "quick",
#       "updated": "2017-11-27T18:07:18.394902Z"
#     },
#     {
#       "__daily_email_enabled": false,
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/searches/ab95b532dff44a0f94811d4634593a13",
#         "results": "https://api.planet.com/data/v1/searches/ab95b532dff44a0f94811d4634593a13/results"
#       },
#       "created": "2017-11-27T18:07:17.017693Z",
#       "filter": {
#         "config": [
#           {
#             "config": {
#               "coordinates": [
#                 [
#                   [
#                     -57.44760721089193,
#                     -33.894133934007115
#                   ],
#                   [
#                     -57.41275995137045,
#                     -33.894133934007115
#                   ],
#                   [
#                     -57.41275995137045,
#                     -33.83854440066395
#                   ],
#                   [
#                     -57.44760721089193,
#                     -33.83854440066395
#                   ],
#                   [
#                     -57.44760721089193,
#                     -33.894133934007115
#                   ]
#                 ]
#               ],
#               "type": "Polygon"
#             },
#             "field_name": "geometry",
#             "type": "GeometryFilter"
#           },
#           {
#             "config": {
#               "gte": 0.0,
#               "lte": 90.0
#             },
#             "field_name": "sun_elevation",
#             "type": "RangeFilter"
#           },
#           {
#             "config": [
#               {
#                 "config": {
#                   "gte": "2017-11-01T15:00:00Z",
#                   "lte": "2017-11-27T23:59:59Z"
#                 },
#                 "field_name": "acquired",
#                 "type": "DateRangeFilter"
#               }
#             ],
#             "type": "OrFilter"
#           }
#         ],
#         "type": "AndFilter"
#       },
#       "id": "ab95b532dff44a0f94811d4634593a13",
#       "item_types": [
#         "PSScene4Band",
#         "REOrthoTile"
#       ],
#       "last_executed": "2017-11-27T18:07:17.030585Z",
#       "name": "ab95b532dff44a0f94811d4634593a13",
#       "search_type": "quick",
#       "updated": "2017-11-27T18:07:17.030745Z"
#     },
#     {
#       "__daily_email_enabled": false,
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/searches/1372cf2ff830431b99afe79a330c7feb",
#         "results": "https://api.planet.com/data/v1/searches/1372cf2ff830431b99afe79a330c7feb/results"
#       },
#       "created": "2017-11-27T18:07:07.113125Z",
#       "filter": {
#         "config": [
#           {
#             "config": {
#               "coordinates": [
#                 [
#                   [
#                     -57.44760721089193,
#                     -33.894133934007115
#                   ],
#                   [
#                     -57.41275995137045,
#                     -33.894133934007115
#                   ],
#                   [
#                     -57.41275995137045,
#                     -33.83854440066395
#                   ],
#                   [
#                     -57.44760721089193,
#                     -33.83854440066395
#                   ],
#                   [
#                     -57.44760721089193,
#                     -33.894133934007115
#                   ]
#                 ]
#               ],
#               "type": "Polygon"
#             },
#             "field_name": "geometry",
#             "type": "GeometryFilter"
#           },
#           {
#             "config": {
#               "gte": 0.0,
#               "lte": 90.0
#             },
#             "field_name": "sun_elevation",
#             "type": "RangeFilter"
#           }
#         ],
#         "type": "AndFilter"
#       },
#       "id": "1372cf2ff830431b99afe79a330c7feb",
#       "item_types": [
#         "PSScene4Band",
#         "REOrthoTile"
#       ],
#       "last_executed": "2017-11-27T18:07:12.185090Z",
#       "name": "1372cf2ff830431b99afe79a330c7feb",
#       "search_type": "quick",
#       "updated": "2017-11-27T18:07:12.185318Z"
#     },
#     {
#       "__daily_email_enabled": false,
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/searches/946953e0699042679e6269d677ebbe0d",
#         "results": "https://api.planet.com/data/v1/searches/946953e0699042679e6269d677ebbe0d/results"
#       },
#       "created": "2017-11-27T18:07:07.109212Z",
#       "filter": {
#         "config": [
#           {
#             "config": {
#               "coordinates": [
#                 [
#                   [
#                     -57.44760721089193,
#                     -33.894133934007115
#                   ],
#                   [
#                     -57.41275995137045,
#                     -33.894133934007115
#                   ],
#                   [
#                     -57.41275995137045,
#                     -33.83854440066395
#                   ],
#                   [
#                     -57.44760721089193,
#                     -33.83854440066395
#                   ],
#                   [
#                     -57.44760721089193,
#                     -33.894133934007115
#                   ]
#                 ]
#               ],
#               "type": "Polygon"
#             },
#             "field_name": "geometry",
#             "type": "GeometryFilter"
#           },
#           {
#             "config": {
#               "gte": 0.0,
#               "lte": 90.0
#             },
#             "field_name": "sun_elevation",
#             "type": "RangeFilter"
#           }
#         ],
#         "type": "AndFilter"
#       },
#       "id": "946953e0699042679e6269d677ebbe0d",
#       "item_types": [
#         "PSScene4Band",
#         "REOrthoTile"
#       ],
#       "last_executed": "2017-11-27T18:07:07.122755Z",
#       "name": "946953e0699042679e6269d677ebbe0d",
#       "search_type": "quick",
#       "updated": "2017-11-27T18:07:07.122903Z"
#     },
#     {
#       "__daily_email_enabled": false,
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/searches/5c596f1baebe45d2af70edb598435e05",
#         "results": "https://api.planet.com/data/v1/searches/5c596f1baebe45d2af70edb598435e05/results"
#       },
#       "created": "2017-11-27T18:07:04.898781Z",
#       "filter": {
#         "config": [
#           {
#             "config": {
#               "coordinates": [
#                 [
#                   [
#                     -57.44760721089193,
#                     -33.894133934007115
#                   ],
#                   [
#                     -57.41275995137045,
#                     -33.894133934007115
#                   ],
#                   [
#                     -57.41275995137045,
#                     -33.83854440066395
#                   ],
#                   [
#                     -57.44760721089193,
#                     -33.83854440066395
#                   ],
#                   [
#                     -57.44760721089193,
#                     -33.894133934007115
#                   ]
#                 ]
#               ],
#               "type": "Polygon"
#             },
#             "field_name": "geometry",
#             "type": "GeometryFilter"
#           },
#           {
#             "config": {
#               "gte": 0.0,
#               "lte": 90.0
#             },
#             "field_name": "sun_elevation",
#             "type": "RangeFilter"
#           }
#         ],
#         "type": "AndFilter"
#       },
#       "id": "5c596f1baebe45d2af70edb598435e05",
#       "item_types": [
#         "PSScene4Band",
#         "REOrthoTile"
#       ],
#       "last_executed": "2017-11-27T18:07:04.906706Z",
#       "name": "5c596f1baebe45d2af70edb598435e05",
#       "search_type": "quick",
#       "updated": "2017-11-27T18:07:04.906869Z"
#     }
#   ]
# }

# %% [markdown]
# Now that we created a saved search, let's get a list of our saved searches:

# %%
# Send a GET request to the saved searches endpoint with the saved search type parameter (Get saved searches)
res = session.get(searches_url, params={"search_type" : "saved"})

# Assign a variable to the searches property in the saved searches response
searches = res.json()["searches"]

# Loop through the searches
for search in searches:
    # Print the ID, Created Time, and Name for each saved search
    print("id: {} created: {} name: {}".format(search["id"], search["created"], search["name"]))
# Out:
# id: 1ebd5ed41669425b915f1da7038d47a8 created: 2017-09-22T19:47:04.669771Z name: inv16
# id: 1676a9f4e1bf45debf4347d7e684cfc3 created: 2017-09-22T19:46:36.035678Z name: inv16
# id: e400d49a826743a1bf96c53bd0780313 created: 2017-09-22T19:46:35.423605Z name: inv16
# id: 3469e210c8ec464cafe3d10150cf702e created: 2017-09-22T19:41:20.073904Z name: ver 17
# id: 982403d970d54f939180feea6cc794e4 created: 2017-09-22T19:28:37.710928Z name: ver16rapid_planet_sentinel

# %% [markdown]
# Ok, now let's check out the results from a particular saved search:

# %%
# Setup the saved search url, using the first saved search in the list
saved_url = "{}/{}".format(searches_url, searches[0]["id"])

# Print the saved search url
p(saved_url)

# Setup the saved search's results url
results_url = "{}/results".format(saved_url)

# Print the saved search's results url
p(results_url)
# Out:
# "https://api.planet.com/data/v1/searches/1ebd5ed41669425b915f1da7038d47a8"
# "https://api.planet.com/data/v1/searches/1ebd5ed41669425b915f1da7038d47a8/results"

# %%
# Send a GET request to the saved search url (Get the saved search data)
res = session.get(saved_url)

# Print the response
p(res.json())

# Print the number of features in the saved search
p(len(res["features"]))

# Print the first feature in the saved search
p(res["features"][0])
# Out:
# {
#   "__daily_email_enabled": false,
#   "_links": {
#     "_self": "https://api.planet.com/data/v1/searches/1ebd5ed41669425b915f1da7038d47a8",
#     "results": "https://api.planet.com/data/v1/searches/1ebd5ed41669425b915f1da7038d47a8/results"
#   },
#   "created": "2017-09-22T19:47:04.669771Z",
#   "filter": {
#     "config": [
#       {
#         "config": {
#           "coordinates": [
#             [
#               [
#                 [
#                   -56.9828,
#                   -33.5712
#                 ],
#                 [
#                   -56.9846,
#                   -33.5706
#                 ],
#                 [
#                   -56.9849,
#                   -33.5683
#                 ],
#                 [
#                   -56.9824,
#                   -33.5615
#                 ],
#                 [
#                   -56.9805,
#                   -33.5601
#                 ],
#                 [
#                   -56.9755,
#                   -33.5596
#                 ],
#                 [
#                   -56.9748,
#                   -33.552
#                 ],
#                 [
#                   -56.9738,
#                   -33.5506
#                 ],
#                 [
#                   -56.966,
#                   -33.5504
#                 ],
#                 [
#                   -56.9636,
#                   -33.5524
#                 ],
#                 [
#                   -56.9653,
#                   -33.5608
#                 ],
#                 [
#                   -56.9689,
#                   -33.5626
#                 ],
#                 [
#                   -56.9716,
#                   -33.5695
#                 ],
#                 [
#                   -56.9742,
#                   -33.5708
#                 ],
#                 [
#                   -56.9828,
#                   -33.5712
#                 ]
#               ]
#             ],
#             [
#               [
#                 [
#                   -56.9642,
#                   -33.5693
#                 ],
#                 [
#                   -56.9664,
#                   -33.5679
#                 ],
#                 [
#                   -56.9653,
#                   -33.5645
#                 ],
#                 [
#                   -56.9632,
#                   -33.5615
#                 ],
#                 [
#                   -56.9625,
#                   -33.5577
#                 ],
#                 [
#                   -56.9603,
#                   -33.5554
#                 ],
#                 [
#                   -56.9558,
#                   -33.5558
#                 ],
#                 [
#                   -56.9552,
#                   -33.5575
#                 ],
#                 [
#                   -56.9573,
#                   -33.5669
#                 ],
#                 [
#                   -56.9584,
#                   -33.5683
#                 ],
#                 [
#                   -56.9642,
#                   -33.5693
#                 ]
#               ]
#             ],
#             [
#               [
#                 [
#                   -56.7329,
#                   -33.5695
#                 ],
#                 [
#                   -56.7365,
#                   -33.5694
#                 ],
#                 [
#                   -56.7435,
#                   -33.5677
#                 ],
#                 [
#                   -56.751,
#                   -33.5667
#                 ],
#                 [
#                   -56.7548,
#                   -33.5665
#                 ],
#                 [
#                   -56.7568,
#                   -33.564
#                 ],
#                 [
#                   -56.7551,
#                   -33.5588
#                 ],
#                 [
#                   -56.7533,
#                   -33.5574
#                 ],
#                 [
#                   -56.749,
#                   -33.5573
#                 ],
#                 [
#                   -56.7474,
#                   -33.558
#                 ],
#                 [
#                   -56.7407,
#                   -33.555
#                 ],
#                 [
#                   -56.7358,
#                   -33.5564
#                 ],
#                 [
#                   -56.7344,
#                   -33.5581
#                 ],
#                 [
#                   -56.7296,
#                   -33.5579
#                 ],
#                 [
#                   -56.7271,
#                   -33.5597
#                 ],
#                 [
#                   -56.7269,
#                   -33.5663
#                 ],
#                 [
#                   -56.729,
#                   -33.5682
#                 ],
#                 [
#                   -56.7329,
#                   -33.5695
#                 ]
#               ]
#             ],
#             [
#               [
#                 [
#                   -56.8956,
#                   -33.5824
#                 ],
#                 [
#                   -56.8983,
#                   -33.5796
#                 ],
#                 [
#                   -56.9056,
#                   -33.5748
#                 ],
#                 [
#                   -56.9066,
#                   -33.5718
#                 ],
#                 [
#                   -56.8996,
#                   -33.5693
#                 ],
#                 [
#                   -56.8967,
#                   -33.5704
#                 ],
#                 [
#                   -56.8957,
#                   -33.5727
#                 ],
#                 [
#                   -56.8858,
#                   -33.5694
#                 ],
#                 [
#                   -56.8809,
#                   -33.5631
#                 ],
#                 [
#                   -56.8785,
#                   -33.5623
#                 ],
#                 [
#                   -56.8766,
#                   -33.5653
#                 ],
#                 [
#                   -56.879,
#                   -33.5753
#                 ],
#                 [
#                   -56.8799,
#                   -33.5762
#                 ],
#                 [
#                   -56.886,
#                   -33.5778
#                 ],
#                 [
#                   -56.8956,
#                   -33.5824
#                 ]
#               ]
#             ],
#             [
#               [
#                 [
#                   -56.7347,
#                   -33.577
#                 ],
#                 [
#                   -56.7383,
#                   -33.5758
#                 ],
#                 [
#                   -56.7437,
#                   -33.5761
#                 ],
#                 [
#                   -56.7483,
#                   -33.574
#                 ],
#                 [
#                   -56.7488,
#                   -33.5711
#                 ],
#                 [
#                   -56.7473,
#                   -33.5703
#                 ],
#                 [
#                   -56.7419,
#                   -33.5695
#                 ],
#                 [
#                   -56.7356,
#                   -33.5713
#                 ],
#                 [
#                   -56.733,
#                   -33.5702
#                 ],
#                 [
#                   -56.7291,
#                   -33.5719
#                 ],
#                 [
#                   -56.7296,
#                   -33.5752
#                 ],
#                 [
#                   -56.7347,
#                   -33.577
#                 ]
#               ]
#             ],
#             [
#               [
#                 [
#                   -57.5965,
#                   -33.5894
#                 ],
#                 [
#                   -57.5985,
#                   -33.5883
#                 ],
#                 [
#                   -57.6011,
#                   -33.5827
#                 ],
#                 [
#                   -57.6012,
#                   -33.5811
#                 ],
#                 [
#                   -57.5988,
#                   -33.5754
#                 ],
#                 [
#                   -57.5971,
#                   -33.5743
#                 ],
#                 [
#                   -57.5922,
#                   -33.5742
#                 ],
#                 [
#                   -57.5914,
#                   -33.5722
#                 ],
#                 [
#                   -57.5886,
#                   -33.5716
#                 ],
#                 [
#                   -57.5664,
#                   -33.574
#                 ],
#                 [
#                   -57.5642,
#                   -33.5763
#                 ],
#                 [
#                   -57.5654,
#                   -33.5833
#                 ],
#                 [
#                   -57.568,
#                   -33.5848
#                 ],
#                 [
#                   -57.583,
#                   -33.5831
#                 ],
#                 [
#                   -57.585,
#                   -33.5839
#                 ],
#                 [
#                   -57.5861,
#                   -33.5859
#                 ],
#                 [
#                   -57.5965,
#                   -33.5894
#                 ]
#               ]
#             ],
#             [
#               [
#                 [
#                   -56.9853,
#                   -33.6
#                 ],
#                 [
#                   -56.988,
#                   -33.5979
#                 ],
#                 [
#                   -56.9899,
#                   -33.5871
#                 ],
#                 [
#                   -56.9891,
#                   -33.5849
#                 ],
#                 [
#                   -56.9805,
#                   -33.5786
#                 ],
#                 [
#                   -56.9747,
#                   -33.5788
#                 ],
#                 [
#                   -56.9729,
#                   -33.5805
#                 ],
#                 [
#                   -56.9719,
#                   -33.5875
#                 ],
#                 [
#                   -56.9722,
#                   -33.5887
#                 ],
#                 [
#                   -56.9757,
#                   -33.5924
#                 ],
#                 [
#                   -56.9834,
#                   -33.5992
#                 ],
#                 [
#                   -56.9853,
#                   -33.6
#                 ]
#               ]
#             ],
#             [
#               [
#                 [
#                   -56.9485,
#                   -33.6018
#                 ],
#                 [
#                   -56.9508,
#                   -33.6015
#                 ],
#                 [
#                   -56.9536,
#                   -33.5998
#                 ],
#                 [
#                   -56.9562,
#                   -33.6007
#                 ],
#                 [
#                   -56.961,
#                   -33.5999
#                 ],
#                 [
#                   -56.9626,
#                   -33.5987
#                 ],
#                 [
#                   -56.9656,
#                   -33.599
#                 ],
#                 [
#                   -56.9697,
#                   -33.5982
#                 ],
#                 [
#                   -56.9704,
#                   -33.5964
#                 ],
#                 [
#                   -56.9684,
#                   -33.5896
#                 ],
#                 [
#                   -56.9662,
#                   -33.5884
#                 ],
#                 [
#                   -56.9633,
#                   -33.5885
#                 ],
#                 [
#                   -56.9609,
#                   -33.5903
#                 ],
#                 [
#                   -56.9594,
#                   -33.5873
#                 ],
#                 [
#                   -56.9579,
#                   -33.5869
#                 ],
#                 [
#                   -56.9474,
#                   -33.588
#                 ],
#                 [
#                   -56.9452,
#                   -33.5903
#                 ],
#                 [
#                   -56.9462,
#                   -33.6002
#                 ],
#                 [
#                   -56.9485,
#                   -33.6018
#                 ]
#               ]
#             ],
#             [
#               [
#                 [
#                   -56.993,
#                   -33.6221
#                 ],
#                 [
#                   -56.9962,
#                   -33.6213
#                 ],
#                 [
#                   -57.0011,
#                   -33.6125
#                 ],
#                 [
#                   -57.0014,
#                   -33.6088
#                 ],
#                 [
#                   -57.0184,
#                   -33.6163
#                 ],
#                 [
#                   -57.022,
#                   -33.6154
#                 ],
#                 [
#                   -57.023,
#                   -33.6141
#                 ],
#                 [
#                   -57.0285,
#                   -33.5974
#                 ],
#                 [
#                   -57.0286,
#                   -33.5963
#                 ],
#                 [
#                   -57.0245,
#                   -33.5937
#                 ],
#                 [
#                   -57.022,
#                   -33.59
#                 ],
#                 [
#                   -57.0176,
#                   -33.589
#                 ],
#                 [
#                   -57.0113,
#                   -33.5931
#                 ],
#                 [
#                   -57.0105,
#                   -33.595
#                 ],
#                 [
#                   -57.0113,
#                   -33.5976
#                 ],
#                 [
#                   -57.0093,
#                   -33.5992
#                 ],
#                 [
#                   -57.0044,
#                   -33.5981
#                 ],
#                 [
#                   -56.9969,
#                   -33.6034
#                 ],
#                 [
#                   -56.9937,
#                   -33.6042
#                 ],
#                 [
#                   -56.9922,
#                   -33.6062
#                 ],
#                 [
#                   -56.993,
#                   -33.6077
#                 ],
#                 [
#                   -56.9902,
#                   -33.6135
#                 ],
#                 [
#                   -56.991,
#                   -33.6212
#                 ],
#                 [
#                   -56.993,
#                   -33.6221
#                 ]
#               ]
#             ],
#             [
#               [
#                 [
#                   -56.9684,
#                   -33.6398
#                 ],
#                 [
#                   -56.9771,
#                   -33.6377
#                 ],
#                 [
#                   -56.9781,
#                   -33.6347
#                 ],
#                 [
#                   -56.9752,
#                   -33.6264
#                 ],
#                 [
#                   -56.9801,
#                   -33.627
#                 ],
#                 [
#                   -56.9829,
#                   -33.6247
#                 ],
#                 [
#                   -56.9851,
#                   -33.6263
#                 ],
#                 [
#                   -56.9885,
#                   -33.6272
#                 ],
#                 [
#                   -56.991,
#                   -33.6257
#                 ],
#                 [
#                   -56.9904,
#                   -33.6233
#                 ],
#                 [
#                   -56.9888,
#                   -33.6223
#                 ],
#                 [
#                   -56.988,
#                   -33.6183
#                 ],
#                 [
#                   -56.9843,
#                   -33.617
#                 ],
#                 [
#                   -56.9817,
#                   -33.6121
#                 ],
#                 [
#                   -56.9795,
#                   -33.6109
#                 ],
#                 [
#                   -56.9754,
#                   -33.6122
#                 ],
#                 [
#                   -56.9733,
#                   -33.6115
#                 ],
#                 [
#                   -56.9668,
#                   -33.6119
#                 ],
#                 [
#                   -56.9628,
#                   -33.6147
#                 ],
#                 [
#                   -56.9628,
#                   -33.617
#                 ],
#                 [
#                   -56.9605,
#                   -33.6168
#                 ],
#                 [
#                   -56.9586,
#                   -33.613
#                 ],
#                 [
#                   -56.9556,
#                   -33.612
#                 ],
#                 [
#                   -56.9512,
#                   -33.6143
#                 ],
#                 [
#                   -56.9513,
#                   -33.6159
#                 ],
#                 [
#                   -56.9575,
#                   -33.6249
#                 ],
#                 [
#                   -56.9618,
#                   -33.6268
#                 ],
#                 [
#                   -56.9653,
#                   -33.6261
#                 ],
#                 [
#                   -56.9659,
#                   -33.6245
#                 ],
#                 [
#                   -56.9703,
#                   -33.6248
#                 ],
#                 [
#                   -56.9682,
#                   -33.6272
#                 ],
#                 [
#                   -56.9638,
#                   -33.6288
#                 ],
#                 [
#                   -56.9634,
#                   -33.6305
#                 ],
#                 [
#                   -56.9662,
#                   -33.6382
#                 ],
#                 [
#                   -56.9684,
#                   -33.6398
#                 ]
#               ]
#             ],
#             [
#               [
#                 [
#                   -56.892,
#                   -33.6738
#                 ],
#                 [
#                   -56.8955,
#                   -33.6713
#                 ],
#                 [
#                   -56.8962,
#                   -33.6691
#                 ],
#                 [
#                   -56.8925,
#                   -33.6645
#                 ],
#                 [
#                   -56.8863,
#                   -33.6621
#                 ],
#                 [
#                   -56.8829,
#                   -33.6624
#                 ],
#                 [
#                   -56.8821,
#                   -33.6635
#                 ],
#                 [
#                   -56.8806,
#                   -33.6696
#                 ],
#                 [
#                   -56.8825,
#                   -33.6716
#                 ],
#                 [
#                   -56.892,
#                   -33.6738
#                 ]
#               ]
#             ],
#             [
#               [
#                 [
#                   -57.1695,
#                   -33.689
#                 ],
#                 [
#                   -57.1752,
#                   -33.687
#                 ],
#                 [
#                   -57.1766,
#                   -33.6845
#                 ],
#                 [
#                   -57.1755,
#                   -33.6798
#                 ],
#                 [
#                   -57.1761,
#                   -33.6781
#                 ],
#                 [
#                   -57.1737,
#                   -33.6724
#                 ],
#                 [
#                   -57.1695,
#                   -33.6706
#                 ],
#                 [
#                   -57.1688,
#                   -33.668
#                 ],
#                 [
#                   -57.1667,
#                   -33.6676
#                 ],
#                 [
#                   -57.163,
#                   -33.669
#                 ],
#                 [
#                   -57.162,
#                   -33.6704
#                 ],
#                 [
#                   -57.1597,
#                   -33.6701
#                 ],
#                 [
#                   -57.1534,
#                   -33.6724
#                 ],
#                 [
#                   -57.1522,
#                   -33.6736
#                 ],
#                 [
#                   -57.1526,
#                   -33.6793
#                 ],
#                 [
#                   -57.1507,
#                   -33.6812
#                 ],
#                 [
#                   -57.1515,
#                   -33.6855
#                 ],
#                 [
#                   -57.1545,
#                   -33.6863
#                 ],
#                 [
#                   -57.1642,
#                   -33.6826
#                 ],
#                 [
#                   -57.168,
#                   -33.6885
#                 ],
#                 [
#                   -57.1695,
#                   -33.689
#                 ]
#               ]
#             ],
#             [
#               [
#                 [
#                   -57.0904,
#                   -33.6894
#                 ],
#                 [
#                   -57.0932,
#                   -33.6889
#                 ],
#                 [
#                   -57.0949,
#                   -33.6873
#                 ],
#                 [
#                   -57.0954,
#                   -33.6836
#                 ],
#                 [
#                   -57.0945,
#                   -33.6791
#                 ],
#                 [
#                   -57.0857,
#                   -33.6703
#                 ],
#                 [
#                   -57.084,
#                   -33.6699
#                 ],
#                 [
#                   -57.0766,
#                   -33.6711
#                 ],
#                 [
#                   -57.0754,
#                   -33.6734
#                 ],
#                 [
#                   -57.0737,
#                   -33.6742
#                 ],
#                 [
#                   -57.072,
#                   -33.6725
#                 ],
#                 [
#                   -57.0692,
#                   -33.6723
#                 ],
#                 [
#                   -57.0644,
#                   -33.6741
#                 ],
#                 [
#                   -57.0626,
#                   -33.6769
#                 ],
#                 [
#                   -57.0599,
#                   -33.6759
#                 ],
#                 [
#                   -57.0575,
#                   -33.6736
#                 ],
#                 [
#                   -57.0532,
#                   -33.6722
#                 ],
#                 [
#                   -57.0498,
#                   -33.6732
#                 ],
#                 [
#                   -57.049,
#                   -33.6752
#                 ],
#                 [
#                   -57.0501,
#                   -33.6771
#                 ],
#                 [
#                   -57.0646,
#                   -33.6878
#                 ],
#                 [
#                   -57.0664,
#                   -33.6882
#                 ],
#                 [
#                   -57.0696,
#                   -33.6858
#                 ],
#                 [
#                   -57.0731,
#                   -33.6868
#                 ],
#                 [
#                   -57.0742,
#                   -33.6881
#                 ],
#                 [
#                   -57.0774,
#                   -33.6883
#                 ],
#                 [
#                   -57.0814,
#                   -33.6858
#                 ],
#                 [
#                   -57.0848,
#                   -33.6856
#                 ],
#                 [
#                   -57.0876,
#                   -33.6888
#                 ],
#                 [
#                   -57.0904,
#                   -33.6894
#                 ]
#               ]
#             ],
#             [
#               [
#                 [
#                   -56.905,
#                   -33.6823
#                 ],
#                 [
#                   -56.9139,
#                   -33.6808
#                 ],
#                 [
#                   -56.9152,
#                   -33.6798
#                 ],
#                 [
#                   -56.9153,
#                   -33.6754
#                 ],
#                 [
#                   -56.9127,
#                   -33.6736
#                 ],
#                 [
#                   -56.9034,
#                   -33.6751
#                 ],
#                 [
#                   -56.9016,
#                   -33.6772
#                 ],
#                 [
#                   -56.9031,
#                   -33.6815
#                 ],
#                 [
#                   -56.905,
#                   -33.6823
#                 ]
#               ]
#             ],
#             [
#               [
#                 [
#                   -57.1583,
#                   -33.693
#                 ],
#                 [
#                   -57.1636,
#                   -33.6913
#                 ],
#                 [
#                   -57.1651,
#                   -33.6891
#                 ],
#                 [
#                   -57.163,
#                   -33.6858
#                 ],
#                 [
#                   -57.1604,
#                   -33.6854
#                 ],
#                 [
#                   -57.1574,
#                   -33.6866
#                 ],
#                 [
#                   -57.1558,
#                   -33.689
#                 ],
#                 [
#                   -57.1566,
#                   -33.6923
#                 ],
#                 [
#                   -57.1583,
#                   -33.693
#                 ]
#               ]
#             ],
#             [
#               [
#                 [
#                   -56.8855,
#                   -33.7175
#                 ],
#                 [
#                   -56.8954,
#                   -33.7132
#                 ],
#                 [
#                   -56.8966,
#                   -33.712
#                 ],
#                 [
#                   -56.897,
#                   -33.7092
#                 ],
#                 [
#                   -56.9008,
#                   -33.7094
#                 ],
#                 [
#                   -56.9022,
#                   -33.7077
#                 ],
#                 [
#                   -56.9024,
#                   -33.7041
#                 ],
#                 [
#                   -56.9015,
#                   -33.7023
#                 ],
#                 [
#                   -56.8983,
#                   -33.7007
#                 ],
#                 [
#                   -56.8957,
#                   -33.7004
#                 ],
#                 [
#                   -56.8944,
#                   -33.6988
#                 ],
#                 [
#                   -56.89,
#                   -33.6966
#                 ],
#                 [
#                   -56.8881,
#                   -33.6963
#                 ],
#                 [
#                   -56.8859,
#                   -33.6984
#                 ],
#                 [
#                   -56.8876,
#                   -33.7083
#                 ],
#                 [
#                   -56.8831,
#                   -33.7102
#                 ],
#                 [
#                   -56.8819,
#                   -33.7121
#                 ],
#                 [
#                   -56.8833,
#                   -33.7161
#                 ],
#                 [
#                   -56.8855,
#                   -33.7175
#                 ]
#               ]
#             ],
#             [
#               [
#                 [
#                   -56.9316,
#                   -33.7129
#                 ],
#                 [
#                   -56.9334,
#                   -33.7122
#                 ],
#                 [
#                   -56.936,
#                   -33.7096
#                 ],
#                 [
#                   -56.9365,
#                   -33.7074
#                 ],
#                 [
#                   -56.9346,
#                   -33.7055
#                 ],
#                 [
#                   -56.9286,
#                   -33.7042
#                 ],
#                 [
#                   -56.9235,
#                   -33.7055
#                 ],
#                 [
#                   -56.9181,
#                   -33.7062
#                 ],
#                 [
#                   -56.916,
#                   -33.7072
#                 ],
#                 [
#                   -56.9157,
#                   -33.7098
#                 ],
#                 [
#                   -56.9187,
#                   -33.7127
#                 ],
#                 [
#                   -56.9316,
#                   -33.7129
#                 ]
#               ]
#             ],
#             [
#               [
#                 [
#                   -56.8952,
#                   -33.7335
#                 ],
#                 [
#                   -56.8994,
#                   -33.7332
#                 ],
#                 [
#                   -56.9015,
#                   -33.7307
#                 ],
#                 [
#                   -56.9002,
#                   -33.7277
#                 ],
#                 [
#                   -56.8954,
#                   -33.7264
#                 ],
#                 [
#                   -56.8938,
#                   -33.7278
#                 ],
#                 [
#                   -56.8931,
#                   -33.7325
#                 ],
#                 [
#                   -56.8952,
#                   -33.7335
#                 ]
#               ]
#             ],
#             [
#               [
#                 [
#                   -56.8331,
#                   -33.7561
#                 ],
#                 [
#                   -56.8363,
#                   -33.7546
#                 ],
#                 [
#                   -56.8369,
#                   -33.7527
#                 ],
#                 [
#                   -56.8313,
#                   -33.7334
#                 ],
#                 [
#                   -56.8302,
#                   -33.7322
#                 ],
#                 [
#                   -56.8251,
#                   -33.7319
#                 ],
#                 [
#                   -56.8218,
#                   -33.7325
#                 ],
#                 [
#                   -56.8195,
#                   -33.7339
#                 ],
#                 [
#                   -56.8184,
#                   -33.7398
#                 ],
#                 [
#                   -56.8218,
#                   -33.7505
#                 ],
#                 [
#                   -56.8244,
#                   -33.752
#                 ],
#                 [
#                   -56.8289,
#                   -33.7515
#                 ],
#                 [
#                   -56.8293,
#                   -33.7543
#                 ],
#                 [
#                   -56.8307,
#                   -33.7558
#                 ],
#                 [
#                   -56.8331,
#                   -33.7561
#                 ]
#               ]
#             ],
#             [
#               [
#                 [
#                   -57.1395,
#                   -33.7497
#                 ],
#                 [
#                   -57.1443,
#                   -33.7465
#                 ],
#                 [
#                   -57.1446,
#                   -33.7441
#                 ],
#                 [
#                   -57.1371,
#                   -33.734
#                 ],
#                 [
#                   -57.134,
#                   -33.7333
#                 ],
#                 [
#                   -57.129,
#                   -33.7354
#                 ],
#                 [
#                   -57.127,
#                   -33.7392
#                 ],
#                 [
#                   -57.1279,
#                   -33.742
#                 ],
#                 [
#                   -57.1303,
#                   -33.743
#                 ],
#                 [
#                   -57.1325,
#                   -33.7421
#                 ],
#                 [
#                   -57.1374,
#                   -33.7486
#                 ],
#                 [
#                   -57.1395,
#                   -33.7497
#                 ]
#               ]
#             ],
#             [
#               [
#                 [
#                   -56.8572,
#                   -33.8227
#                 ],
#                 [
#                   -56.8599,
#                   -33.82
#                 ],
#                 [
#                   -56.8634,
#                   -33.8208
#                 ],
#                 [
#                   -56.8676,
#                   -33.8193
#                 ],
#                 [
#                   -56.8716,
#                   -33.82
#                 ],
#                 [
#                   -56.8733,
#                   -33.8189
#                 ],
#                 [
#                   -56.8757,
#                   -33.8134
#                 ],
#                 [
#                   -56.8798,
#                   -33.8132
#                 ],
#                 [
#                   -56.8809,
#                   -33.8119
#                 ],
#                 [
#                   -56.8799,
#                   -33.8088
#                 ],
#                 [
#                   -56.8807,
#                   -33.8056
#                 ],
#                 [
#                   -56.8793,
#                   -33.8045
#                 ],
#                 [
#                   -56.8749,
#                   -33.8036
#                 ],
#                 [
#                   -56.8725,
#                   -33.8064
#                 ],
#                 [
#                   -56.8699,
#                   -33.8071
#                 ],
#                 [
#                   -56.8686,
#                   -33.8035
#                 ],
#                 [
#                   -56.8673,
#                   -33.8028
#                 ],
#                 [
#                   -56.8557,
#                   -33.8026
#                 ],
#                 [
#                   -56.8529,
#                   -33.803
#                 ],
#                 [
#                   -56.8522,
#                   -33.8054
#                 ],
#                 [
#                   -56.8548,
#                   -33.809
#                 ],
#                 [
#                   -56.8541,
#                   -33.8126
#                 ],
#                 [
#                   -56.8529,
#                   -33.8127
#                 ],
#                 [
#                   -56.847,
#                   -33.8088
#                 ],
#                 [
#                   -56.8409,
#                   -33.8081
#                 ],
#                 [
#                   -56.8376,
#                   -33.8104
#                 ],
#                 [
#                   -56.8379,
#                   -33.8131
#                 ],
#                 [
#                   -56.8406,
#                   -33.814
#                 ],
#                 [
#                   -56.8431,
#                   -33.8189
#                 ],
#                 [
#                   -56.8482,
#                   -33.8208
#                 ],
#                 [
#                   -56.8518,
#                   -33.8204
#                 ],
#                 [
#                   -56.8541,
#                   -33.8219
#                 ],
#                 [
#                   -56.8572,
#                   -33.8227
#                 ]
#               ]
#             ]
#           ],
#           "type": "MultiPolygon"
#         },
#         "field_name": "geometry",
#         "type": "GeometryFilter"
#       },
#       {
#         "config": {
#           "gte": 0.0,
#           "lte": 0.25
#         },
#         "field_name": "cloud_cover",
#         "type": "RangeFilter"
#       },
#       {
#         "config": {
#           "gte": 0.0,
#           "lte": 90.0
#         },
#         "field_name": "sun_elevation",
#         "type": "RangeFilter"
#       },
#       {
#         "config": [
#           {
#             "config": {
#               "gte": "2016-04-01T15:00:00Z",
#               "lte": "2016-12-30T23:59:59Z"
#             },
#             "field_name": "acquired",
#             "type": "DateRangeFilter"
#           }
#         ],
#         "type": "OrFilter"
#       }
#     ],
#     "type": "AndFilter"
#   },
#   "id": "1ebd5ed41669425b915f1da7038d47a8",
#   "item_types": [
#     "REOrthoTile",
#     "Sentinel2L1C",
#     "PSOrthoTile"
#   ],
#   "last_executed": null,
#   "name": "inv16",
#   "search_type": "saved",
#   "updated": "2017-09-22T19:47:04.669789Z"
# }
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-104-4cd2ac59575f> in <module>()
#       6
#       7 # Print the number of features in the saved search
# ----> 8 p(len(res["features"]))
#       9
#      10 # Print the first feature in the saved search
#
# TypeError: 'Response' object is not subscriptable

# %% [markdown]
# A saved search can also be updated by senidng a **`PUT`** request with a changed search definition back to the API.
#
# Did you know that saved searches can also send you a daily email to alert you to when new items are added to the search resutlts? Oh yeah!

# %%
# Assign a variable to the saved search response
search = res.json();

# Print the saved search
p(search)

# %%
# Change the saved search name to "South Vancouver Island"
search["name"] = "South Vancouver Island"

# Set the daily email enabled to true (Get email alerts when new items show up in this search)
search["__daily_email_enabled"] = True

# Send a PUT request to the saved search endpoint (Update the saved search)
res = session.put(saved_url, json=search)

# The response status code
res.status_code

# %% [markdown]
# ## Conclusion
#
# You made it! You should now be able to use the Planet API to find items and assets by searching, get stats and save searches, and activate and download assets using Python code!
#
# Don't forget to visit the [Planet API Reference Docs](https://www.planet.com/docs/reference/).
