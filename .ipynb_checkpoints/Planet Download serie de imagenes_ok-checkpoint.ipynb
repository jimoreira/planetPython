# %% [markdown]
# # Este script baja imagen segun un aoi dibujado interactivamente, y luego, clipea con el aoi (sobre la imagen ya bajada)
# * busca imagenes por filtros
# * genera un calculo de overlapping con el aoi determinado
# * filtra de la base total aquellas imagenes que cumplan con un criterio (por ej, :x% overlaping)
# * activa el asset que se quiera, y baja las imagenes zipeadas en un directorio a definir

# %%
import sys
import os
import json
import scipy
import urllib
import datetime 
import urllib3
import rasterio
import subprocess
import numpy as np
import pandas as pd
import seaborn as sns
from osgeo import gdal
from planet import api
from planet.api import filters
from traitlets import link
import rasterio.mask as rio_mask
from shapely.geometry import mapping, shape
from IPython.display import display, Image, HTML
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
urllib3.disable_warnings()
from ipyleaflet import (
    Map,
    Marker,
    TileLayer, ImageOverlay,
    Polyline, Polygon, Rectangle, Circle, CircleMarker,
    GeoJSON,
    DrawControl
)

api_keys = json.load(open("apikeys.json",'r'))
client = api.ClientV1(api_key=api_keys["PLANET_API_KEY"])

# %% [markdown]
# # Make a slippy map to get GeoJSON
# The planet API allows you to query using a geojson which is a special flavor of json.
# We are going to create a slippy map using leaflet and apply the Planet 2017 Q1 mosaic as the basemap. This requires our api key.
# We are going to add a special draw handler that shoves a draw region into a object so we get the geojson.
# If you don't want to do this, or need a fixed query try geojson.io
# To install and run:
# $ pip install ipyleaflet
# $ jupyter nbextension enable --py --sys-prefix ipyleaflet
# $ jupyter nbextension enable --py --sys-prefix widgetsnbextension
# More information

# %% [markdown]
# ## filtros y definir aoi

# %%
AOI = json.load(open("bichadero.geojson",'r'))
print(AOI['properties']['name'])
myAOI=AOI["geometry"]
print(myAOI)

# build a query using the AOI and
# a cloud_cover filter that excludes 'cloud free' scenes

oldthan = datetime.datetime(year=2018,month=3,day=1)
lessthan= datetime.datetime(year=2018,month=3,day=29)

query = filters.and_filter(
    filters.geom_filter(myAOI),
    filters.range_filter('cloud_cover', lt=5),
    filters.date_range('acquired', gt=oldthan,lte=lessthan)
)

# build a request for only PlanetScope imagery
request = filters.build_search_request(
    query, item_types=['PSScene4Band']
)

# if you don't have an API key configured, this will raise an exception
result = client.quick_search(request)
#print(result.items_iter)
scenes = []
planet_map = {}
for item in result.items_iter(limit=500):
    planet_map[item['id']]=item
    props = item['properties']
    props["id"] = item["id"]
    props["geometry"] = item["geometry"]
    props["thumbnail"] = item["_links"]["thumbnail"]
    #print(props)
    scenes.append(props)
    #print(scenes)
scenes = pd.DataFrame(data=scenes)
display(scenes)
print(len(scenes))
# Out:
# bichadero
# {'type': 'Polygon', 'coordinates': [[[-57.69987344741821, -32.97309988687854], [-57.69627928733825, -32.97309988687854], [-57.69627928733825, -32.97038163320756], [-57.69987344741821, -32.97038163320756], [-57.69987344741821, -32.97309988687854]]]}
#                        acquired  anomalous_pixels  cloud_cover  columns  \
# 0   2018-03-27T14:58:26.245808Z              0.24         1.00     8470
# 1   2018-03-19T14:59:27.695585Z              0.00         0.00     8600
# 2   2018-03-19T13:18:58.618712Z              0.00         0.00     9116
# 3   2018-03-26T14:59:07.583714Z              0.00         0.00     8535
# 4   2018-03-26T14:59:06.621776Z              0.00         0.00     8537
# 5   2018-03-18T13:19:02.385351Z              0.00         0.71     9147
# 15      32721  {'coordinates': [[[-57.93963568585062, -32.988...
# 16      32721  {'coordinates': [[[-57.713512825695034, -33.03...
# 17      32721  {'coordinates': [[[-57.68924316090456, -32.943...
# 18      32721  {'coordinates': [[[-57.910990845194185, -32.93...
# 19      32721  {'coordinates': [[[-57.74211146269597, -32.960...
# 20      32721  {'coordinates': [[[-57.802364337798245, -32.89...
# 21      32721  {'coordinates': [[[-57.69559629452762, -32.953...
# 22      32721  {'coordinates': [[[-57.633336975777084, -32.98...
# 23      32721  {'coordinates': [[[-57.7406552953091, -32.9356...
# 24      32721  {'coordinates': [[[-57.90506023875662, -32.885...
# 25      32721  {'coordinates': [[[-57.874825162873435, -32.87...
# 26      32721  {'coordinates': [[[-57.8808944587013, -32.9840...
# 27      32721  {'coordinates': [[[-57.960123990670475, -32.92...
# 28      32721  {'coordinates': [[[-57.750858594712795, -33.02...
# 29      32721  {'coordinates': [[[-57.79871756651193, -32.977...
# 30      32721  {'coordinates': [[[-57.70205651787926, -32.898...
# 31      32721  {'coordinates': [[[-57.71800440230151, -32.960...
# 32      32721  {'coordinates': [[[-57.42812972904205, -33.049...
# 33      32721  {'coordinates': [[[-57.74272082117539, -32.941...
# 34      32721  {'coordinates': [[[-57.70913114671833, -32.969...
# 35      32721  {'coordinates': [[[-57.7880040247514, -32.9696...
# 36      32721  {'coordinates': [[[-57.43034352087175, -33.049...
# 37      32721  {'coordinates': [[[-57.4101752913218, -32.9679...
# 38      32721  {'coordinates': [[[-57.946836010255474, -32.93...
#
#     ground_control  gsd                      id instrument    ...      \
# 0            False  3.7    20180327_145826_0f2b        PS2    ...
# 1             True  3.7    20180319_145927_0f1a        PS2    ...
# 2             True  4.0    20180319_131858_101b        PS2    ...
# 3             True  3.7    20180326_145907_104e        PS2    ...
# 4             True  3.7    20180326_145906_104e        PS2    ...
# 5            False  4.0    20180318_131902_1042        PS2    ...
# 6             True  3.7    20180324_145825_0f2d        PS2    ...
# 7             True  3.7    20180324_145826_0f2d        PS2    ...
# 8             True  3.7    20180323_145909_0f4d        PS2    ...
# 9            False  4.1    20180317_131806_102f        PS2    ...
# 10            True  4.0    20180323_131949_0f25        PS2    ...
# 11            True  3.9    20180316_132113_0e0f        PS2    ...
# 12            True  2.9    20180316_122833_0c54        PS2    ...
# 13            True  4.0    20180321_131922_100e        PS2    ...
# 14            True  4.0    20180321_131921_100e        PS2    ...
# 15            True  3.7    20180315_150030_1051        PS2    ...
# 16            True  4.0    20180314_131816_102e        PS2    ...
# 17            True  4.0    20180314_131815_102e        PS2    ...
# 18            True  4.0    20180313_131919_1039        PS2    ...
# 19            True  3.7    20180312_150009_104b        PS2    ...
# 20            True  4.0    20180312_131823_100c        PS2    ...
# 21            True  4.0    20180310_131844_0f52        PS2    ...
# 22            True  3.7    20180310_150059_103f        PS2    ...
# 23            True  4.0    20180309_131832_100a        PS2    ...
# 24            True  4.0    20180308_131907_100e        PS2    ...
# 25            True  4.0    20180307_131842_1014        PS2    ...
# 26            True  3.7    20180306_150141_1020        PS2    ...
# 27            True  4.0    20180306_131830_101b        PS2    ...
# 28            True  3.8    20180305_150131_0f32        PS2    ...
# 29            True  4.0    20180305_131840_1042        PS2    ...
# 30            True  4.0    20180304_131738_102f        PS2    ...
# 31            True  4.0    20180304_131739_102f        PS2    ...
# 32            True  4.0    20180303_131807_0f3f        PS2    ...
# 33            True  2.5  20180302_151254_1_0c24        PS2    ...
# 34            True  2.5    20180302_151255_0c24        PS2    ...
# 35            True  3.8    20180301_150155_0f2d        PS2    ...
# 36            True  4.1    20180301_163939_0f02        PS2    ...
# 37            True  4.1    20180301_163938_0f02        PS2    ...
# 38            True  4.0    20180301_131901_1040        PS2    ...
#
#    quality_category  rows  satellite_id  strip_id sun_azimuth sun_elevation  \
# 0              test  4211          0f2b   1302604        23.7          51.7
# 1          standard  4298          0f1a   1306226        26.2          54.6
# 2          standard  4519          101b   1305048        57.3          40.5
# 3          standard  4262          104e   1298904        24.0          52.1
# 4          standard  4265          104e   1298904        23.9          52.1
# 5              test  4494          1042   1297872        57.7          40.7
# 6          standard  4257          0f2d   1290624        24.6          52.8
# 7          standard  4260          0f2d   1290624        24.6          52.9
# 8          standard  4265          0f4d   1287884        24.8          53.2
# 9              test  4458          102f   1289450        58.3          40.7
# 10         standard  4459          0f25   1286976        55.4          39.6
# 11         standard  4436          0e0f   1281929        58.4          41.3
# 12         standard  5921          0c54   1280759        69.1          31.6
# 13         standard  4538          100e   1277854        56.4          40.0
# 14         standard  4537          100e   1277854        56.4          40.1
# 15         standard  4284          1051   1271107        27.3          56.0
# 16         standard  4579          102e   1268141        59.5          41.5
# 17         standard  4580          102e   1268141        59.5          41.5
# 18         standard  4572          1039   1264692        60.0          41.8
# 19         standard  4284          104b   1262274        28.3          57.1
# 20         standard  4545          100c   1261335        60.6          41.9
# 21         standard  4576          0f52   1255054        61.2          42.4
# 22         standard  4272          103f   1254726        29.1          57.7
# 23         standard  4553          100a   1251766        61.8          42.6
# 24         standard  4556          100e   1248350        62.3          42.9
# 25         standard  4583          1014   1244599        62.9          43.0
# 26         standard  4286          1020   1241403        30.4          59.2
# 27         standard  4566          101b   1241489        63.2          43.2
# 28         standard  4304          0f32   1238277        30.7          59.5
# 29         standard  4522          1042   1238215        63.7          43.4
# 30         standard  4571          102f   1234706        64.3          43.5
# 31         standard  4569          102f   1234706        64.2          43.5
# 32         standard  4565          0f3f   1231628        64.6          43.9
# 33             test  5213          0c24   1229601        27.1          61.7
# 34             test  5215          0c24   1229601        27.1          61.7
# 35         standard  4322          0f2d   1225299        32.3          60.8
# 36             test  4630          0f02   1225231       339.3          63.1
# 37             test  4633          0f02   1225231       339.3          63.1
# 38         standard  4600          1040   1225102        65.5          44.2
#
#                                             thumbnail               updated  \
# 0   https://api.planet.com/data/v1/item-types/PSSc...  2018-03-28T16:50:20Z
# 1   https://api.planet.com/data/v1/item-types/PSSc...  2018-03-28T16:11:17Z
# 2   https://api.planet.com/data/v1/item-types/PSSc...  2018-03-28T10:13:10Z
# 3   https://api.planet.com/data/v1/item-types/PSSc...  2018-03-27T14:23:25Z
# 4   https://api.planet.com/data/v1/item-types/PSSc...  2018-03-27T14:23:25Z
# 5   https://api.planet.com/data/v1/item-types/PSSc...  2018-03-26T18:14:01Z
# 6   https://api.planet.com/data/v1/item-types/PSSc...  2018-03-25T08:20:19Z
# 7   https://api.planet.com/data/v1/item-types/PSSc...  2018-03-25T06:04:32Z
# 8   https://api.planet.com/data/v1/item-types/PSSc...  2018-03-24T18:56:55Z
# 9   https://api.planet.com/data/v1/item-types/PSSc...  2018-03-24T18:39:51Z
# 10  https://api.planet.com/data/v1/item-types/PSSc...  2018-03-24T08:45:14Z
# 11  https://api.planet.com/data/v1/item-types/PSSc...  2018-03-22T22:00:21Z
# 12  https://api.planet.com/data/v1/item-types/PSSc...  2018-03-22T10:06:46Z
# 13  https://api.planet.com/data/v1/item-types/PSSc...  2018-03-22T05:39:16Z
# 14  https://api.planet.com/data/v1/item-types/PSSc...  2018-03-22T05:40:38Z
# 15  https://api.planet.com/data/v1/item-types/PSSc...  2018-03-16T08:02:26Z
# 16  https://api.planet.com/data/v1/item-types/PSSc...  2018-03-15T06:28:13Z
# 17  https://api.planet.com/data/v1/item-types/PSSc...  2018-03-15T06:29:41Z
# 18  https://api.planet.com/data/v1/item-types/PSSc...  2018-03-14T06:57:23Z
# 19  https://api.planet.com/data/v1/item-types/PSSc...  2018-03-13T04:28:46Z
# 20  https://api.planet.com/data/v1/item-types/PSSc...  2018-03-13T05:36:33Z
# 21  https://api.planet.com/data/v1/item-types/PSSc...  2018-03-11T05:09:59Z
# 22  https://api.planet.com/data/v1/item-types/PSSc...  2018-03-11T07:41:44Z
# 23  https://api.planet.com/data/v1/item-types/PSSc...  2018-03-10T05:42:41Z
# 24  https://api.planet.com/data/v1/item-types/PSSc...  2018-03-09T05:55:24Z
# 25  https://api.planet.com/data/v1/item-types/PSSc...  2018-03-08T05:50:36Z
# 26  https://api.planet.com/data/v1/item-types/PSSc...  2018-03-07T08:11:34Z
# 27  https://api.planet.com/data/v1/item-types/PSSc...  2018-03-07T06:06:47Z
# 28  https://api.planet.com/data/v1/item-types/PSSc...  2018-03-06T08:19:01Z
# 29  https://api.planet.com/data/v1/item-types/PSSc...  2018-03-06T07:59:02Z
# 30  https://api.planet.com/data/v1/item-types/PSSc...  2018-03-05T06:47:58Z
# 31  https://api.planet.com/data/v1/item-types/PSSc...  2018-03-05T06:48:26Z
# 32  https://api.planet.com/data/v1/item-types/PSSc...  2018-03-04T04:59:47Z
# 33  https://api.planet.com/data/v1/item-types/PSSc...  2018-03-03T08:29:18Z
# 34  https://api.planet.com/data/v1/item-types/PSSc...  2018-03-03T08:29:18Z
# 35  https://api.planet.com/data/v1/item-types/PSSc...  2018-03-02T09:00:01Z
# 36  https://api.planet.com/data/v1/item-types/PSSc...  2018-03-01T20:21:55Z
# 37  https://api.planet.com/data/v1/item-types/PSSc...  2018-03-01T20:21:54Z
# 38  https://api.planet.com/data/v1/item-types/PSSc...  2018-03-02T08:01:47Z
#
#    usable_data view_angle
# 0            0        0.1
# 1            0        0.3
# 2            0        0.8
# 3            0        0.0
# 4            0        0.1
# 5            0        0.9
# 6            0        0.2
# 7            0        0.2
# 8            0        0.1
# 9            0        0.1
# 10           0        1.1
# 11           0        1.3
# 12           0        2.5
# 13           0        0.9
# 14           0        0.9
# 15           0        0.2
# 16           0        0.7
# 17           0        0.7
# 18           0        0.7
# 19           0        0.2
# 20           0        0.9
# 21           0        0.1
# 22           0        0.1
# 23           0        0.9
# 24           0        0.9
# 25           0        0.9
# 26           0        0.2
# 27           0        1.9
# 28           0        0.2
# 29           0        0.9
# 30           0        0.7
# 31           0        0.7
# 32           0        0.9
# 33           0        3.2
# 34           0        3.2
# 35           0        0.3
# 36           0        0.1
# 37           0        0.1
# 38           0        0.8
#
# [39 rows x 26 columns]
# 39

# %% [markdown]
# # Cleanup
# The data we got back is good, but we need some more information
# We got back big scenes, but we only care about our area of interest. The scene may not cover the whole area of interest.
# We can use the Shapely library to quickly figure out how much each scene overlaps our AOI
# We will convert our AOI and the geometry of each scene to calculate overlap using a shapely call.
# The returned acquisition, publish, and update times are strings, we'll convert them to datatime objects so we wan search.

# %%
# now let's clean up the datetime stuff
# make a shapely shape from our aoi
AOIs = shape(myAOI)
footprints = []
overlaps = []
# go through the geometry from our api call, convert to a shape and calculate overlap area.
# also save the shape for safe keeping
for footprint in scenes["geometry"].tolist():
    s = shape(footprint)
    footprints.append(s)
    overlap = 100.0*(AOIs.intersection(s).area / AOIs.area)
    overlaps.append(overlap)
# take our lists and add them back to our dataframe
scenes['overlap'] = pd.Series(overlaps, index=scenes.index)
scenes['footprint'] = pd.Series(footprints, index=scenes.index)
# now make sure pandas knows about our date/time columns.
scenes["acquired"] = pd.to_datetime(scenes["acquired"])
scenes["published"] = pd.to_datetime(scenes["published"])
scenes["updated"] = pd.to_datetime(scenes["updated"])
scenes.head()
# Out:
#                     acquired  anomalous_pixels  cloud_cover  columns  \
# 0 2018-03-27 14:58:26.245808              0.24          1.0     8470
# 1 2018-03-19 14:59:27.695585              0.00          0.0     8600
# 2 2018-03-19 13:18:58.618712              0.00          0.0     9116
# 3 2018-03-26 14:59:07.583714              0.00          0.0     8535
# 4 2018-03-26 14:59:06.621776              0.00          0.0     8537
#
#    epsg_code                                           geometry  \
# 0      32721  {'coordinates': [[[-57.86186992566264, -32.980...
# 1      32721  {'coordinates': [[[-57.60093875059825, -32.997...
# 2      32721  {'coordinates': [[[-57.78040776496816, -32.897...
# 3      32721  {'coordinates': [[[-57.95884154019544, -32.968...
# 4      32721  {'coordinates': [[[-57.94812641769533, -33.013...
#
#    ground_control  gsd                    id instrument  \
# 0           False  3.7  20180327_145826_0f2b        PS2
# 1            True  3.7  20180319_145927_0f1a        PS2
# 2            True  4.0  20180319_131858_101b        PS2
# 3            True  3.7  20180326_145907_104e        PS2
# 4            True  3.7  20180326_145906_104e        PS2
#
#                          ...                         satellite_id  strip_id  \
# 0                        ...                                 0f2b   1302604
# 1                        ...                                 0f1a   1306226
# 2                        ...                                 101b   1305048
# 3                        ...                                 104e   1298904
# 4                        ...                                 104e   1298904
#
#    sun_azimuth  sun_elevation  \
# 0         23.7           51.7
# 1         26.2           54.6
# 2         57.3           40.5
# 3         24.0           52.1
# 4         23.9           52.1
#
#                                            thumbnail             updated  \
# 0  https://api.planet.com/data/v1/item-types/PSSc... 2018-03-28 16:50:20
# 1  https://api.planet.com/data/v1/item-types/PSSc... 2018-03-28 16:11:17
# 2  https://api.planet.com/data/v1/item-types/PSSc... 2018-03-28 10:13:10
# 3  https://api.planet.com/data/v1/item-types/PSSc... 2018-03-27 14:23:25
# 4  https://api.planet.com/data/v1/item-types/PSSc... 2018-03-27 14:23:25
#
#   usable_data  view_angle overlap  \
# 0           0         0.1   100.0
# 1           0         0.3   100.0
# 2           0         0.8   100.0
# 3           0         0.0   100.0
# 4           0         0.1   100.0
#
#                                            footprint
# 0  POLYGON ((-57.86186992566264 -32.9800820963985...
# 1  POLYGON ((-57.60093875059825 -32.9978626178496...
# 2  POLYGON ((-57.78040776496816 -32.8970959836591...
# 3  POLYGON ((-57.95884154019544 -32.9685601588453...
# 4  POLYGON ((-57.94812641769533 -33.0130790206442...
#
# [5 rows x 28 columns]

# %% [markdown]
# # Filtering our search using pandas.
# * Using our dataframe we will filter the scenes to just what we want.
# * First we want scenes with less than 10% clouds.
# * Second we want standard quality images. Test images may not be high quality.
# * Third well only look for scenes since January.
# * Finally we will create a new data frame with our queries and print the results.

# %%
# Now let's get it down to just good, recent, clear scenes
clear = scenes['cloud_cover']<0.1
good = scenes['quality_category']=="standard"

# definir que es recent, aca esta puesto con el mismo valor de oldthan, pero si el set es grande, hay que corregir.
recent = scenes["acquired"] > oldthan
#datetime.date(year=2018,month=3,day=1)

partial_coverage = scenes["overlap"] >90
good_scenes = scenes[(good&clear&recent&partial_coverage)]
good_scenes=good_scenes.sort_values(['acquired'], ascending=[False])
display(good_scenes)
print (len(good_scenes))

# Now let's get it down to just good, recent, clear scenes
clear = scenes['cloud_cover']<0.5
good = scenes['quality_category']=="standard"
all_time = scenes["acquired"] > datetime.date(year=2017,month=11,day=1)
full_coverage = scenes["overlap"] >= 60
all_scenes = scenes[(good&clear&all_time&full_coverage)]
#display(all_scenes)
print (len(all_scenes))
# Out:
#                      acquired  anomalous_pixels  cloud_cover  columns  \
# 3  2018-03-26 14:59:07.583714              0.00         0.00     8535
# 4  2018-03-26 14:59:06.621776              0.00         0.00     8537
# 11            True  3.9  20180316_132113_0e0f        PS2
# 12            True  2.9  20180316_122833_0c54        PS2
# 15            True  3.7  20180315_150030_1051        PS2
# 18            True  4.0  20180313_131919_1039        PS2
# 19            True  3.7  20180312_150009_104b        PS2
# 20            True  4.0  20180312_131823_100c        PS2
# 22            True  3.7  20180310_150059_103f        PS2
# 21            True  4.0  20180310_131844_0f52        PS2
# 23            True  4.0  20180309_131832_100a        PS2
# 24            True  4.0  20180308_131907_100e        PS2
# 25            True  4.0  20180307_131842_1014        PS2
# 26            True  3.7  20180306_150141_1020        PS2
# 27            True  4.0  20180306_131830_101b        PS2
# 28            True  3.8  20180305_150131_0f32        PS2
# 31            True  4.0  20180304_131739_102f        PS2
# 30            True  4.0  20180304_131738_102f        PS2
# 38            True  4.0  20180301_131901_1040        PS2
#
#                           ...                         satellite_id  strip_id  \
# 3                         ...                                 104e   1298904
# 4                         ...                                 104e   1298904
# 8                         ...                                 0f4d   1287884
# 10                        ...                                 0f25   1286976
# 1                         ...                                 0f1a   1306226
# 2                         ...                                 101b   1305048
# 11                        ...                                 0e0f   1281929
# 12                        ...                                 0c54   1280759
# 15                        ...                                 1051   1271107
# 18                        ...                                 1039   1264692
# 19                        ...                                 104b   1262274
# 20                        ...                                 100c   1261335
# 22                        ...                                 103f   1254726
# 21                        ...                                 0f52   1255054
# 23                        ...                                 100a   1251766
# 24                        ...                                 100e   1248350
# 25                        ...                                 1014   1244599
# 26                        ...                                 1020   1241403
# 27                        ...                                 101b   1241489
# 28                        ...                                 0f32   1238277
# 31                        ...                                 102f   1234706
# 30                        ...                                 102f   1234706
# 38                        ...                                 1040   1225102
#
#     sun_azimuth  sun_elevation  \
# 3          24.0           52.1
# 4          23.9           52.1
# 8          24.8           53.2
# 10         55.4           39.6
# 1          26.2           54.6
# 2          57.3           40.5
# 11         58.4           41.3
# 12         69.1           31.6
# 15         27.3           56.0
# 18         60.0           41.8
# 19         28.3           57.1
# 20         60.6           41.9
# 22         29.1           57.7
# 21         61.2           42.4
# 23         61.8           42.6
# 24         62.3           42.9
# 25         62.9           43.0
# 26         30.4           59.2
# 27         63.2           43.2
# 28         30.7           59.5
# 31         64.2           43.5
# 30         64.3           43.5
# 38         65.5           44.2
#
#                                             thumbnail             updated  \
# 3   https://api.planet.com/data/v1/item-types/PSSc... 2018-03-27 14:23:25
# 4   https://api.planet.com/data/v1/item-types/PSSc... 2018-03-27 14:23:25
# 8   https://api.planet.com/data/v1/item-types/PSSc... 2018-03-24 18:56:55
# 10  https://api.planet.com/data/v1/item-types/PSSc... 2018-03-24 08:45:14
# 1   https://api.planet.com/data/v1/item-types/PSSc... 2018-03-28 16:11:17
# 2   https://api.planet.com/data/v1/item-types/PSSc... 2018-03-28 10:13:10
# 11  https://api.planet.com/data/v1/item-types/PSSc... 2018-03-22 22:00:21
# 12  https://api.planet.com/data/v1/item-types/PSSc... 2018-03-22 10:06:46
# 15  https://api.planet.com/data/v1/item-types/PSSc... 2018-03-16 08:02:26
# 18  https://api.planet.com/data/v1/item-types/PSSc... 2018-03-14 06:57:23
# 19  https://api.planet.com/data/v1/item-types/PSSc... 2018-03-13 04:28:46
# 20  https://api.planet.com/data/v1/item-types/PSSc... 2018-03-13 05:36:33
# 22  https://api.planet.com/data/v1/item-types/PSSc... 2018-03-11 07:41:44
# 21  https://api.planet.com/data/v1/item-types/PSSc... 2018-03-11 05:09:59
# 23  https://api.planet.com/data/v1/item-types/PSSc... 2018-03-10 05:42:41
# 24  https://api.planet.com/data/v1/item-types/PSSc... 2018-03-09 05:55:24
# 25  https://api.planet.com/data/v1/item-types/PSSc... 2018-03-08 05:50:36
# 26  https://api.planet.com/data/v1/item-types/PSSc... 2018-03-07 08:11:34
# 27  https://api.planet.com/data/v1/item-types/PSSc... 2018-03-07 06:06:47
# 28  https://api.planet.com/data/v1/item-types/PSSc... 2018-03-06 08:19:01
# 31  https://api.planet.com/data/v1/item-types/PSSc... 2018-03-05 06:48:26
# 30  https://api.planet.com/data/v1/item-types/PSSc... 2018-03-05 06:47:58
# 38  https://api.planet.com/data/v1/item-types/PSSc... 2018-03-02 08:01:47
#
#    usable_data  view_angle     overlap  \
# 3            0         0.0  100.000000
# 4            0         0.1  100.000000
# 8            0         0.1  100.000000
# 10           0         1.1  100.000000
# 1            0         0.3  100.000000
# 2            0         0.8  100.000000
# 11           0         1.3  100.000000
# 12           0         2.5  100.000000
# 15           0         0.2  100.000000
# 18           0         0.7  100.000000
# 19           0         0.2  100.000000
# 20           0         0.9  100.000000
# 22           0         0.1  100.000000
# 21           0         0.1   99.895693
# 23           0         0.9  100.000000
# 24           0         0.9  100.000000
# 25           0         0.9  100.000000
# 26           0         0.2  100.000000
# 27           0         1.9  100.000000
# 28           0         0.2  100.000000
# 31           0         0.7  100.000000
# 30           0         0.7  100.000000
# 38           0         0.8  100.000000
#
#                                             footprint
# 3   POLYGON ((-57.95884154019544 -32.9685601588453...
# 4   POLYGON ((-57.94812641769533 -33.0130790206442...
# 8   POLYGON ((-57.8568418737346 -32.99076485601099...
# 10  POLYGON ((-57.94856592895204 -32.9410548388414...
# 1   POLYGON ((-57.60093875059825 -32.9978626178496...
# 2   POLYGON ((-57.78040776496816 -32.8970959836591...
# 11  POLYGON ((-57.97073909335779 -32.9696977092725...
# 12  POLYGON ((-57.55635649245573 -32.8699857959382...
# 15  POLYGON ((-57.93963568585062 -32.9882941725762...
# 18  POLYGON ((-57.91099084519418 -32.9349283954991...
# 19  POLYGON ((-57.74211146269597 -32.9605818412144...
# 20  POLYGON ((-57.80236433779825 -32.8905075335516...
# 22  POLYGON ((-57.63333697577708 -32.9883000474824...
# 21  POLYGON ((-57.69559629452762 -32.9539739571388...
# 23  POLYGON ((-57.7406552953091 -32.93561281204036...
# 24  POLYGON ((-57.90506023875662 -32.8853356872812...
# 25  POLYGON ((-57.87482516287344 -32.8755721793901...
# 26  POLYGON ((-57.8808944587013 -32.98408174212476...
# 27  POLYGON ((-57.96012399067047 -32.9244396808857...
# 28  POLYGON ((-57.7508585947128 -33.02270155302862...
# 31  POLYGON ((-57.71800440230151 -32.9604035416702...
# 30  POLYGON ((-57.70205651787926 -32.8983811073412...
# 38  POLYGON ((-57.94683601025547 -32.9364862113621...
#
# [23 rows x 28 columns]
# 23
# 27

# %% [markdown]
# # Product Activation and Downloading
# There are two things we need to know, the satellite type (asset) and image type (product).
# Full resolution uncompressed satellite images are big and there are lots of ways to view them.
# For this reason Planet generally keeps images in their native format and only processes them on customer requests. There is some caching of processed scenes, but this is the exception not the rule.
# All images must be activated prior to downloading and this can take some time based on demand.
# Additionally we need to determine what sort of product we want to download. Generally speaking there are three kinds of scenes:
# Analytic - multi-band full resolution images that have not been processed. These are like raw files for DSLR camers.
# Visual - these are color corrected rectified tifs. If you are just starting out this is your best call.
# UDM - Usable data mask. This mask can be used to find bad pixels and columns and to mask out areas with clouds.

# %%
import requests
import time

# Set Item Type
item_type = 'PSScene4Band'

# Set Asset Type
asset_type = 'analytic_sr'

#lista de los nombres de imagenes a bajar (era scene_id)
to_get=good_scenes['id'].tolist()
print(to_get)
#calcular el area de la sumatoria de las imagenes#
#
api_key=api_keys["PLANET_API_KEY"]
url_base=[]
i=0
for scenes in to_get[0:1]:
# Request clip of scene (This will take some time to complete)
    #calcular el area de la seleccion de imagenes hecha e imprimir#
    
    clip_payload = {'aoi': myAOI,'targets': [{'item_id': to_get[i],'item_type': item_type,'asset_type': asset_type}]}
    #print(clip_payload)
    i=i+1
    request = requests.post('https://api.planet.com/compute/ops/clips/v1', auth=(api_key, ''), json=clip_payload)
    print(request)
    clip_url= request.json()['_links']['_self']
    print(clip_url)
    # Poll API to monitor clip status. Once finished, download and upzip the scene
    clip_succeeded = False
    while not clip_succeeded:

    # Poll API
        check_state_request = requests.get(clip_url, auth=(api_key, ''))
        #print(check_state_request)
    # If clipping process succeeded , we are done
        if check_state_request.json()['state'] == 'succeeded':
            clip_download_url = check_state_request.json()['_links']['results'][0]
            clip_succeeded = True
            #print(clip_download_url)
            if clip_download_url in url_base: continue
            url_base.append(clip_download_url)
            print("Clip of scene succeeded and is ready to download") 
    
    # Still activating. Wait 1 second and check again.
        else:
            print("...Still waiting for clipping to complete...")
            time.sleep(2)

print(len(url_base))
# Out:
# ['20180326_145907_104e', '20180326_145906_104e', '20180323_145909_0f4d', '20180323_131949_0f25', '20180319_145927_0f1a', '20180319_131858_101b', '20180316_132113_0e0f', '20180316_122833_0c54', '20180315_150030_1051', '20180313_131919_1039', '20180312_150009_104b', '20180312_131823_100c', '20180310_150059_103f', '20180310_131844_0f52', '20180309_131832_100a', '20180308_131907_100e', '20180307_131842_1014', '20180306_150141_1020', '20180306_131830_101b', '20180305_150131_0f32', '20180304_131739_102f', '20180304_131738_102f', '20180301_131901_1040']
# <Response [202]>
# https://api.planet.com/compute/ops/clips/v1/2322b028-7ab3-45f1-9f99-b4fbf5849166
# ...Still waiting for clipping to complete...
# Clip of scene succeeded and is ready to download
# 1

# %% [markdown]
# Download and upzip the clip
# Once complete, look in the output directory to see your clipped tif file.
#
# NOTE: Clipped scene will only be available for 5 minutes.

# %%
import os
from tqdm import tqdm
import zipfile
from datetime import datetime

# ubicar los archivos donde se desee
path_or='D:/javie/Descargas/'

print(to_get[0:3])
#print(url_base)
i=0    
downloaded=[]
for url in url_base[0:1]: 
    response = requests.get(url, stream=True)
    #print(response)
    scene_id=to_get[i]
    print(scene_id)
    path =os.path.join(path_or+ scene_id +'_'+ asset_type +'_'+ AOI['properties']['name'])
    #print(path)
    i= i+1
    if os.path.isfile(path + '.zip' ):
        print ("skipping, we allready have scene: ", scene_id)
        continue 
    else:
        with open(path +'.zip', "wb") as handle:
            for data in tqdm(response.iter_content()):
                #print(data)
                handle.write(data)
        downloaded.append(path)
        print(downloaded)

        date=datetime.now()
        date=date.strftime('%Y_%m_%d_%H%M')

        newpath=os.path.join(path_or, date + '_downloaded.txt')
        #print(newpath)
        with open (newpath , "w") as pronto:
            for item in downloaded:
                pronto.write("%s\n" % item)       
    #Unzip file
        ziped_item = zipfile.ZipFile(path + ".zip")
        ziped_item.extractall(path)     
  
    # Delete zip file
        #time.sleep(5)
        #os.remove(path + '.zip')
        print('Downloaded clips located in:', path_or)
# Out:
# ['20180326_145907_104e', '20180326_145906_104e', '20180323_145909_0f4d']
# 20180326_145907_104e
# 108846it [00:02, 49441.09it/s]
# ['D:/javie/Descargas/20180326_145907_104e_analytic_sr_bichadero']
# Downloaded clips located in: D:/javie/Descargas/
